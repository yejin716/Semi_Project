# %%
#csv파일 통합하기 

import pandas as pd
from glob import glob

file_names = glob("./*.csv") #폴더 내의 모든 csv파일 목록을 불러온다
total = pd.DataFrame() #빈 데이터프레임 하나를 생성한다

for file_name in file_names:
    temp = pd.read_csv(file_name, sep='구분자', encoding='ANSI') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
    total = pd.concat([total, temp]) #전체 데이터프레임에 추가하여 넣는다

total.to_csv("./total.csv")


# df1 = pd.read_csv('./2019.csv',encoding='ANSI')
# df2 = pd.read_csv('./2020.csv',encoding='ANSI')
# df3 = pd.read_csv('./2021.csv',encoding='ANSI')
# df4 = pd.read_csv('./2022.csv',encoding='ANSI')
# df5 = pd.read_csv('./2023.csv',encoding='ANSI')


# df = pd.concat([df1, df2, df3,df4,df5], ignore_index=True, encoding='ANSI')
# Out:
# C:\Users\Master\AppData\Local\Temp\ipykernel_13796\3935597690.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='ANSI') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\Master\AppData\Local\Temp\ipykernel_13796\3935597690.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='ANSI') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# ...

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("./2019-2023가계동향조사.csv", encoding="ANSI")

df = pd.DataFrame(data)
df
# print(df)

a = df[(df['가구원수'] == 1) & (df["가구주_연령"] >= 20) & (df["가구주_연령"] <= 30)].groupby("조사연월").value_counts() #월별 가구수가1이고 연령이 20-30인 데이터 개수  
pd.DataFrame(a)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
#년도별 가구원이 1이고 연령이 20이상 30이하인 데이터 개수 구하기 

data1 = df[(df['가구원수'] == 1) & (df["가구주_연령"] >= 20) & (df["가구주_연령"] <= 30)].groupby(["조사연월","가구원수"])["가구주_연령"].value_counts()
data2 = df[(df['가구원수'] == 1) & (df["가구주_연령"] >= 20) & (df["가구주_연령"] <= 30)].groupby(["조사연월","가구원수","가구주_연령"])["가구주_연령"].count()
pd.DataFrame(data1)
# Out:
#                     count
# 조사연월   가구원수 가구주_연령
# 201900 1    28         56
#             29         53
#             27         45
#             25         42
#             26         40
#             22         38
#             24         37
#             23         33
#             30         32
#             21         23
#             20         22
# 202000 1    29         77
#             27         71
#             28         68
#             26         67
#             30         66
#             25         59
#             23         55
#             24         46
#             22         30
#             21         26
#             20         13
# 202100 1    29         83
#             27         80
#             26         78
#             28         72
#             30         67
#             25         56
#             24         55
#             23         42
#             22         29
#             21         23
#             20         10
# ...

# %%
#월별 가구원이 1인 20~30대별 총 데이터 개수 
age = pd.DataFrame(data2)
age.columns = ["해당연령의 인원수"]
age
# Out:
#                     해당연령의 인원수
# 조사연월   가구원수 가구주_연령
# 201900 1    20             22
#             21             23
#             22             38
#             23             33
#             24             37
#             25             42
#             26             40
#             27             45
#             28             56
#             29             53
#             30             32
# 202000 1    20             13
#             21             26
#             22             30
#             23             55
#             24             46
#             25             59
#             26             67
#             27             71
#             28             68
#             29             77
#             30             66
# 202100 1    20             10
#             21             23
#             22             29
#             23             42
#             24             55
#             25             56
#             26             78
# ...

# %%
#교육이라는 글자가 포함된 열값 가져오기

find_char = '교육'
columns_fc = [column for column in df.columns if find_char in column]
print(columns_fc) # 교육비가 포함된 컬럼값 가져오기
# Out:
# ['가계지출_소비지출_교육비', '가계지출_소비지출_교육_정규교육비', '가계지출_소비지출_교육_초등교육비', '가계지출_소비지출_교육_중등교육비', '가계지출_소비지출_교육_고등교육비', '가계지출_소비지출_교육_학원보습교육비', '가계지출_소비지출_교육_학생학원교육비', '가계지출_소비지출_교육_성인학원비', '가계지출_소비지출_교육_기타교육비']

# %% [markdown]
# 교육비 지출 분석

# %%
#'교육' 글자가 들어간 컬럼명의 값 찾기 
import pandas as pd

grouped = df.groupby('조사연월') #조사연월별로 
new_rows = pd.DataFrame() # 추출된 행을 저장할 빈 데이터프레임 생성
find_char = '교육' #열이름에서 찾을 글자 지정 

for y, g in grouped: 
    fr = g[(g['가구원수'] == 1) & (g["가구주_연령"] >= 20) & (g["가구주_연령"] <= 30)] #가구원수가 1이고 가구주연령이 20살~30살인 조건 지정
    columns_fc = [column for column in g.columns if '교육' in column] #교육이 포함된 열 지정
    new_rows = pd.concat([new_rows, fr[columns_fc]], ignore_index= True)#빈 데이터프레임에 fr조건을 만족하는 행값중 columns_fc 이어붙이기

    #print(f"연도 {y}에 해당하는 행 값:")
    #print(pd.DataFrame(sr) )
    print()
    
pd.DataFrame(new_rows)
# Out:
#       가계지출_소비지출_교육비  가계지출_소비지출_교육_정규교육비  가계지출_소비지출_교육_초등교육비  \
# 0                 0                   0                   0
# 1             33333                   0                   0
# 2                 0                   0                   0
# 3                 0                   0                   0
# 4                 0                   0                   0
# ...             ...                 ...                 ...
# 3000         518000              292000                   0
# 3001              0                   0                   0
# 3002              0                   0                   0
# 3003          33333                   0                   0
# 3004              0                   0                   0
#
#       가계지출_소비지출_교육_중등교육비  가계지출_소비지출_교육_고등교육비  가계지출_소비지출_교육_학원보습교육비  \
# 0                      0                   0                     0
# 1                      0                   0                 33333
# ...

# %%
#'교육' 글자가 들어간 컬럼명의 값 찾기 
import pandas as pd

grouped = df.groupby('조사연월') #조사연월별로 
sr = pd.DataFrame() # 추출된 행을 저장할 빈 데이터프레임 생성
find_char = '교육' #열이름에서 찾을 글자 지정 

for y, g in grouped: 
    fr = g[(g['가구원수'] == 1) & (g["가구주_연령"] >= 20) & (g["가구주_연령"] <= 30)] #가구원수가 1이고 가구주연령이 20살~30살인 조건 지정
    columns_fc = [column for column in g.columns if '교육' in column] #교육이 포함된 열 지정
    sr = fr[fr[columns_fc] > 0].dropna(axis=1, how='any')#빈 데이터프레임에 fr조건을 만족하는 행값중 columns_fc 이어붙이기
    sr = fr[["가구원수","가구주_연령"] + columns_fc]
    
    #print(f"연도 {y}에 해당하는 행 값:")
    #print(pd.DataFrame(sr))
    #print()
pd.DataFrame(sr)
# Out:
#        가구원수  가구주_연령  가계지출_소비지출_교육비  가계지출_소비지출_교육_정규교육비  가계지출_소비지출_교육_초등교육비  \
# 46780     1      30              0                   0                   0
# 46781     1      29          21667                   0                   0
# 46784     1      26              0                   0                   0
# 46789     1      30              0                   0                   0
# 46790     1      29              0                   0                   0
# ...     ...     ...            ...                 ...                 ...
# 59560     1      24         518000              292000                   0
# 59647     1      24              0                   0                   0
# 59661     1      28              0                   0                   0
# 59689     1      28          33333                   0                   0
# 59718     1      30              0                   0                   0
#
# ...

# %%
#2019-2023년도 교육비 총합계

ss = new_rows.sum()
ds = pd.DataFrame(ss)

ds.columns = ["총합계"]

ds
# Out:
#                             총합계
# 가계지출_소비지출_교육비         141773684
# 가계지출_소비지출_교육_정규교육비     74032539
# 가계지출_소비지출_교육_초등교육비            0
# 가계지출_소비지출_교육_중등교육비            0
# 가계지출_소비지출_교육_고등교육비     74032539
# 가계지출_소비지출_교육_학원보습교육비   66516878
# 가계지출_소비지출_교육_학생학원교육비    6714552
# 가계지출_소비지출_교육_성인학원비     59802327
# 가계지출_소비지출_교육_기타교육비      1224263

# %% [markdown]
# 음식숙박 분석

# %%
import pandas as pd

grouped = df.groupby('조사연월') #조사연월별로 
sf = pd.DataFrame() # 추출된 행을 저장할 빈 데이터프레임 생성
find_char = '음식숙박' #열이름에서 찾을 글자 지정 

for y, g in grouped: 
    fr = g[(g['가구원수'] == 1) & (g["가구주_연령"] >= 20) & (g["가구주_연령"] <= 30)] #가구원수가 1이고 가구주연령이 20살~30살인 조건 지정
    columns_fc = [column for column in g.columns if '음식숙박' in column] #교육이 포함된 열 지정
    sf = pd.concat([sf, fr[columns_fc]], ignore_index= True)#빈 데이터프레임에 fr조건을 만족하는 행값중 columns_fc 이어붙이기
    # sf = fr[["가구원수","가구주_연령"] + columns_fc]

    #print(f"연도 {y}에 해당하는 행 값:")
    #print(sf) 
    print()
pd.DataFrame(sf)
# Out:
#       가계지출_소비지출_음식숙박비  가계지출_소비지출_음식숙박_식대  가계지출_소비지출_음식숙박_숙박비
# 0              139950             139950                   0
# 1              147913             147913                   0
# 2              254500             177000               77500
# 3              351350             351350                   0
# 4              410090             410090                   0
# ...               ...                ...                 ...
# 3000           179720             179720                   0
# 3001           383725             383725                   0
# 3002           278700             278700                   0
# 3003           669003             594337               74667
# 3004            76200              76200                   0
#
# [3005 rows x 3 columns]

# %%
ss = sf.sum()
ds = pd.DataFrame(ss)

ds.columns = ["총합계"]

ds
# Out:
#                            총합계
# 가계지출_소비지출_음식숙박비     1111967274
# 가계지출_소비지출_음식숙박_식대   1057803643
# 가계지출_소비지출_음식숙박_숙박비    54163645
