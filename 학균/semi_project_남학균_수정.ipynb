# %%
# 조건으로 검색하기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat = pd.read_csv("./data/2019_1인가구.csv", encoding='cp949') ; dat
dat_2019 = dat.copy()

# %%
## [데이터 필요한 행만 전처리]

dat_2019.rename(columns={
    '가계지출금액' : '전체소비지출',
    '가계지출_소비지출금액' : '소비지출',
    '가계지출_소비지출_주거수도광열비' : '주거수도광열비',
    '가계지출_소비지출_주거수도광열_실제주거비구입비' : '주거수도광열_실제주거비구입',
    '가계지출_소비지출_주거수도광열_주택유지수선구입비' : '주거수도광열_주택유지수선구입',
    '가계지출_소비지출_주거수도광열_상하수도폐기물처리비' : '주거수도광열_상하수도폐기물처리',
    '가계지출_소비지출_주거수도광열_기타주거관련서비스구입비' : '주거수도광열_기타주거관련서비스구입',
    '가계지출_소비지출_주거수도광열_연료비구입비' : '주거수도광열_연료비구입',
    '가계지출_소비지출_가정용품가사서비스이용금액' : '가정용품가사서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가구조명구입비' : '가정용품가사서비스_가구조명구입',
    '가계지출_소비지출_가정용품가사서비스_실내장식구입비' : '가정용품가사서비스_실내장식구입',
    '가계지출_소비지출_가정용품가사서비스_가구조명장식서비스이용금액' : '가정용품가사서비스_가구조명장식서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가정용섬유구입비' : '가정용품가사서비스_가정용섬유구입',
    '가계지출_소비지출_가정용품가사서비스_가전가정용기기구입비' : '가정용품가사서비스_가전가정용기기구입',
    '가계지출_소비지출_가정용품가사서비스_가전관련서비스이용금액' : '가정용품가사서비스_가전관련서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가사용품구입비' : '가정용품가사서비스_가사용품구입',
    '가계지출_소비지출_가정용품가사서비스_가정용공구기타구입비' : '가정용품가사서비스_가정용공구기타구입',
    '가계지출_소비지출_가정용품가사서비스_가사소모품구입비' : '가정용품가사서비스_가사소모품구입',
    '가계지출_소비지출_가정용품가사서비스_가사서비스금액' : '가정용품가사서비스_가사서비스',
    '가계지출_소비지출_보건제품구입비' : '보건제품구입',
    '가계지출_소비지출_보건_의약품구입비' : '보건_의약품구입',
    '가계지출_소비지출_보건_의료용소모품구입비' : '보건_의료용소모품구입',
    '가계지출_소비지출_보건_보건의료용품기구구입비' : '보건_보건의료용품기구구입',
    '가계지출_소비지출_보건_외래의료서비스이용금액' : '보건_외래의료서비스이용',
    '가계지출_소비지출_보건_치과서비스이용금액' : '보건_치과서비스이용',
    '가계지출_소비지출_보건_기타의료서비스이용금액' : '보건_기타의료서비스이용',
    '가계지출_소비지출_보건_입원서비스이용금액' : '보건_입원서비스이용'
}, inplace=True
)

# %%
dat_2019.columns
# Out:
# Index(['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드',
#        '가구주_성별코드', '가구주_연령', '가구주_취업여부',
#        ...
#        '가계지출_소비지출_기타상품서비스_기타서비스금액구입비', '가계지출_비소비지출금액', '가계지출_비소비지출_경상조세',
#        '가계지출_비소비지출_비경상조세', '가계지출_비소비지출_연금기여금', '가계지출_비소비지출_사회보장구입비',
#        '가계지출_비소비지출_이자비용', '가계지출_비소비지출_가구간이전지출금액', '가계지출_비소비지출_비영리단체이전지출금액',
#        '도시읍면부구분코드'],
#       dtype='object', length=139)

# %%
# 행 전처리

dat_2019 = dat_2019[['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드', '가구주_성별코드', '가구주_연령', '가구주_취업여부', '거처구분코드', '자동차보유대수',
           '입주형태코드', '월세평가금액', '전세보증금', '소득구간코드', '전체소비지출', '소비지출', '전체소비지출', '소비지출', '주거수도광열비', '주거수도광열_실제주거비구입', '주거수도광열_주택유지수선구입', '주거수도광열_상하수도폐기물처리',
           '주거수도광열_기타주거관련서비스구입', '주거수도광열_연료비구입', '가정용품가사서비스이용', '가정용품가사서비스_가구조명구입', '가정용품가사서비스_실내장식구입', '가정용품가사서비스_가구조명장식서비스이용', '가정용품가사서비스_가정용섬유구입', '가정용품가사서비스_가전가정용기기구입', '가정용품가사서비스_가전관련서비스이용',
           '가정용품가사서비스_가사용품구입', '가정용품가사서비스_가정용공구기타구입', '가정용품가사서비스_가사소모품구입', '가정용품가사서비스_가사서비스', '보건제품구입', '보건_의약품구입', '보건_의료용소모품구입', '보건_보건의료용품기구구입', '보건_외래의료서비스이용',
           '보건_치과서비스이용', '보건_기타의료서비스이용', '보건_입원서비스이용']]

# %%
dat_2019['가구구분코드'] = dat_2019['가구구분코드'].replace({1: '근로자 가구', 2: '비근로자 가구'})
dat_2019['노인가구여부'] = dat_2019['노인가구여부'].replace({0: '아니요', 1: '예'})
dat_2019['배우자코드'] = dat_2019['배우자코드'].replace({1: '현재(동거)', 2: '현재(비동거)', 3:'부재'})
dat_2019['가구주_성별코드'] = dat_2019['가구주_성별코드'].replace({1: '남성', 2: '여성'})
dat_2019['가구주_취업여부'] = dat_2019['가구주_취업여부'].replace({1: '취업', 2: '실업자'})
dat_2019['거처구분코드'] = dat_2019['거처구분코드'].replace({1: '단독주택(다세대 포함)', 2: '아파트', 3: '연립주택', 4: '다가구주택', 5: '비주거용 건물', 6: '오피스텔', 7: '기타'})
dat_2019['입주형태코드'] = dat_2019['입주형태코드'].replace({1: '내 집', 2: '무료주택', 3: '회사주택', 4: '임대', 5: '영구임대', 6: '보증금 월세', 7: '보증금 없는 월세'})
dat_2019['소득구간코드'] = dat_2019['소득구간코드'].replace({1: '100만원 미만', 2: '100~200만원', 3: '200~300만원', 4: '300~400만원', 5: '400~500만원', 6: '500~600만원', 7: '600~700만원', 8: '700만원 이상'})
# dat_2019['도시읍면부구분코드'] = dat_2019['도시읍면부구분코드'].replace({0: '비도시', 1: '도시'})

# %%
dat_2019
# Out:
#         조사연월  가구일련번호   가구구분코드  가구원수  취업인원수 노인가구여부    배우자코드 가구주_성별코드  가구주_연령  \
# 0     201900       1  비근로자 가구     1      0    아니요  현재(비동거)       여성      64
# 1     201900       2   근로자 가구     3      2    아니요   현재(동거)       남성      63
# 2     201900       3  비근로자 가구     1      0    아니요       부재       남성      58
# 3     201900       4   근로자 가구     3      2    아니요   현재(동거)       남성      29
# 4     201900       5   근로자 가구     1      1    아니요       부재       여성      58
# ...      ...     ...      ...   ...    ...    ...      ...      ...     ...
# 9505  201900    9506  비근로자 가구     4      2    아니요   현재(동거)       남성      37
# 9506  201900    9507  비근로자 가구     4      3    아니요   현재(동거)       남성      59
# 9507  201900    9508  비근로자 가구     5      3    아니요   현재(동거)       남성      60
# 9508  201900    9509   근로자 가구     1      1    아니요       부재       남성      63
# 9509  201900    9510  비근로자 가구     2      2      예   현재(동거)       남성      78
#
# ...

# %%
def age(가구주_연령):
    if 가구주_연령 < 20:
        return '10대'
    elif 20 <= 가구주_연령 < 30:
        return '20대'
    elif 30 <= 가구주_연령 < 40:
        return '30대'
    elif 40 <= 가구주_연령 < 50:
        return '40대'
    elif 50 <= 가구주_연령 < 60:
        return '50대'
    elif 60 <= 가구주_연령 < 70:
        return '60대'
    else:
        return '70대 이상'

# 데이터 연령대별 구분
dat_2019.loc[:,'연령대'] = dat_2019['가구주_연령'].apply(age)
dat_2019.연령대
# Out:
# 0          60대
# 1          60대
# 2          50대
# 3          20대
# 4          50대
#          ...
# 9505       30대
# 9506       50대
# 9507       60대
# 9508       60대
# 9509    70대 이상
# Name: 연령대, Length: 9510, dtype: object

# %%
# 연령대별 소득구간코드 분포 분석
income_by_age_group = dat_2019.groupby('연령대')['소득구간코드'].value_counts().unstack().fillna(0)

# 연령대별 소득구간코드 분포 출력
print(income_by_age_group)
# Out:
# 소득구간코드    100~200만원     100만원 미만    200~300만원    300~400만원    400~500만원  \
# 연령대
# 10대      5.00000000   9.00000000   4.00000000   0.00000000   0.00000000
# 20대    105.00000000  88.00000000 153.00000000  90.00000000  38.00000000
# 30대     60.00000000  37.00000000 181.00000000 248.00000000 201.00000000
# 40대    104.00000000  56.00000000 243.00000000 276.00000000 252.00000000
# 50대    237.00000000 137.00000000 299.00000000 306.00000000 273.00000000
# 60대    387.00000000 231.00000000 363.00000000 302.00000000 228.00000000
# 70대 이상 637.00000000 714.00000000 277.00000000 123.00000000  93.00000000
#
# 소득구간코드    500~600만원    600~700만원     700만원 이상
# 연령대
# 10대      0.00000000   0.00000000   0.00000000
# 20대     24.00000000  12.00000000  10.00000000
# 30대    165.00000000  92.00000000 164.00000000
# 40대    236.00000000 183.00000000 401.00000000
# 50대    269.00000000 205.00000000 479.00000000
# 60대    161.00000000  91.00000000 179.00000000
# 70대 이상  37.00000000  15.00000000  30.00000000

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc
import warnings
import pandas as pd

# %%
# # 나눔글꼴 경로 설정
# font_path = 'C:/Windows/Fonts/KoPub바탕체.ttf'

# # 폰트 이름 가져오기
# font_name = fm.FontProperties(fname=font_path).get_name()

# # 폰트 설정
# plt.rc('font', family=font_name)

# # 시각화 설정
# plt.figure(figsize=(10, 6))

# # 각 연령대별로 막대 그래프 그리기
# income = income_by_age_group.plot(kind='bar', stacked=True)

# '''
# # 각 연령대별 소득구간 합산 계산
# income_by_age_group_sum = income_by_age_group.sum(axis=1)

# # 연령대별 소득구간 비율 계산
# income_by_age_group_ratio = income_by_age_group.div(income_by_age_group_sum, axis=0)
# '''

# # 그래프 제목 및 축 레이블 설정 (한글 폰트 적용)
# plt.title('연령대별 소득구간 분포')
# plt.xlabel('연령대')
# plt.ylabel('인원 수')

# # x축 레이블 1로 설정하여 출력
# plt.xticks(rotation=1)

# # 범례 표시
# plt.legend(title='소득구간코드', bbox_to_anchor=(1.05, 1), loc='upper left')

# # 그래프 출력
# plt.tight_layout()
# plt.show()

# ## 에러문구 없애기
# warnings.filterwarnings('ignore')
# pd.options.display.float_format = '{:.8f}'.format

# %%
import matplotlib as mpl

print(mpl.matplotlib_fname())
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
print(mpl.get_cachedir())
# Out:
# C:\Users\USER\.matplotlib

# %%
from IPython.core.display import HTML
import matplotlib
from matplotlib import font_manager
import shutil

# %%
print(f'캐시 디렉토리: {matplotlib.get_cachedir()}')
shutil.rmtree(matplotlib.get_cachedir())
# Out:
# 캐시 디렉토리: C:\Users\USER\.matplotlib

# %%
sorted([font.name for font in fm.fontManager.ttflist])
# Out:
# ['Agency FB',
#  'Agency FB',
#  'Algerian',
#  'Ami R',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial Rounded MT Bold',
#  'Arial Unicode MS',
#  'Bahnschrift',
#  'Baskerville Old Face',
#  'Batang',
#  'Bauhaus 93',
#  'Bell MT',
#  'Bell MT',
#  'Bell MT',
#  'Berlin Sans FB',
#  'Berlin Sans FB',
#  'Berlin Sans FB Demi',
#  'Bernard MT Condensed',
#  'Blackadder ITC',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookshelf Symbol 7',
#  'Bradley Hand ITC',
#  'Britannic Bold',
#  'Broadway',
#  'Brush Script MT',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
# ...

# %%
# def make_html(fontname):
#     return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

# code = "\n".join([make_html(font) for font in sorted(set([f.name for f in fm.fontManager.ttflist]))])

# HTML("<div style='column-count: 2;'>{}</div>".format(code))

# %%
# Font 디렉토리 목록을 출력합니다.
font_dirs = font_manager.OSXFontDirectories
font_dirs
# Out:
# ['/Library/Fonts/',
#  '/Network/Library/Fonts/',
#  '/System/Library/Fonts/',
#  '/opt/local/share/fonts',
#  'C:\\Users\\USER\\Library\\Fonts']

# %%
# 각 디렉토리를 확인하여 설치하고자 하는 폰트의 경로 확인
for idx, f_dir in enumerate(font_dirs):
    print(f'==='*10)
    print(f'인덱스 [{idx}] \t위치: {f_dir}')
    font_list = font_manager.findSystemFonts(fontpaths=f_dir, fontext='ttf')
    print(sorted(font_list))
    print(f'==='*10)
# Out:
# ...
# 인덱스 [0] 	위치: /Library/Fonts/
# []
# ...
# 인덱스 [1] 	위치: /Network/Library/Fonts/
# []
# ...
# 인덱스 [2] 	위치: /System/Library/Fonts/
# []
# ...
# 인덱스 [3] 	위치: /opt/local/share/fonts
# []
# ...
# 인덱스 [4] 	위치: C:\Users\USER\Library\Fonts
# []
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
# 시각화 설정
plt.figure(figsize=(10, 6))

# 각 연령대별로 막대 그래프 그리기
income = income_by_age_group.plot(kind='bar', stacked=True)

'''
# 각 연령대별 소득구간 합산 계산
income_by_age_group_sum = income_by_age_group.sum(axis=1)

# 연령대별 소득구간 비율 계산
income_by_age_group_ratio = income_by_age_group.div(income_by_age_group_sum, axis=0)
'''

# 그래프 제목 및 축 레이블 설정 (한글 폰트 적용)
plt.title('연령대별 소득구간 분포')
plt.xlabel('연령대')
plt.ylabel('인원 수')

# x축 레이블 1로 설정하여 출력
plt.xticks(rotation=1)

# 범례 표시
plt.legend(title='소득구간코드', bbox_to_anchor=(1.05, 1), loc='upper left')

# 그래프 출력
plt.tight_layout()
plt.show()

## 에러문구 없애기
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:.8f}'.format

# %%
import matplotlib.pyplot as plt

# '기타'로 묶인 항목들의 소비 데이터 추출
주거수도광열비 = dat_2019[['주거수도광열_실제주거비구입','주거수도광열_주택유지수선구입','주거수도광열_상하수도폐기물처리','주거수도광열_기타주거관련서비스구입','주거수도광열_연료비구입']]

# 카테고리 별 소비 합계 계산
주거수도광열비_소비합계 = 주거수도광열비.sum()

# 데이터를 정렬하여 분위수 계산
sort_dat = np.sort(주거수도광열비_소비합계.values)
quartile = np.percentile(sort_dat, [25, 50, 75])  # 4분위수 계산

# 바 그래프 그리기
plt.bar(주거수도광열비_소비합계.index, 주거수도광열비_소비합계.values)
plt.title('주거수도광열비 소비')
plt.xlabel('카테고리')
plt.ylabel('소비 금액')
plt.xticks(rotation=90)

# 사분위수 기준 선 그리기
for q in quartile:
    plt.axhline(y=q, color='r', linestyle='--')

plt.show()

# %%
import matplotlib.pyplot as plt

# '기타'로 묶인 항목들의 소비 데이터 추출
가정용품가사서비스이용 = dat_2019[['가정용품가사서비스_가구조명구입','가정용품가사서비스_실내장식구입','가정용품가사서비스_가구조명장식서비스이용','가정용품가사서비스_가정용섬유구입','가정용품가사서비스_가전가정용기기구입','가정용품가사서비스_가전관련서비스이용','가정용품가사서비스_가사용품구입','가정용품가사서비스_가정용공구기타구입','가정용품가사서비스_가사소모품구입']]

# 카테고리 별 소비 합계 계산
가정용품가사서비스이용_소비합계 = 가정용품가사서비스이용.sum()

# 데이터를 정렬하여 분위수 계산
sort_dat = np.sort(가정용품가사서비스이용_소비합계.values)
quartile = np.percentile(sort_dat, [25, 50, 75])  # 4분위수 계산

# 바 그래프 그리기
plt.bar(가정용품가사서비스이용_소비합계.index, 가정용품가사서비스이용_소비합계.values)
plt.title('주가정용품가사서비스이용 소비')
plt.xlabel('카테고리')
plt.ylabel('소비 금액')
plt.xticks(rotation=90)

# 사분위수 기준 선 그리기
for q in quartile:
    plt.axhline(y=q, color='r', linestyle='--')

plt.show()

# %%
import matplotlib.pyplot as plt

# '기타'로 묶인 항목들의 소비 데이터 추출
보건제품구입 = dat_2019[['보건_의약품구입','보건_의료용소모품구입','보건_보건의료용품기구구입','보건_외래의료서비스이용','보건_치과서비스이용','보건_기타의료서비스이용','보건_입원서비스이용']]

# 카테고리 별 소비 합계 계산
보건제품구입_소비합계 = 보건제품구입.sum()

# 데이터를 정렬하여 분위수 계산
sort_dat = np.sort(보건제품구입_소비합계.values)
quartile = np.percentile(sort_dat, [25, 50, 75])  # 4분위수 계산

# 바 그래프 그리기
plt.bar(보건제품구입_소비합계.index, 보건제품구입_소비합계.values)
plt.title('보건 소비')
plt.xlabel('카테고리')
plt.ylabel('소비 금액')
plt.xticks(rotation=90)

# 사분위수 기준 선 그리기
for q in quartile:
    plt.axhline(y=q, color='r', linestyle='--')

plt.show()

# %%
# 연령대별로 주거수도광열비 소비 추출
연령대별_주거수도광열비 = dat_2019.groupby('연령대')[['주거수도광열_실제주거비구입','주거수도광열_주택유지수선구입','주거수도광열_상하수도폐기물처리','주거수도광열_기타주거관련서비스구입','주거수도광열_연료비구입']].sum()

# 바 그래프 그리기
연령대별_주거수도광열비.plot(kind='bar', stacked=True)
plt.title('연령대별_주거수도광열비')
plt.xlabel('연령대')
plt.ylabel('소비 금액')
plt.xticks(rotation=45)
plt.legend(title='카테고리', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# 각 연령대별로 소비가 높은 순서대로 품목 출력

for 연령대, 소비품목 in 연령대별_주거수도광열비.iterrows():
    # 소비가 높은 순으로 정렬
    sort_data = 소비품목.sort_values(ascending=False)
    print(f"{연령대}의 기타소비 순위:")
    for 순위, (품목, 금액) in enumerate(sort_data.items(), start=1):
        print(f"{순위}. {품목}: {금액}")
    print()
# Out:
# 10대의 기타소비 순위:
# 1. 주거수도광열_실제주거비구입: 4428179
# 2. 주거수도광열_연료비구입: 399286
# 3. 주거수도광열_기타주거관련서비스구입: 382871
# 4. 주거수도광열_상하수도폐기물처리: 81799
# 5. 주거수도광열_주택유지수선구입: 667
#
# 20대의 기타소비 순위:
# 1. 주거수도광열_실제주거비구입: 114753909
# 2. 주거수도광열_연료비구입: 22590647
# 3. 주거수도광열_기타주거관련서비스구입: 17312501
# 4. 주거수도광열_상하수도폐기물처리: 5248017
# 5. 주거수도광열_주택유지수선구입: 858550
#
# 30대의 기타소비 순위:
# 1. 주거수도광열_실제주거비구입: 135386941
# 2. 주거수도광열_연료비구입: 85892737
# 3. 주거수도광열_기타주거관련서비스구입: 69615701
# 4. 주거수도광열_상하수도폐기물처리: 24617471
# 5. 주거수도광열_주택유지수선구입: 23059772
#
# 40대의 기타소비 순위:
# 1. 주거수도광열_실제주거비구입: 169276835
# 2. 주거수도광열_연료비구입: 155042610
# 3. 주거수도광열_기타주거관련서비스구입: 113103510
# 4. 주거수도광열_상하수도폐기물처리: 43675427
# 5. 주거수도광열_주택유지수선구입: 41805715
#
# 50대의 기타소비 순위:
# 1. 주거수도광열_실제주거비구입: 207177796
# 2. 주거수도광열_연료비구입: 192855074
# 3. 주거수도광열_기타주거관련서비스구입: 115944354
# 4. 주거수도광열_주택유지수선구입: 74856954
# 5. 주거수도광열_상하수도폐기물처리: 47426426
#
# 60대의 기타소비 순위:
# 1. 주거수도광열_연료비구입: 160670676
# 2. 주거수도광열_실제주거비구입: 109416425
# 3. 주거수도광열_주택유지수선구입: 72786071
# 4. 주거수도광열_기타주거관련서비스구입: 72072076
# ...

# %%
# 연령대별로 가정용품가사서비스이용 소비 추출
연령대별_가정용품가사서비스이용 = dat_2019.groupby('연령대')[['가정용품가사서비스_가구조명구입','가정용품가사서비스_실내장식구입','가정용품가사서비스_가구조명장식서비스이용','가정용품가사서비스_가정용섬유구입','가정용품가사서비스_가전가정용기기구입','가정용품가사서비스_가전관련서비스이용','가정용품가사서비스_가사용품구입','가정용품가사서비스_가정용공구기타구입','가정용품가사서비스_가사소모품구입']].sum()

# 바 그래프 그리기
연령대별_가정용품가사서비스이용.plot(kind='bar', stacked=True)
plt.title('연령대별_가정용품가사서비스이용')
plt.xlabel('연령대')
plt.ylabel('소비 금액')
plt.xticks(rotation=45)
plt.legend(title='카테고리', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# 각 연령대별로 소비가 높은 순서대로 품목 출력

for 연령대, 소비품목 in 연령대별_가정용품가사서비스이용.iterrows():
    # 소비가 높은 순으로 정렬
    sort_data = 소비품목.sort_values(ascending=False)
    print(f"{연령대}의 기타소비 순위:")
    for 순위, (품목, 금액) in enumerate(sort_data.items(), start=1):
        print(f"{순위}. {품목}: {금액}")
    print()
# Out:
# 10대의 기타소비 순위:
# 1. 가정용품가사서비스_가전가정용기기구입: 398317
# 2. 가정용품가사서비스_가구조명구입: 172775
# 3. 가정용품가사서비스_가정용섬유구입: 126915
# 4. 가정용품가사서비스_가사소모품구입: 106420
# 5. 가정용품가사서비스_가사용품구입: 85759
# 6. 가정용품가사서비스_실내장식구입: 34727
# 7. 가정용품가사서비스_가정용공구기타구입: 18467
# 8. 가정용품가사서비스_가구조명장식서비스이용: 0
# 9. 가정용품가사서비스_가전관련서비스이용: 0
#
# 20대의 기타소비 순위:
# 1. 가정용품가사서비스_가전가정용기기구입: 9121870
# 2. 가정용품가사서비스_가구조명구입: 5467123
# 3. 가정용품가사서비스_가사소모품구입: 4893853
# 4. 가정용품가사서비스_가정용섬유구입: 3717080
# 5. 가정용품가사서비스_가사용품구입: 2344846
# 6. 가정용품가사서비스_가전관련서비스이용: 1716912
# 7. 가정용품가사서비스_가정용공구기타구입: 1312806
# 8. 가정용품가사서비스_실내장식구입: 666066
# 9. 가정용품가사서비스_가구조명장식서비스이용: 216852
#
# 30대의 기타소비 순위:
# 1. 가정용품가사서비스_가전가정용기기구입: 62540800
# 2. 가정용품가사서비스_가구조명구입: 42662676
# 3. 가정용품가사서비스_가사소모품구입: 19763064
# 4. 가정용품가사서비스_가전관련서비스이용: 17310760
# 5. 가정용품가사서비스_가정용섬유구입: 14512693
# 6. 가정용품가사서비스_가사용품구입: 12944030
# 7. 가정용품가사서비스_가정용공구기타구입: 6457712
# 8. 가정용품가사서비스_실내장식구입: 4175318
# 9. 가정용품가사서비스_가구조명장식서비스이용: 1404958
#
# 40대의 기타소비 순위:
# 1. 가정용품가사서비스_가전가정용기기구입: 99237415
# ...

# %%
# 연령대별로 보건제품구입 소비 추출
연령대별_보건제품구입 = dat_2019.groupby('연령대')[['보건_의약품구입','보건_의료용소모품구입','보건_보건의료용품기구구입','보건_외래의료서비스이용','보건_치과서비스이용','보건_기타의료서비스이용','보건_입원서비스이용']].sum()

# 바 그래프 그리기
연령대별_보건제품구입.plot(kind='bar', stacked=True)
plt.title('연령대별_보건제품구입')
plt.xlabel('연령대')
plt.ylabel('소비 금액')
plt.xticks(rotation=45)
plt.legend(title='카테고리', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# 각 연령대별로 소비가 높은 순서대로 품목 출력

for 연령대, 소비품목 in 연령대별_보건제품구입.iterrows():
    # 소비가 높은 순으로 정렬
    sort_data = 소비품목.sort_values(ascending=False)
    print(f"{연령대}의 기타소비 순위:")
    for 순위, (품목, 금액) in enumerate(sort_data.items(), start=1):
        print(f"{순위}. {품목}: {금액}")
    print()
# Out:
# 10대의 기타소비 순위:
# 1. 보건_외래의료서비스이용: 83408
# 2. 보건_의약품구입: 75362
# 3. 보건_보건의료용품기구구입: 44084
# 4. 보건_의료용소모품구입: 36634
# 5. 보건_치과서비스이용: 0
# 6. 보건_기타의료서비스이용: 0
# 7. 보건_입원서비스이용: 0
#
# 20대의 기타소비 순위:
# 1. 보건_외래의료서비스이용: 17801870
# 2. 보건_의약품구입: 9763355
# 3. 보건_입원서비스이용: 4737107
# 4. 보건_치과서비스이용: 3950949
# 5. 보건_보건의료용품기구구입: 3849620
# 6. 보건_의료용소모품구입: 3083566
# 7. 보건_기타의료서비스이용: 202856
#
# 30대의 기타소비 순위:
# 1. 보건_외래의료서비스이용: 69867593
# 2. 보건_의약품구입: 51816241
# 3. 보건_치과서비스이용: 30329344
# 4. 보건_입원서비스이용: 26863680
# 5. 보건_의료용소모품구입: 17400863
# 6. 보건_보건의료용품기구구입: 12668318
# 7. 보건_기타의료서비스이용: 5588950
#
# 40대의 기타소비 순위:
# 1. 보건_외래의료서비스이용: 121352990
# 2. 보건_의약품구입: 84052765
# 3. 보건_치과서비스이용: 58035592
# 4. 보건_입원서비스이용: 40099760
# 5. 보건_보건의료용품기구구입: 26963515
# 6. 보건_의료용소모품구입: 13056064
# 7. 보건_기타의료서비스이용: 5430901
#
# 50대의 기타소비 순위:
# 1. 보건_외래의료서비스이용: 148869852
# 2. 보건_의약품구입: 126167976
# 3. 보건_입원서비스이용: 113843239
# 4. 보건_치과서비스이용: 63127552
# 5. 보건_보건의료용품기구구입: 24457658
# 6. 보건_의료용소모품구입: 8386050
# 7. 보건_기타의료서비스이용: 6067888
#
# ...
