# %%
# 조건으로 검색하기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat = pd.read_csv("./data/2019_1인가구.csv", encoding='cp949') ; dat
dat_2019 = dat.copy()

# %%
## [데이터 필요한 행만 전처리]

dat_2019.rename(columns={
    '가계지출금액' : '전체소비지출','가계지출_소비지출금액' : '소비지출','가계지출_소비지출_식료품비주류음료구입비' : '식료품음료구입',
    '가계지출_소비지출_식료품비주류음료_곡물구입비' : '식료품_곡물구입','가계지출_소비지출_식료품비주류음료_곡물가공품구입비' : '식료품_곡물가공품구입',
    '가계지출_소비지출_식료품비주류음료_빵떡류구입비' : '식료품_빵떡류구입','가계지출_소비지출_식료품비주류음료_육류구입비' : '식료품_육류구입',
    '가계지출_소비지출_식료품비주류음료_육류가공품구입비' : '식료품_육류가공품구입','가계지출_소비지출_식료품비주류음료_신선수산동물구입비' : '식료품_신선수산동물구입',
    '가계지출_소비지출_식료품비주류음료_염건수산동물구입비' : '식료품_염건수산동물구입','가계지출_소비지출_식료품비주류음료_기타수산동물가공구입비' : '식료품_기타수산동물가공구입',
    '가계지출_소비지출_식료품비주류음료_유제품및알구입비' : '식료품_유제품알구입','가계지출_소비지출_식료품비주류음료_유지류구입비' : '식료품_유지류구입',
    '가계지출_소비지출_식료품비주류음료_과일가공품구입비' : '식료품_과일가공품구입','가계지출_소비지출_식료품비주류음료_채소가공품구입비' : '식료품_채소가공품구입',
    '가계지출_소비지출_식료품비주류음료_해조가공품구입비' : '식료품_해조가공품구입','가계지출_소비지출_식료품비주류음료_당류과자류구입비' : '식료품_당류과자류구입',
    '가계지출_소비지출_식료품비주류음료_조미식품구입비' : '식료품_조미식품구입','가계지출_소비지출_식료품비주류음료_기타식품구입비' : '식료품_기타식품구입',
    '가계지출_소비지출_식료품비주류음료_커피차구입비' : '식료품_커피차구입','가계지출_소비지출_식료품비주류음료_쥬스기타음료구입비' : '식료품_쥬스음료구입',
    '가계지출_소비지출_주류담배구입비' : '주류담배구입','가계지출_소비지출_주류담배_주류구입비' : '주류구입','가계지출_소비지출_주류담배_담배구입비' : '담배구입',
    '가계지출_소비지출_의류신발구입비' : '의류신발구입','가계지출_소비지출_의류신발_직물및외의구입비' : '의류신발_직물및외의구입','가계지출_소비지출_의류신발_내의구입비' : '의류신발_내의구입',
    '가계지출_소비지출_의류신발_기타의복구입비' : '의류신발_기타의복구입','가계지출_소비지출_의류신발_의복관련서비스구입비' : '의류신발_의복관련서비스구입',
    '가계지출_소비지출_의류신발_신발구입비' : '의류신발_신발구입','가계지출_소비지출_의류신발_신발서비스구입비' : '의류신발_신발서비스구입','가계지출_소비지출_주거수도광열비' : '주거수도광열비',
    '가계지출_소비지출_주거수도광열_실제주거비구입비' : '주거수도광열_실제주거비구입','가계지출_소비지출_주거수도광열_주택유지수선구입비' : '주거수도광열_주택유지수선구입',
    '가계지출_소비지출_주거수도광열_상하수도폐기물처리비' : '주거수도광열_상하수도폐기물처리','가계지출_소비지출_주거수도광열_기타주거관련서비스구입비' : '주거수도광열_기타주거관련서비스구입',
    '가계지출_소비지출_주거수도광열_연료비구입비' : '주거수도광열_연료비구입','가계지출_소비지출_가정용품가사서비스이용금액' : '가정용품가사서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가구조명구입비' : '가정용품가사서비스_가구조명구입','가계지출_소비지출_가정용품가사서비스_실내장식구입비' : '가정용품가사서비스_실내장식구입',
    '가계지출_소비지출_가정용품가사서비스_가구조명장식서비스이용금액' : '가정용품가사서비스_가구조명장식서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가정용섬유구입비' : '가정용품가사서비스_가정용섬유구입','가계지출_소비지출_가정용품가사서비스_가전가정용기기구입비' : '가정용품가사서비스_가전가정용기기구입',
    '가계지출_소비지출_가정용품가사서비스_가전관련서비스이용금액' : '가정용품가사서비스_가전관련서비스이용','가계지출_소비지출_가정용품가사서비스_가사용품구입비' : '가정용품가사서비스_가사용품구입',
    '가계지출_소비지출_가정용품가사서비스_가정용공구기타구입비' : '가정용품가사서비스_가정용공구기타구입','가계지출_소비지출_가정용품가사서비스_가사소모품구입비' : '가정용품가사서비스_가사소모품구입',
    '가계지출_소비지출_가정용품가사서비스_가사서비스금액' : '가정용품가사서비스_가사서비스','가계지출_소비지출_보건제품구입비' : '보건제품구입',
    '가계지출_소비지출_보건_의약품구입비' : '보건_의약품구입','가계지출_소비지출_보건_의료용소모품구입비' : '보건_의료용소모품구입',
    '가계지출_소비지출_보건_보건의료용품기구구입비' : '보건_보건의료용품기구구입','가계지출_소비지출_보건_외래의료서비스이용금액' : '보건_외래의료서비스이용',
    '가계지출_소비지출_보건_치과서비스이용금액' : '보건_치과서비스이용','가계지출_소비지출_보건_기타의료서비스이용금액' : '보건_기타의료서비스이용',
    '가계지출_소비지출_보건_입원서비스이용금액' : '보건_입원서비스이용','가계지출_소비지출_교통비' : '교통비','가계지출_소비지출_교통_자동차구입비' : '교통_자동차구입',
    '가계지출_소비지출_교통_기타운송기구구입비' : '교통_기타운송기구구입','가계지출_소비지출_교통_운송기구유지수리비' : '교통_운송기구유지수리',
    '가계지출_소비지출_교통_운송기구연료비' : '교통_운송기구연료','가계지출_소비지출_교통_기타개인교통서비스이용금액' : '교통_기타개인교통서비스이용',
    '가계지출_소비지출_교통_철도운송금액' : '교통_철도운송','가계지출_소비지출_교통_육상운송금액' : '교통_육상운송','가계지출_소비지출_교통_기타운송금액' : '교통_기타운송',
    '가계지출_소비지출_교통_기타교통관련서비스이용금액' : '교통_기타교통관련서비스이용','가계지출_소비지출_통신비' : '통신비','가계지출_소비지출_통신_우편서비스이용금액' : '통신_우편서비스이용',
    '가계지출_소비지출_통신_통신장비구입비' : '통신_통신장비구입','가계지출_소비지출_통신_통신서비스이용금액' : '통신_통신서비스이용','가계지출_소비지출_오락문화비' : '오락문화비',
    '가계지출_소비지출_오락문화_영상음향기기구입비' : '오락문화_영상음향기기구입','가계지출_소비지출_오락문화_사진광학장비구입비' : '오락문화_사진광학장비구입',
    '가계지출_소비지출_오락문화_정보처리장치구입비' : '오락문화_정보처리장치구입','가계지출_소비지출_오락문화_기록매체구입비' : '오락문화_기록매체구입',
    '가계지출_소비지출_오락문화_영상음향정보기기수리비' : '오락문화_영상음향정보기기수리','가계지출_소비지출_오락문화_내구재구입비' : '오락문화_내구재구입',
    '가계지출_소비지출_오락문화_악기기구구입비' : '오락문화_악기기구구입','가계지출_소비지출_오락문화_오락문화내구재유지수리비' : '오락문화_오락문화내구재유지수리',
    '가계지출_소비지출_오락문화_장난감취미용품구입비' : '오락문화_장난감취미용품구입','가계지출_소비지출_오락문화_캠핑운동관련용품구입비' : '오락문화_캠핑운동관련용품구입',
    '가계지출_소비지출_오락문화_화훼관련용품구입비' : '오락문화_화훼관련용품구입','가계지출_소비지출_오락문화_애완동물관련물품구입비' : '애완동물_물품구입',
    '가계지출_소비지출_오락문화_화훼애완동물서비스이용금액' : '애완동물_서비스이용','가계지출_소비지출_오락문화_운동오락서비스이용금액' : '운동오락_서비스이용',
    '가계지출_소비지출_오락문화_문화서비스이용금액' : '문화_서비스이용','가계지출_소비지출_오락문화_복권구입비' : '복권_구입비','가계지출_소비지출_오락문화_서적구입비' : '서적_구입비',
    '가계지출_소비지출_오락문화_기타인쇄물구입비' : '인쇄물_구입비','가계지출_소비지출_오락문화_문구구입비' : '문구_구입비','가계지출_소비지출_오락문화_단체여행경비' : '단체여행_경비',
    '가계지출_소비지출_교육비' : '교육비','가계지출_소비지출_교육_정규교육비' : '정규교육비','가계지출_소비지출_교육_초등교육비' : '초등교육비','가계지출_소비지출_교육_중등교육비' : '중등교육비',
    '가계지출_소비지출_교육_고등교육비' : '고등교육비','가계지출_소비지출_교육_학원보습교육비' : '학원보습교육비','가계지출_소비지출_교육_학생학원교육비' : '학생학원교육비',
    '가계지출_소비지출_교육_성인학원비' : '성인학원비','가계지출_소비지출_교육_기타교육비' : '기타교육비','가계지출_소비지출_음식숙박비' : '음식숙박비','가계지출_소비지출_음식숙박_식대' : '식대',
    '가계지출_소비지출_음식숙박_숙박비' : '숙박비','가계지출_소비지출_기타상품서비스이용금액' : '기타상품서비스이용','가계지출_소비지출_기타상품서비스_이미용서비스이용금액' : '이미용서비스이용',
    '가계지출_소비지출_기타상품서비스_이미용기기구입비' : '이미용기기구입','가계지출_소비지출_기타상품서비스_위생이미용용품구입비' : '위생이미용용품구입',
    '가계지출_소비지출_기타상품서비스_시계장신구구입비' : '시계장신구구입','가계지출_소비지출_기타상품서비스_기타개인용품구입비' : '기타개인용품구입',
    '가계지출_소비지출_기타상품서비스_복지시설비용금액' : '복지시설비용','가계지출_소비지출_기타상품서비스_보험료' : '보험료','가계지출_소비지출_기타상품서비스_기타금융구입비' : '기타금융구입',
    '가계지출_소비지출_기타상품서비스_기타서비스금액구입비' : '기타서비스금액구입','가계지출_비소비지출금액' : '비소비지출금액','가계지출_비소비지출_경상조세' : '비경상조세',
    '가계지출_비소비지출_비경상조세' : '비경상조세','가계지출_비소비지출_연금기여금' : '연금기여금','가계지출_비소비지출_사회보장구입비' : '사회보장구입비',
    '가계지출_비소비지출_이자비용' : '이자비용','가계지출_비소비지출_가구간이전지출금액' : '가구간이전지출금액','가계지출_비소비지출_비영리단체이전지출금액' : '비영리단체이전지출금액'
}, inplace=True
)

# %%
dat_2019.columns
# Out:
# Index(['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드',
#        '가구주_성별코드', '가구주_연령', '가구주_취업여부',
#        ...
#        '기타서비스금액구입', '비소비지출금액', '비경상조세', '비경상조세', '연금기여금', '사회보장구입비', '이자비용',
#        '가구간이전지출금액', '비영리단체이전지출금액', '도시읍면부구분코드'],
#       dtype='object', length=139)

# %%
# 행 전처리

dat_2019 = dat_2019[['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드', '가구주_성별코드', '가구주_연령', '가구주_취업여부', '거처구분코드',
                     '자동차보유대수','입주형태코드', '월세평가금액', '전세보증금', '소득구간코드', '전체소비지출', '소비지출','식료품음료구입','식료품_곡물구입',
                     '식료품_곡물가공품구입','식료품_빵떡류구입','식료품_육류구입','식료품_육류가공품구입','식료품_신선수산동물구입','식료품_염건수산동물구입','식료품_기타수산동물가공구입',
                     '식료품_유제품알구입','식료품_유지류구입','식료품_과일가공품구입','식료품_채소가공품구입','식료품_해조가공품구입','식료품_당류과자류구입','식료품_조미식품구입',
                     '식료품_기타식품구입','식료품_커피차구입','식료품_쥬스음료구입','주류담배구입','주류구입','담배구입','의류신발구입','의류신발_직물및외의구입','의류신발_내의구입',
                     '의류신발_기타의복구입','의류신발_의복관련서비스구입','의류신발_신발구입','의류신발_신발서비스구입','주거수도광열비','주거수도광열_실제주거비구입',
                     '주거수도광열_주택유지수선구입','주거수도광열_상하수도폐기물처리','주거수도광열_기타주거관련서비스구입','주거수도광열_연료비구입','가정용품가사서비스이용',
                     '가정용품가사서비스_가구조명구입','가정용품가사서비스_실내장식구입','가정용품가사서비스_가구조명장식서비스이용','가정용품가사서비스_가정용섬유구입',
                     '가정용품가사서비스_가전가정용기기구입','가정용품가사서비스_가전관련서비스이용','가정용품가사서비스_가사용품구입','가정용품가사서비스_가정용공구기타구입',
                     '가정용품가사서비스_가사소모품구입','가정용품가사서비스_가사서비스','보건제품구입','보건_의약품구입','보건_의료용소모품구입','보건_보건의료용품기구구입',
                     '보건_외래의료서비스이용','보건_치과서비스이용','보건_기타의료서비스이용','보건_입원서비스이용','교통비','교통_자동차구입','교통_기타운송기구구입','교통_운송기구유지수리',
                     '교통_운송기구연료','교통_기타개인교통서비스이용','교통_철도운송','교통_육상운송','교통_기타운송','교통_기타교통관련서비스이용','통신비','통신_우편서비스이용',
                     '통신_통신장비구입','통신_통신서비스이용','오락문화비','오락문화_영상음향기기구입','오락문화_사진광학장비구입','오락문화_정보처리장치구입','오락문화_기록매체구입',
                     '오락문화_영상음향정보기기수리','오락문화_내구재구입','오락문화_악기기구구입','오락문화_오락문화내구재유지수리','오락문화_장난감취미용품구입','오락문화_캠핑운동관련용품구입',
                     '오락문화_화훼관련용품구입','애완동물_물품구입','애완동물_서비스이용','운동오락_서비스이용','문화_서비스이용','복권_구입비','서적_구입비','인쇄물_구입비','문구_구입비',
                     '단체여행_경비','교육비','정규교육비','초등교육비','중등교육비','고등교육비','학원보습교육비','학생학원교육비','성인학원비','기타교육비','음식숙박비','식대','숙박비',
                     '기타상품서비스이용','이미용서비스이용','이미용기기구입','위생이미용용품구입','시계장신구구입','기타개인용품구입','복지시설비용','보험료','기타금융구입','기타서비스금액구입',
                     '비소비지출금액','비경상조세','비경상조세','연금기여금','사회보장구입비','이자비용','가구간이전지출금액','비영리단체이전지출금액']]

# %%
dat_2019['가구구분코드'] = dat_2019['가구구분코드'].replace({1: '근로자 가구', 2: '비근로자 가구'})
dat_2019['노인가구여부'] = dat_2019['노인가구여부'].replace({0: '아니요', 1: '예'})
dat_2019['배우자코드'] = dat_2019['배우자코드'].replace({1: '현재(동거)', 2: '현재(비동거)', 3:'부재'})
dat_2019['가구주_성별코드'] = dat_2019['가구주_성별코드'].replace({1: '남성', 2: '여성'})
dat_2019['가구주_취업여부'] = dat_2019['가구주_취업여부'].replace({1: '취업', 2: '실업자'})
dat_2019['거처구분코드'] = dat_2019['거처구분코드'].replace({1: '단독주택(다세대 포함)', 2: '아파트', 3: '연립주택', 4: '다가구주택', 5: '비주거용 건물', 6: '오피스텔', 7: '기타'})
dat_2019['입주형태코드'] = dat_2019['입주형태코드'].replace({1: '내 집', 2: '무료주택', 3: '회사주택', 4: '임대', 5: '영구임대', 6: '보증금 월세', 7: '보증금 없는 월세'})
dat_2019['소득구간코드'] = dat_2019['소득구간코드'].replace({1: '100만원 미만', 2: '100~200만원', 3: '200~300만원', 4: '300~400만원', 5: '400~500만원', 6: '500~600만원', 7: '600~700만원', 8: '700만원 이상'})
# dat_2019['도시읍면부구분코드'] = dat_2019['도시읍면부구분코드'].replace({0: '비도시', 1: '도시'})

# %%
dat_2019
# Out:
#         조사연월  가구일련번호   가구구분코드  가구원수  취업인원수 노인가구여부    배우자코드 가구주_성별코드  가구주_연령  \
# 0     201900       1  비근로자 가구     1      0    아니요  현재(비동거)       여성      64
# 1     201900       2   근로자 가구     3      2    아니요   현재(동거)       남성      63
# 2     201900       3  비근로자 가구     1      0    아니요       부재       남성      58
# 3     201900       4   근로자 가구     3      2    아니요   현재(동거)       남성      29
# 4     201900       5   근로자 가구     1      1    아니요       부재       여성      58
# ...      ...     ...      ...   ...    ...    ...      ...      ...     ...
# 9505  201900    9506  비근로자 가구     4      2    아니요   현재(동거)       남성      37
# 9506  201900    9507  비근로자 가구     4      3    아니요   현재(동거)       남성      59
# 9507  201900    9508  비근로자 가구     5      3    아니요   현재(동거)       남성      60
# 9508  201900    9509   근로자 가구     1      1    아니요       부재       남성      63
# 9509  201900    9510  비근로자 가구     2      2      예   현재(동거)       남성      78
#
# ...

# %%
def age(가구주_연령):
    if 가구주_연령 < 20:
        return '10대'
    elif 20 <= 가구주_연령 < 30:
        return '20대'
    elif 30 <= 가구주_연령 < 40:
        return '30대'
    elif 40 <= 가구주_연령 < 50:
        return '40대'
    elif 50 <= 가구주_연령 < 60:
        return '50대'
    elif 60 <= 가구주_연령 < 70:
        return '60대'
    elif 70 <= 가구주_연령:
        return '70대 이상'

# 데이터 연령대별 구분
dat_2019.loc[:,'연령대'] = dat_2019['가구주_연령'].apply(age)
dat_2019.연령대
# Out:
# 0          60대
# 1          60대
# 2          50대
# 3          20대
# 4          50대
#          ...
# 9505       30대
# 9506       50대
# 9507       60대
# 9508       60대
# 9509    70대 이상
# Name: 연령대, Length: 9510, dtype: object

# %%
# 연령대별 가구원 수 분포
dat_2019.groupby('연령대')['가구원수'].value_counts().unstack().fillna(0).astype(int)
# Out:
# 가구원수      1    2    3    4    5   6  7  8
# 연령대
# 10대      17    1    0    0    0   0  0  0
# 20대     389   80   39    9    1   2  0  0
# 30대     286  219  291  290   56   5  1  0
# 40대     284  298  431  570  144  21  3  0
# 50대     474  776  570  323   53   8  0  1
# 60대     550  982  318   70   16   6  0  0
# 70대 이상  827  954  115   22    7   1  0  0

# %% [markdown]
# ##### 전체가구 지출 (total_expend) | 1인가구 지출 (single_expend )

# %% [markdown]
# 전체가구 소비지출

# %% [markdown]
# box plot 그려서 분포 확인해봐야 함

# %%
total_expend_2019 = dat_2019['소비지출']

total_expend_2019.info # 전체가구 소비지출
# Out:
# <bound method Series.info of 0        451464
# 1       1468101
# 2       1358773
# 3       1166942
# 4       5875488
#          ...
# 9505    3133653
# 9506    2995655
# 9507    5863909
# 9508    1788251
# 9509    1102741
# Name: 소비지출, Length: 9510, dtype: int64>

# %% [markdown]
# --2차 전처리--
#
# 전체가구 소비지출 이상치확인 (9,510개중 6,730개) <2,780개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(total_expend_2019, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(total_expend_2019, 25)
Q3 = np.percentile(total_expend_2019, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(total_expend_2019), f'Median: {np.median(total_expend_2019):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(total_expend_2019):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(total_expend_2019):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('전체가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_total_expend_2019 = ((total_expend_2019 >= lower_limit) & (total_expend_2019 <= upper_limit))
total_expend_2019[cleaned_total_expend_2019]
# Out:
# 0        451464
# 1       1468101
# 2       1358773
# 3       1166942
# 5       1180308
#          ...
# 9504     694386
# 9505    3133653
# 9506    2995655
# 9508    1788251
# 9509    1102741
# Name: 소비지출, Length: 9115, dtype: int64

# %%
# 이상치 제거
cleaned_total_expend_2019 = total_expend_2019[(total_expend_2019 >= lower_limit) & (total_expend_2019 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_total_expend_2019, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_total_expend_2019, 25)
Q3 = np.percentile(cleaned_total_expend_2019, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_total_expend_2019), f'Median: {np.median(cleaned_total_expend_2019):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_total_expend_2019):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_total_expend_2019):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('전체가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 전체가구 평균 소비지출
total_expend_mean_2019 = int(total_expend_2019.mean())
print(f"전체가구의 평균 소비지출: {total_expend_mean_2019:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,294,545원

# %%
# 전체가구 평균 소비지출 이상치 제거 후
cleaned_total_expend_mean_2019 = int(cleaned_total_expend_2019.mean())
print(f"전체가구의 평균 소비지출: {cleaned_total_expend_mean_2019:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,042,441원

# %% [markdown]
# 1인가구 소비지출

# %%
# 가구원수 1로 설정하여 9510개에서 2827개의 데이터 전처리

single_expend_2019 = dat_2019.loc[dat['가구원수'] == 1, '소비지출']

single_expend_2019.info # 1인가구 소비지출
# Out:
# <bound method Series.info of 0        451464
# 2       1358773
# 4       5875488
# 5       1180308
# 12       637191
#          ...
# 9499    2933981
# 9500    1009745
# 9501    1292380
# 9504     694386
# 9508    1788251
# Name: 소비지출, Length: 2827, dtype: int64>

# %%
# 1인가구 이상치 식별
(single_expend_2019 < lower_limit) & (single_expend_2019 > upper_limit)
# Out:
# 0       False
# 2       False
# 4       False
# 5       False
# 12      False
#         ...
# 9499    False
# 9500    False
# 9501    False
# 9504    False
# 9508    False
# Name: 소비지출, Length: 2827, dtype: bool

# %% [markdown]
# -- 2차전처리 --
#
# * 1인가구 소비지출 이상치확인 (2827개중 2701개) <126개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(single_expend_2019, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(single_expend_2019, 25)
Q3 = np.percentile(single_expend_2019, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(single_expend_2019), f'Median: {np.median(total_expend_2019):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(single_expend_2019):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(single_expend_2019):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('1인가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_single_expend_2019 = ((single_expend_2019 >= lower_limit) & (single_expend_2019 <= upper_limit))
single_expend_2019[cleaned_single_expend_2019]
# Out:
# 0        451464
# 2       1358773
# 5       1180308
# 12       637191
# 18      2524804
#          ...
# 9496     948939
# 9500    1009745
# 9501    1292380
# 9504     694386
# 9508    1788251
# Name: 소비지출, Length: 2701, dtype: int64

# %%
# 이상치 제거
cleaned_single_expend_2019 = single_expend_2019[(single_expend_2019 >= lower_limit) & (single_expend_2019 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_single_expend_2019, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_single_expend_2019, 25)
Q3 = np.percentile(cleaned_single_expend_2019, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_single_expend_2019), f'Median: {np.median(cleaned_single_expend_2019):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_single_expend_2019):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_single_expend_2019):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('1인가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 1인가구 평균 소비지출
single_expend_mean_2019 = int(single_expend_2019.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {single_expend_mean_2019:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,307,691원

# %%
# 1인가구 평균 소비지출 이상치 제거 후
cleaned_single_expend_mean_2019 = int(cleaned_single_expend_2019.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {cleaned_single_expend_mean_2019:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,136,664원

# %% [markdown]
# 전체가구 식료품음료구입 평균소비 비용, 비율

# %%
tot_식료품음료구입_2019 = dat_2019['식료품음료구입']
tot_식료품음료구입_mean_2019 = int(tot_식료품음료구입_2019.mean())
tot_식료품음료구입_per_2019 = (tot_식료품음료구입_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 식료품음료구입 소비 비율

print(tot_식료품음료구입_2019)
print(tot_식료품음료구입_mean_2019)
print(tot_식료품음료구입_per_2019)
# Out:
# 0       153011
# 1       300713
# 2       171247
# 3       155088
# 4       311939
#          ...
# 9505    689222
# 9506    657277
# 9507    623311
# 9508    270455
# 9509    343307
# Name: 식료품음료구입, Length: 9510, dtype: int64
# 330163
# 14.389040092916025

# %% [markdown]
# 1인가구 식료품음료구입 평균소비 비용, 비율

# %%
sin_tot_식료품음료구입_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '식료품음료구입']
sin_tot_식료품음료구입_mean_2019 = int(sin_tot_식료품음료구입_2019.mean())
sin_tot_식료품음료구입_per_2019 = (sin_tot_식료품음료구입_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 식료품음료구입 소비 비율

print(sin_tot_식료품음료구입_2019)
print(sin_tot_식료품음료구입_mean_2019)
print(sin_tot_식료품음료구입_per_2019)
# Out:
# 0       153011
# 2       171247
# 4       311939
# 5       163525
# 12      170024
#          ...
# 9499    147440
# 9500    129670
# 9501    185910
# 9504    135465
# 9508    270455
# Name: 식료품음료구입, Length: 2827, dtype: int64
# 175818
# 13.444919327272267

# %%
print(f"전체가구 소비 중 식료품음료구입 소비지출, 비율: {tot_식료품음료구입_mean_2019:,}원 ({tot_식료품음료구입_per_2019:.2f}%)")
print(f"1인가구 소비 중 식료품음료구입 소비지출, 비율: {sin_tot_식료품음료구입_mean_2019:,}원 ({sin_tot_식료품음료구입_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 식료품음료구입 소비지출, 비율: 330,163원 (14.39%)
# 1인가구 소비 중 식료품음료구입 소비지출, 비율: 175,818원 (13.44%)

# %% [markdown]
# 전체가구 주류담배구입 평균소비 비용, 비율

# %%
tot_주류담배구입_2019 = dat_2019['주류담배구입']
tot_주류담배구입_mean_2019 = int(tot_주류담배구입_2019.mean())
tot_주류담배구입_per_2019 = (tot_주류담배구입_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 주류담배구입 소비 비율

print(tot_주류담배구입_2019)
print(tot_주류담배구입_mean_2019)
print(tot_주류담배구입_per_2019)
# Out:
# 0         1142
# 1          800
# 2         1594
# 3         4429
# 4        55529
#          ...
# 9505     27333
# 9506    222713
# 9507     33882
# 9508    174718
# 9509    131605
# Name: 주류담배구입, Length: 9510, dtype: int64
# 34241
# 1.492278425570211

# %% [markdown]
# 1인가구 주류담배구입 평균소비 비용, 비율

# %%
sin_tot_주류담배구입_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '주류담배구입']
sin_tot_주류담배구입_mean_2019 = int(sin_tot_주류담배구입_2019.mean())
sin_tot_주류담배구입_per_2019 = (sin_tot_주류담배구입_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 주류담배구입 소비 비율

print(sin_tot_주류담배구입_2019)
print(sin_tot_주류담배구입_mean_2019)
print(sin_tot_주류담배구입_per_2019)
# Out:
# 0         1142
# 2         1594
# 4        55529
# 5        11847
# 12           0
#          ...
# 9499     86940
# 9500     39000
# 9501     30000
# 9504    143065
# 9508    174718
# Name: 주류담배구입, Length: 2827, dtype: int64
# 28626
# 2.189049247872777

# %%
print(f"전체가구 소비 중 주류담배구입 소비지출, 비율: {tot_주류담배구입_mean_2019:,}원 ({tot_주류담배구입_per_2019:.2f}%)")
print(f"1인가구 소비 중 주류담배구입 소비지출, 비율: {sin_tot_주류담배구입_mean_2019:,}원 ({sin_tot_주류담배구입_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 주류담배구입 소비지출, 비율: 34,241원 (1.49%)
# 1인가구 소비 중 주류담배구입 소비지출, 비율: 28,626원 (2.19%)

# %% [markdown]
# 전체가구 의류신발구입 평균소비 비용, 비율

# %%
tot_의류신발구입_2019 = dat_2019['의류신발구입']
tot_의류신발구입_mean_2019 = int(tot_의류신발구입_2019.mean())
tot_의류신발구입_per_2019 = (tot_의류신발구입_mean_2019/ total_expend_mean_2019) * 100  # 전체가구 소비 중 의류신발구입 소비 비율

print(tot_의류신발구입_2019)
print(tot_의류신발구입_mean_2019)
print(tot_의류신발구입_per_2019)
# Out:
# 0        21833
# 1        45300
# 2        86571
# 3        35060
# 4       367754
#          ...
# 9505     73956
# 9506    107586
# 9507    491053
# 9508     50709
# 9509      2591
# Name: 의류신발구입, Length: 9510, dtype: int64
# 131953
# 5.750726178828482

# %% [markdown]
# 1인가구 의류신발구입 평균소비 비용, 비율

# %%
sin_tot_의류신발구입_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '의류신발구입']
sin_tot_의류신발구입_mean_2019 = int(sin_tot_의류신발구입_2019.mean())
sin_tot_의류신발구입_per_2019 = (sin_tot_의류신발구입_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 의류신발구입 소비 비율

print(sin_tot_의류신발구입_2019)
print(sin_tot_의류신발구입_mean_2019)
print(sin_tot_의류신발구입_per_2019)
# Out:
# 0        21833
# 2        86571
# 4       367754
# 5         8177
# 12       29400
#          ...
# 9499    144780
# 9500         0
# 9501    152000
# 9504      2800
# 9508     50709
# Name: 의류신발구입, Length: 2827, dtype: int64
# 66339
# 5.072987425928602

# %%
print(f"전체가구 소비 중 의류신발구입 소비지출, 비율: {tot_의류신발구입_mean_2019:,}원 ({tot_의류신발구입_per_2019:.2f}%)")
print(f"1인가구 소비 중 의류신발구입 소비지출, 비율: {sin_tot_의류신발구입_mean_2019:,}원 ({sin_tot_의류신발구입_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 의류신발구입 소비지출, 비율: 131,953원 (5.75%)
# 1인가구 소비 중 의류신발구입 소비지출, 비율: 66,339원 (5.07%)

# %% [markdown]
# 전체가구 주거수도광열비 평균소비 비용, 비율

# %%
tot_주거수도광열비_2019 = dat_2019['주거수도광열비']
tot_주거수도광열비_mean_2019 = int(tot_주거수도광열비_2019.mean())
tot_주거수도광열비_per_2019 = (tot_주거수도광열비_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 주거수도광열비 소비 비율

print(tot_주거수도광열비_2019)
print(tot_주거수도광열비_mean_2019)
print(tot_주거수도광열비_per_2019)
# Out:
# 0        79220
# 1       302318
# 2       506276
# 3       117620
# 4       368676
#          ...
# 9505    140402
# 9506    137099
# 9507    466607
# 9508    135583
# 9509     57155
# Name: 주거수도광열비, Length: 9510, dtype: int64
# 261760
# 11.407926190159705

# %% [markdown]
# 1인가구 주거수도광열비 평균소비 비용, 비율

# %%
sin_tot_주거수도광열비_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '주거수도광열비']
sin_tot_주거수도광열비_mean_2019 = int(sin_tot_주거수도광열비_2019.mean())
sin_tot_주거수도광열비_per_2019 = (sin_tot_주거수도광열비_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 주거수도광열비 소비 비율

print(sin_tot_주거수도광열비_2019)
print(sin_tot_주거수도광열비_mean_2019)
print(sin_tot_주거수도광열비_per_2019)
# Out:
# 0        79220
# 2       506276
# 4       368676
# 5       409643
# 12      268340
#          ...
# 9499    179690
# 9500    161150
# 9501     78560
# 9504    168001
# 9508    135583
# Name: 주거수도광열비, Length: 2827, dtype: int64
# 237834
# 18.18732406967701

# %%
print(f"전체가구 소비 중 주거수도광열비 소비지출, 비율: {tot_주거수도광열비_mean_2019:,}원 ({tot_주거수도광열비_per_2019:.2f}%)")
print(f"1인가구 소비 중 주거수도광열비 소비지출, 비율: {sin_tot_주거수도광열비_mean_2019:,}원 ({sin_tot_주거수도광열비_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 주거수도광열비 소비지출, 비율: 261,760원 (11.41%)
# 1인가구 소비 중 주거수도광열비 소비지출, 비율: 237,834원 (18.19%)

# %% [markdown]
# 전체가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
tot_가정용품가사서비스이용_2019 = dat_2019['가정용품가사서비스이용']
tot_가정용품가사서비스이용_mean_2019 = int(tot_가정용품가사서비스이용_2019.mean())
tot_가정용품가사서비스이용_per_2019 = (tot_가정용품가사서비스이용_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 가정용품가사서비스이용 소비 비율

print(tot_가정용품가사서비스이용_2019)
print(tot_가정용품가사서비스이용_mean_2019)
print(tot_가정용품가사서비스이용_per_2019)
# Out:
# 0          8013
# 1         26840
# 2         35007
# 3         12674
# 4       2808527
#          ...
# 9505      89460
# 9506      73629
# 9507      81907
# 9508      12647
# 9509      28841
# Name: 가정용품가사서비스이용, Length: 9510, dtype: int64
# 113575
# 4.949783072460989

# %% [markdown]
# 1인가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
sin_tot_가정용품가사서비스이용_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '가정용품가사서비스이용']
sin_tot_가정용품가사서비스이용_mean_2019 = int(sin_tot_가정용품가사서비스이용_2019.mean())
sin_tot_가정용품가사서비스이용_per_2019 = (sin_tot_가정용품가사서비스이용_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 가정용품가사서비스이용 소비 비율

print(sin_tot_가정용품가사서비스이용_2019)
print(sin_tot_가정용품가사서비스이용_mean_2019)
print(sin_tot_가정용품가사서비스이용_per_2019)
# Out:
# 0          8013
# 2         35007
# 4       2808527
# 5        129128
# 12        16806
#          ...
# 9499      24750
# 9500      37000
# 9501       6000
# 9504      17992
# 9508      12647
# Name: 가정용품가사서비스이용, Length: 2827, dtype: int64
# 62826
# 4.804345980816569

# %%
print(f"전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {tot_가정용품가사서비스이용_mean_2019:,}원 ({tot_가정용품가사서비스이용_per_2019:.2f}%)")
print(f"1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {sin_tot_가정용품가사서비스이용_mean_2019:,}원 ({sin_tot_가정용품가사서비스이용_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 113,575원 (4.95%)
# 1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 62,826원 (4.80%)

# %% [markdown]
# 전체가구 보건제품구입 평균소비 비용, 비율

# %%
tot_보건제품구입_2019 = dat_2019['보건제품구입']
tot_보건제품구입_mean_2019 = int(tot_보건제품구입_2019.mean())
tot_보건제품구입_per_2019 = (tot_보건제품구입_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 보건제품구입 소비 비율

print(tot_보건제품구입_2019)
print(tot_보건제품구입_mean_2019)
print(tot_보건제품구입_per_2019)
# Out:
# 0        16733
# 1       139575
# 2        66304
# 3        39010
# 4       272351
#          ...
# 9505     61709
# 9506     59520
# 9507    293552
# 9508     56918
# 9509    125686
# Name: 보건제품구입, Length: 9510, dtype: int64
# 206698
# 9.00823474806552

# %% [markdown]
# 1인가구 보건제품구입 평균소비 비용, 비율

# %%
sin_tot_보건제품구입_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '보건제품구입']
sin_tot_보건제품구입_mean_2019 = int(sin_tot_보건제품구입_2019.mean())
sin_tot_보건제품구입_per_2019 = (sin_tot_보건제품구입_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 보건제품구입 소비 비율

print(sin_tot_보건제품구입_2019)
print(sin_tot_보건제품구입_mean_2019)
print(sin_tot_보건제품구입_per_2019)
# Out:
# 0        16733
# 2        66304
# 4       272351
# 5         9933
# 12       87480
#          ...
# 9499     72500
# 9500         0
# 9501    127100
# 9504     14699
# 9508     56918
# Name: 보건제품구입, Length: 2827, dtype: int64
# 118033
# 9.026061967238439

# %%
print(f"전체가구 소비 중 보건제품구입 소비지출, 비율: {tot_보건제품구입_mean_2019:,}원 ({tot_보건제품구입_per_2019:.2f}%)")
print(f"1인가구 소비 중 보건제품구입 소비지출, 비율: {sin_tot_보건제품구입_mean_2019:,}원 ({sin_tot_보건제품구입_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 보건제품구입 소비지출, 비율: 206,698원 (9.01%)
# 1인가구 소비 중 보건제품구입 소비지출, 비율: 118,033원 (9.03%)

# %%
# col = ['2019']
# index = ['소비지출','식료품음료구입','주류담배구입','의류신발구입','주거수도광열비','가정용품가사서비스이용','보건제품구입','교통비','통신비','오락문화비','교육비','음식숙박비',
#          '기타상품서비스이용','비소비지출금액']
# content = [[total_expend_mean],[tot_식료품음료구입_mean],[tot_주류담배구입_mean],[tot_의류신발구입_mean],[tot_주거수도광열비_mean],[tot_가정용품가사서비스이용_mean],[tot_보건제품구입_mean],
#            [tot_교통비_mean],[tot_통신비_mean],[tot_오락문화비_mean],[tot_교육비_mean],[tot_음식숙박비_mean],[tot_기타상품서비스이용_mean],[tot_비소비지출금액_mean]]

# %%
col = [['2019','2019'],['전체가구','1인가구']]
ind = ['소비지출','식료품음료구입','주류담배구입','의류신발구입','주거수도광열비','가정용품가사서비스이용','보건제품구입']
content = [[total_expend_mean_2019,single_expend_mean_2019],[tot_식료품음료구입_mean_2019,sin_tot_식료품음료구입_mean_2019],[tot_주류담배구입_mean_2019,sin_tot_주류담배구입_mean_2019],
           [tot_의류신발구입_mean_2019,sin_tot_의류신발구입_mean_2019],[tot_주거수도광열비_mean_2019,sin_tot_주거수도광열비_mean_2019],
           [tot_가정용품가사서비스이용_mean_2019,sin_tot_가정용품가사서비스이용_mean_2019],[tot_보건제품구입_mean_2019,sin_tot_보건제품구입_mean_2019]]

# %% [markdown]
# 전체가구 교통비 평균소비 비용, 비율

# %%
tot_교통비_2019 = dat_2019['교통비']
tot_교통비_mean_2019 = int(tot_교통비_2019.mean())
tot_교통비_per_2019 = (tot_교통비_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 교통비 소비 비율

print(tot_교통비_2019)
print(tot_교통비_mean_2019)
print(tot_교통비_per_2019)
# Out:
# 0        31550
# 1       123183
# 2        34700
# 3       169601
# 4        73970
#          ...
# 9505    190525
# 9506    282010
# 9507    609318
# 9508    214141
# 9509    165051
# Name: 교통비, Length: 9510, dtype: int64
# 287754
# 12.540786953404707

# %% [markdown]
# 1인가구 교통비 평균소비 비용, 비율

# %%
sin_tot_교통비_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '교통비']
sin_tot_교통비_mean_2019 = int(sin_tot_교통비_2019.mean())
sin_tot_교통비_per_2019 = (sin_tot_교통비_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 교통비 소비 비율

print(sin_tot_교통비_2019)
print(sin_tot_교통비_mean_2019)
print(sin_tot_교통비_per_2019)
# Out:
# 0        31550
# 2        34700
# 4        73970
# 5       124507
# 12        2000
#          ...
# 9499    787900
# 9500    221190
# 9501    329700
# 9504     79200
# 9508    214141
# Name: 교통비, Length: 2827, dtype: int64
# 160438
# 12.268800504094623

# %% [markdown]
# 전체가구 통신비 평균소비 비용, 비율

# %%
tot_통신비_2019 = dat_2019['통신비']
tot_통신비_mean_2019 = int(tot_통신비_2019.mean())
tot_통신비_per_2019 = (tot_통신비_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 통신비 소비 비율

print(tot_통신비_2019)
print(tot_통신비_mean_2019)
print(tot_통신비_per_2019)
# Out:
# 0        36850
# 1        89476
# 2        63129
# 3       143110
# 4        63276
#          ...
# 9505    218346
# 9506    157815
# 9507    459401
# 9508    117198
# 9509      9475
# Name: 통신비, Length: 9510, dtype: int64
# 112556
# 4.9053733964685815

# %% [markdown]
# 1인가구 통신비 평균소비 비용, 비율

# %%
sin_tot_통신비_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '통신비']
sin_tot_통신비_mean_2019 = int(sin_tot_통신비_2019.mean())
sin_tot_통신비_per_2019 = (sin_tot_통신비_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 통신비 소비 비율

print(sin_tot_통신비_2019)
print(sin_tot_통신비_mean_2019)
print(sin_tot_통신비_per_2019)
# Out:
# 0        36850
# 2        63129
# 4        63276
# 5        69847
# 12        8090
#          ...
# 9499    166600
# 9500     68881
# 9501     36748
# 9504     46800
# 9508    117198
# Name: 통신비, Length: 2827, dtype: int64
# 51662
# 3.9506274800392447

# %% [markdown]
# 전체가구 오락문화비 평균소비 비용, 비율

# %%
tot_오락문화비_2019 = dat_2019['오락문화비']
tot_오락문화비_mean_2019 = int(tot_오락문화비_2019.mean())
tot_오락문화비_per_2019 = (tot_오락문화비_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 오락문화비 소비 비율

print(tot_오락문화비_2019)
print(tot_오락문화비_mean_2019)
print(tot_오락문화비_per_2019)
# Out:
# 0         4818
# 1        46501
# 2       262869
# 3        70786
# 4       448777
#          ...
# 9505    206015
# 9506    210551
# 9507    474079
# 9508     76308
# 9509     28425
# Name: 오락문화비, Length: 9510, dtype: int64
# 155304
# 6.768400706893959

# %% [markdown]
# 1인가구 오락문화비 평균소비 비용, 비율

# %%
sin_tot_오락문화비_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '오락문화비']
sin_tot_오락문화비_mean_2019 = int(sin_tot_오락문화비_2019.mean())
sin_tot_오락문화비_per_2019 = (sin_tot_오락문화비_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 오락문화비 소비 비율

print(sin_tot_오락문화비_2019)
print(sin_tot_오락문화비_mean_2019)
print(sin_tot_오락문화비_per_2019)
# Out:
# 0         4818
# 2       262869
# 4       448777
# 5        93977
# 12       28900
#          ...
# 9499     67770
# 9500     26160
# 9501     19395
# 9504     19556
# 9508     76308
# Name: 오락문화비, Length: 2827, dtype: int64
# 83652
# 6.396924043982867

# %%
print(f"전체가구 소비 중 오락문화비 소비지출, 비율: {tot_오락문화비_mean_2019:,}원 ({tot_오락문화비_per_2019:.2f}%)")
print(f"1인가구 소비 중 오락문화비 소비지출, 비율: {sin_tot_오락문화비_mean_2019:,}원 ({sin_tot_오락문화비_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 오락문화비 소비지출, 비율: 155,304원 (6.77%)
# 1인가구 소비 중 오락문화비 소비지출, 비율: 83,652원 (6.40%)

# %% [markdown]
# 전체가구 교육비 평균소비 비용, 비율

# %%
tot_교육비_2019 = dat_2019['교육비']
tot_교육비_mean_2019 = int(tot_교육비_2019.mean())
tot_교육비_per_2019 = (tot_교육비_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 교육비 소비 비율

print(tot_교육비_2019)
print(tot_교육비_mean_2019)
print(tot_교육비_per_2019)
# Out:
# 0            0
# 1        17200
# 2            0
# 3        34786
# 4            0
#          ...
# 9505    648300
# 9506    152380
# 9507    226145
# 9508         0
# 9509         0
# Name: 교육비, Length: 9510, dtype: int64
# 151169
# 6.5881906870425295

# %% [markdown]
# 1인가구 교육비 평균소비 비용, 비율

# %%
sin_tot_교육비_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '교육비']
sin_tot_교육비_mean_2019 = int(sin_tot_교육비_2019.mean())
sin_tot_교육비_per_2019 = (sin_tot_교육비_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 교육비 소비 비율

print(sin_tot_교육비_2019)
print(sin_tot_교육비_mean_2019)
print(sin_tot_교육비_per_2019)
# Out:
# 0       0
# 2       0
# 4       0
# 5       0
# 12      0
#        ..
# 9499    0
# 9500    0
# 9501    0
# 9504    0
# 9508    0
# Name: 교육비, Length: 2827, dtype: int64
# 22715
# 1.7370311487958547

# %%
print(f"전체가구 소비 중 교육비 소비지출, 비율: {tot_교육비_mean_2019:,}원 ({tot_교육비_per_2019:.2f}%)")
print(f"1인가구 소비 중 교육비 소비지출, 비율: {sin_tot_교육비_mean_2019:,}원 ({sin_tot_교육비_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 교육비 소비지출, 비율: 151,169원 (6.59%)
# 1인가구 소비 중 교육비 소비지출, 비율: 22,715원 (1.74%)

# %% [markdown]
# 전체가구 음식숙박비 평균소비 비용, 비율

# %%
tot_음식숙박비_2019 = dat_2019['음식숙박비']
tot_음식숙박비_mean_2019 = int(tot_음식숙박비_2019.mean())
tot_음식숙박비_per_2019 = (tot_음식숙박비_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 음식숙박비 소비 비율

print(tot_음식숙박비_2019)
print(tot_음식숙박비_mean_2019)
print(tot_음식숙박비_per_2019)
# Out:
# 0         40642
# 1        152167
# 2        108943
# 3        268471
# 4        216033
#          ...
# 9505     564641
# 9506     802885
# 9507    1250118
# 9508     157455
# 9509     167727
# Name: 음식숙박비, Length: 9510, dtype: int64
# 311318
# 13.567744367619724

# %% [markdown]
# 1인가구 음식숙박비 평균소비 비용, 비율

# %%
sin_tot_음식숙박비_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '음식숙박비']
sin_tot_음식숙박비_mean_2019 = int(sin_tot_음식숙박비_2019.mean())
sin_tot_음식숙박비_per_2019 = (sin_tot_음식숙박비_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 음식숙박비 소비 비율

print(sin_tot_음식숙박비_2019)
print(sin_tot_음식숙박비_mean_2019)
print(sin_tot_음식숙박비_per_2019)
# Out:
# 0        40642
# 2       108943
# 4       216033
# 5       139950
# 12        3000
#          ...
# 9499    936440
# 9500    165100
# 9501    196100
# 9504     36900
# 9508    157455
# Name: 음식숙박비, Length: 2827, dtype: int64
# 195412
# 14.943285531520825

# %%
print(f"전체가구 소비 중 음식숙박비 소비지출, 비율: {tot_음식숙박비_mean_2019:,}원 ({tot_음식숙박비_per_2019:.2f}%)")
print(f"1인가구 소비 중 음식숙박비 소비지출, 비율: {sin_tot_음식숙박비_mean_2019:,}원 ({sin_tot_음식숙박비_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 음식숙박비 소비지출, 비율: 311,318원 (13.57%)
# 1인가구 소비 중 음식숙박비 소비지출, 비율: 195,412원 (14.94%)

# %% [markdown]
# 전체가구 기타상품서비스이용 평균소비 비용, 비율

# %%
tot_기타상품서비스이용_2019 = dat_2019['기타상품서비스이용']
tot_기타상품서비스이용_mean_2019 = int(tot_기타상품서비스이용_2019.mean())
tot_기타상품서비스이용_per_2019 = (tot_기타상품서비스이용_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 기타상품서비스이용 소비 비율

print(tot_기타상품서비스이용_2019)
print(tot_기타상품서비스이용_mean_2019)
print(tot_기타상품서비스이용_per_2019)
# Out:
# 0        57652
# 1       224028
# 2        22133
# 3       116307
# 4       888656
#          ...
# 9505    223745
# 9506    132191
# 9507    854536
# 9508    522120
# 9509     42878
# Name: 기타상품서비스이용, Length: 9510, dtype: int64
# 198050
# 8.631340854069107

# %% [markdown]
# 1인가구 기타상품서비스이용 평균소비 비용, 비율

# %%
sin_tot_기타상품서비스이용_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '기타상품서비스이용']
sin_tot_기타상품서비스이용_mean_2019 = int(sin_tot_기타상품서비스이용_2019.mean())
sin_tot_기타상품서비스이용_per_2019 = (sin_tot_기타상품서비스이용_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 기타상품서비스이용 소비 비율

print(sin_tot_기타상품서비스이용_2019)
print(sin_tot_기타상품서비스이용_mean_2019)
print(sin_tot_기타상품서비스이용_per_2019)
# Out:
# 0        57652
# 2        22133
# 4       888656
# 5        19775
# 12       23150
#          ...
# 9499    319171
# 9500    161594
# 9501    130867
# 9504     29908
# 9508    522120
# Name: 기타상품서비스이용, Length: 2827, dtype: int64
# 104332
# 7.978337390102095

# %%
print(f"전체가구 소비 중 기타상품서비스이용 소비지출, 비율: {tot_기타상품서비스이용_mean_2019:,}원 ({tot_기타상품서비스이용_per_2019:.2f}%)")
print(f"1인가구 소비 중 기타상품서비스이용 소비지출, 비율: {sin_tot_기타상품서비스이용_mean_2019:,}원 ({sin_tot_기타상품서비스이용_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 기타상품서비스이용 소비지출, 비율: 198,050원 (8.63%)
# 1인가구 소비 중 기타상품서비스이용 소비지출, 비율: 104,332원 (7.98%)

# %% [markdown]
# 전체가구 비소비지출금액 평균소비 비용, 비율

# %%
tot_비소비지출금액_2019 = dat_2019['비소비지출금액']
tot_비소비지출금액_mean_2019 = int(tot_비소비지출금액_2019.mean())
tot_비소비지출금액_per_2019 = (tot_비소비지출금액_mean_2019 / total_expend_mean_2019) * 100  # 전체가구 소비 중 비소비지출금액 소비 비율

print(tot_비소비지출금액_2019)
print(tot_비소비지출금액_mean_2019)
print(tot_비소비지출금액_per_2019)
# Out:
# 0         99416
# 1        316357
# 2          9206
# 3        445731
# 4        359537
#          ...
# 9505    1538751
# 9506     685210
# 9507    1459269
# 9508     117633
# 9509     490845
# Name: 비소비지출금액, Length: 9510, dtype: int64
# 797791
# 34.769028282295615

# %% [markdown]
# 1인가구 비소비지출금액 평균소비 비용, 비율

# %%
sin_tot_비소비지출금액_2019 = dat_2019.loc[dat_2019['가구원수'] == 1, '비소비지출금액']
sin_tot_비소비지출금액_mean_2019 = int(sin_tot_비소비지출금액_2019.mean())
sin_tot_비소비지출금액_per_2019 = (sin_tot_비소비지출금액_mean_2019 / single_expend_mean_2019) * 100  # 1인가구 소비 중 비소비지출금액 소비 비율

print(sin_tot_비소비지출금액_2019)
print(sin_tot_비소비지출금액_mean_2019)
print(sin_tot_비소비지출금액_per_2019)
# Out:
# 0        99416
# 2         9206
# 4       359537
# 5       101000
# 12      251000
#          ...
# 9499    299880
# 9500    313710
# 9501    875920
# 9504    116685
# 9508    117633
# Name: 비소비지출금액, Length: 2827, dtype: int64
# 444904
# 34.0221046103399

# %%
print(f"전체가구 소비 중 비소비지출금액 소비지출, 비율: {tot_비소비지출금액_mean_2019:,}원 ({tot_비소비지출금액_per_2019:.2f}%)")
print(f"1인가구 소비 중 비소비지출금액 소비지출, 비율: {sin_tot_비소비지출금액_mean_2019:,}원 ({sin_tot_비소비지출금액_per_2019:.2f}%)")
# Out:
# 전체가구 소비 중 비소비지출금액 소비지출, 비율: 797,791원 (34.77%)
# 1인가구 소비 중 비소비지출금액 소비지출, 비율: 444,904원 (34.02%)

# %%
# 조건으로 검색하기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat = pd.read_csv("./data/2020_1인가구.csv", encoding='cp949') ; dat
dat_2020 = dat.copy()

# %%
## [데이터 필요한 행만 전처리]

dat_2020.rename(columns={
    '가계지출금액' : '전체소비지출','가계지출_소비지출금액' : '소비지출','가계지출_소비지출_식료품비주류음료구입비' : '식료품음료구입',
    '가계지출_소비지출_식료품비주류음료_곡물구입비' : '식료품_곡물구입','가계지출_소비지출_식료품비주류음료_곡물가공품구입비' : '식료품_곡물가공품구입',
    '가계지출_소비지출_식료품비주류음료_빵떡류구입비' : '식료품_빵떡류구입','가계지출_소비지출_식료품비주류음료_육류구입비' : '식료품_육류구입',
    '가계지출_소비지출_식료품비주류음료_육류가공품구입비' : '식료품_육류가공품구입','가계지출_소비지출_식료품비주류음료_신선수산동물구입비' : '식료품_신선수산동물구입',
    '가계지출_소비지출_식료품비주류음료_염건수산동물구입비' : '식료품_염건수산동물구입','가계지출_소비지출_식료품비주류음료_기타수산동물가공구입비' : '식료품_기타수산동물가공구입',
    '가계지출_소비지출_식료품비주류음료_유제품및알구입비' : '식료품_유제품알구입','가계지출_소비지출_식료품비주류음료_유지류구입비' : '식료품_유지류구입',
    '가계지출_소비지출_식료품비주류음료_과일가공품구입비' : '식료품_과일가공품구입','가계지출_소비지출_식료품비주류음료_채소가공품구입비' : '식료품_채소가공품구입',
    '가계지출_소비지출_식료품비주류음료_해조가공품구입비' : '식료품_해조가공품구입','가계지출_소비지출_식료품비주류음료_당류과자류구입비' : '식료품_당류과자류구입',
    '가계지출_소비지출_식료품비주류음료_조미식품구입비' : '식료품_조미식품구입','가계지출_소비지출_식료품비주류음료_기타식품구입비' : '식료품_기타식품구입',
    '가계지출_소비지출_식료품비주류음료_커피차구입비' : '식료품_커피차구입','가계지출_소비지출_식료품비주류음료_쥬스기타음료구입비' : '식료품_쥬스음료구입',
    '가계지출_소비지출_주류담배구입비' : '주류담배구입','가계지출_소비지출_주류담배_주류구입비' : '주류구입','가계지출_소비지출_주류담배_담배구입비' : '담배구입',
    '가계지출_소비지출_의류신발구입비' : '의류신발구입','가계지출_소비지출_의류신발_직물및외의구입비' : '의류신발_직물및외의구입','가계지출_소비지출_의류신발_내의구입비' : '의류신발_내의구입',
    '가계지출_소비지출_의류신발_기타의복구입비' : '의류신발_기타의복구입','가계지출_소비지출_의류신발_의복관련서비스구입비' : '의류신발_의복관련서비스구입',
    '가계지출_소비지출_의류신발_신발구입비' : '의류신발_신발구입','가계지출_소비지출_의류신발_신발서비스구입비' : '의류신발_신발서비스구입','가계지출_소비지출_주거수도광열비' : '주거수도광열비',
    '가계지출_소비지출_주거수도광열_실제주거비구입비' : '주거수도광열_실제주거비구입','가계지출_소비지출_주거수도광열_주택유지수선구입비' : '주거수도광열_주택유지수선구입',
    '가계지출_소비지출_주거수도광열_상하수도폐기물처리비' : '주거수도광열_상하수도폐기물처리','가계지출_소비지출_주거수도광열_기타주거관련서비스구입비' : '주거수도광열_기타주거관련서비스구입',
    '가계지출_소비지출_주거수도광열_연료비구입비' : '주거수도광열_연료비구입','가계지출_소비지출_가정용품가사서비스이용금액' : '가정용품가사서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가구조명구입비' : '가정용품가사서비스_가구조명구입','가계지출_소비지출_가정용품가사서비스_실내장식구입비' : '가정용품가사서비스_실내장식구입',
    '가계지출_소비지출_가정용품가사서비스_가구조명장식서비스이용금액' : '가정용품가사서비스_가구조명장식서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가정용섬유구입비' : '가정용품가사서비스_가정용섬유구입','가계지출_소비지출_가정용품가사서비스_가전가정용기기구입비' : '가정용품가사서비스_가전가정용기기구입',
    '가계지출_소비지출_가정용품가사서비스_가전관련서비스이용금액' : '가정용품가사서비스_가전관련서비스이용','가계지출_소비지출_가정용품가사서비스_가사용품구입비' : '가정용품가사서비스_가사용품구입',
    '가계지출_소비지출_가정용품가사서비스_가정용공구기타구입비' : '가정용품가사서비스_가정용공구기타구입','가계지출_소비지출_가정용품가사서비스_가사소모품구입비' : '가정용품가사서비스_가사소모품구입',
    '가계지출_소비지출_가정용품가사서비스_가사서비스금액' : '가정용품가사서비스_가사서비스','가계지출_소비지출_보건제품구입비' : '보건제품구입',
    '가계지출_소비지출_보건_의약품구입비' : '보건_의약품구입','가계지출_소비지출_보건_의료용소모품구입비' : '보건_의료용소모품구입',
    '가계지출_소비지출_보건_보건의료용품기구구입비' : '보건_보건의료용품기구구입','가계지출_소비지출_보건_외래의료서비스이용금액' : '보건_외래의료서비스이용',
    '가계지출_소비지출_보건_치과서비스이용금액' : '보건_치과서비스이용','가계지출_소비지출_보건_기타의료서비스이용금액' : '보건_기타의료서비스이용',
    '가계지출_소비지출_보건_입원서비스이용금액' : '보건_입원서비스이용','가계지출_소비지출_교통비' : '교통비','가계지출_소비지출_교통_자동차구입비' : '교통_자동차구입',
    '가계지출_소비지출_교통_기타운송기구구입비' : '교통_기타운송기구구입','가계지출_소비지출_교통_운송기구유지수리비' : '교통_운송기구유지수리',
    '가계지출_소비지출_교통_운송기구연료비' : '교통_운송기구연료','가계지출_소비지출_교통_기타개인교통서비스이용금액' : '교통_기타개인교통서비스이용',
    '가계지출_소비지출_교통_철도운송금액' : '교통_철도운송','가계지출_소비지출_교통_육상운송금액' : '교통_육상운송','가계지출_소비지출_교통_기타운송금액' : '교통_기타운송',
    '가계지출_소비지출_교통_기타교통관련서비스이용금액' : '교통_기타교통관련서비스이용','가계지출_소비지출_통신비' : '통신비','가계지출_소비지출_통신_우편서비스이용금액' : '통신_우편서비스이용',
    '가계지출_소비지출_통신_통신장비구입비' : '통신_통신장비구입','가계지출_소비지출_통신_통신서비스이용금액' : '통신_통신서비스이용','가계지출_소비지출_오락문화비' : '오락문화비',
    '가계지출_소비지출_오락문화_영상음향기기구입비' : '오락문화_영상음향기기구입','가계지출_소비지출_오락문화_사진광학장비구입비' : '오락문화_사진광학장비구입',
    '가계지출_소비지출_오락문화_정보처리장치구입비' : '오락문화_정보처리장치구입','가계지출_소비지출_오락문화_기록매체구입비' : '오락문화_기록매체구입',
    '가계지출_소비지출_오락문화_영상음향정보기기수리비' : '오락문화_영상음향정보기기수리','가계지출_소비지출_오락문화_내구재구입비' : '오락문화_내구재구입',
    '가계지출_소비지출_오락문화_악기기구구입비' : '오락문화_악기기구구입','가계지출_소비지출_오락문화_오락문화내구재유지수리비' : '오락문화_오락문화내구재유지수리',
    '가계지출_소비지출_오락문화_장난감취미용품구입비' : '오락문화_장난감취미용품구입','가계지출_소비지출_오락문화_캠핑운동관련용품구입비' : '오락문화_캠핑운동관련용품구입',
    '가계지출_소비지출_오락문화_화훼관련용품구입비' : '오락문화_화훼관련용품구입','가계지출_소비지출_오락문화_애완동물관련물품구입비' : '애완동물_물품구입',
    '가계지출_소비지출_오락문화_화훼애완동물서비스이용금액' : '애완동물_서비스이용','가계지출_소비지출_오락문화_운동오락서비스이용금액' : '운동오락_서비스이용',
    '가계지출_소비지출_오락문화_문화서비스이용금액' : '문화_서비스이용','가계지출_소비지출_오락문화_복권구입비' : '복권_구입비','가계지출_소비지출_오락문화_서적구입비' : '서적_구입비',
    '가계지출_소비지출_오락문화_기타인쇄물구입비' : '인쇄물_구입비','가계지출_소비지출_오락문화_문구구입비' : '문구_구입비','가계지출_소비지출_오락문화_단체여행경비' : '단체여행_경비',
    '가계지출_소비지출_교육비' : '교육비','가계지출_소비지출_교육_정규교육비' : '정규교육비','가계지출_소비지출_교육_초등교육비' : '초등교육비','가계지출_소비지출_교육_중등교육비' : '중등교육비',
    '가계지출_소비지출_교육_고등교육비' : '고등교육비','가계지출_소비지출_교육_학원보습교육비' : '학원보습교육비','가계지출_소비지출_교육_학생학원교육비' : '학생학원교육비',
    '가계지출_소비지출_교육_성인학원비' : '성인학원비','가계지출_소비지출_교육_기타교육비' : '기타교육비','가계지출_소비지출_음식숙박비' : '음식숙박비','가계지출_소비지출_음식숙박_식대' : '식대',
    '가계지출_소비지출_음식숙박_숙박비' : '숙박비','가계지출_소비지출_기타상품서비스이용금액' : '기타상품서비스이용','가계지출_소비지출_기타상품서비스_이미용서비스이용금액' : '이미용서비스이용',
    '가계지출_소비지출_기타상품서비스_이미용기기구입비' : '이미용기기구입','가계지출_소비지출_기타상품서비스_위생이미용용품구입비' : '위생이미용용품구입',
    '가계지출_소비지출_기타상품서비스_시계장신구구입비' : '시계장신구구입','가계지출_소비지출_기타상품서비스_기타개인용품구입비' : '기타개인용품구입',
    '가계지출_소비지출_기타상품서비스_복지시설비용금액' : '복지시설비용','가계지출_소비지출_기타상품서비스_보험료' : '보험료','가계지출_소비지출_기타상품서비스_기타금융구입비' : '기타금융구입',
    '가계지출_소비지출_기타상품서비스_기타서비스금액구입비' : '기타서비스금액구입','가계지출_비소비지출금액' : '비소비지출금액','가계지출_비소비지출_경상조세' : '비경상조세',
    '가계지출_비소비지출_비경상조세' : '비경상조세','가계지출_비소비지출_연금기여금' : '연금기여금','가계지출_비소비지출_사회보장구입비' : '사회보장구입비',
    '가계지출_비소비지출_이자비용' : '이자비용','가계지출_비소비지출_가구간이전지출금액' : '가구간이전지출금액','가계지출_비소비지출_비영리단체이전지출금액' : '비영리단체이전지출금액'
}, inplace=True
)

# %%
dat_2020.columns
# Out:
# Index(['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드',
#        '가구주_성별코드', '가구주_연령', '가구주_취업여부',
#        ...
#        '기타서비스금액구입', '비소비지출금액', '비경상조세', '비경상조세', '연금기여금', '사회보장구입비', '이자비용',
#        '가구간이전지출금액', '비영리단체이전지출금액', '도시읍면부구분코드'],
#       dtype='object', length=139)

# %%
# 행 전처리

dat_2020 = dat_2020[['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드', '가구주_성별코드', '가구주_연령', '가구주_취업여부', '거처구분코드',
                     '자동차보유대수','입주형태코드', '월세평가금액', '전세보증금', '소득구간코드', '전체소비지출', '소비지출','식료품음료구입','식료품_곡물구입',
                     '식료품_곡물가공품구입','식료품_빵떡류구입','식료품_육류구입','식료품_육류가공품구입','식료품_신선수산동물구입','식료품_염건수산동물구입','식료품_기타수산동물가공구입',
                     '식료품_유제품알구입','식료품_유지류구입','식료품_과일가공품구입','식료품_채소가공품구입','식료품_해조가공품구입','식료품_당류과자류구입','식료품_조미식품구입',
                     '식료품_기타식품구입','식료품_커피차구입','식료품_쥬스음료구입','주류담배구입','주류구입','담배구입','의류신발구입','의류신발_직물및외의구입','의류신발_내의구입',
                     '의류신발_기타의복구입','의류신발_의복관련서비스구입','의류신발_신발구입','의류신발_신발서비스구입','주거수도광열비','주거수도광열_실제주거비구입',
                     '주거수도광열_주택유지수선구입','주거수도광열_상하수도폐기물처리','주거수도광열_기타주거관련서비스구입','주거수도광열_연료비구입','가정용품가사서비스이용',
                     '가정용품가사서비스_가구조명구입','가정용품가사서비스_실내장식구입','가정용품가사서비스_가구조명장식서비스이용','가정용품가사서비스_가정용섬유구입',
                     '가정용품가사서비스_가전가정용기기구입','가정용품가사서비스_가전관련서비스이용','가정용품가사서비스_가사용품구입','가정용품가사서비스_가정용공구기타구입',
                     '가정용품가사서비스_가사소모품구입','가정용품가사서비스_가사서비스','보건제품구입','보건_의약품구입','보건_의료용소모품구입','보건_보건의료용품기구구입',
                     '보건_외래의료서비스이용','보건_치과서비스이용','보건_기타의료서비스이용','보건_입원서비스이용','교통비','교통_자동차구입','교통_기타운송기구구입','교통_운송기구유지수리',
                     '교통_운송기구연료','교통_기타개인교통서비스이용','교통_철도운송','교통_육상운송','교통_기타운송','교통_기타교통관련서비스이용','통신비','통신_우편서비스이용',
                     '통신_통신장비구입','통신_통신서비스이용','오락문화비','오락문화_영상음향기기구입','오락문화_사진광학장비구입','오락문화_정보처리장치구입','오락문화_기록매체구입',
                     '오락문화_영상음향정보기기수리','오락문화_내구재구입','오락문화_악기기구구입','오락문화_오락문화내구재유지수리','오락문화_장난감취미용품구입','오락문화_캠핑운동관련용품구입',
                     '오락문화_화훼관련용품구입','애완동물_물품구입','애완동물_서비스이용','운동오락_서비스이용','문화_서비스이용','복권_구입비','서적_구입비','인쇄물_구입비','문구_구입비',
                     '단체여행_경비','교육비','정규교육비','초등교육비','중등교육비','고등교육비','학원보습교육비','학생학원교육비','성인학원비','기타교육비','음식숙박비','식대','숙박비',
                     '기타상품서비스이용','이미용서비스이용','이미용기기구입','위생이미용용품구입','시계장신구구입','기타개인용품구입','복지시설비용','보험료','기타금융구입','기타서비스금액구입',
                     '비소비지출금액','비경상조세','비경상조세','연금기여금','사회보장구입비','이자비용','가구간이전지출금액','비영리단체이전지출금액']]

# %%
dat_2020['가구구분코드'] = dat_2020['가구구분코드'].replace({1: '근로자 가구', 2: '비근로자 가구'})
dat_2020['노인가구여부'] = dat_2020['노인가구여부'].replace({0: '아니요', 1: '예'})
dat_2020['배우자코드'] = dat_2020['배우자코드'].replace({1: '현재(동거)', 2: '현재(비동거)', 3:'부재'})
dat_2020['가구주_성별코드'] = dat_2020['가구주_성별코드'].replace({1: '남성', 2: '여성'})
dat_2020['가구주_취업여부'] = dat_2020['가구주_취업여부'].replace({1: '취업', 2: '실업자'})
dat_2020['거처구분코드'] = dat_2020['거처구분코드'].replace({1: '단독주택(다세대 포함)', 2: '아파트', 3: '연립주택', 4: '다가구주택', 5: '비주거용 건물', 6: '오피스텔', 7: '기타'})
dat_2020['입주형태코드'] = dat_2020['입주형태코드'].replace({1: '내 집', 2: '무료주택', 3: '회사주택', 4: '임대', 5: '영구임대', 6: '보증금 월세', 7: '보증금 없는 월세'})
dat_2020['소득구간코드'] = dat_2020['소득구간코드'].replace({1: '100만원 미만', 2: '100~200만원', 3: '200~300만원', 4: '300~400만원', 5: '400~500만원', 6: '500~600만원', 7: '600~700만원', 8: '700만원 이상'})
# dat_2020['도시읍면부구분코드'] = dat_2020['도시읍면부구분코드'].replace({0: '비도시', 1: '도시'})

# %%
dat_2020
# Out:
#          조사연월  가구일련번호   가구구분코드  가구원수  취업인원수 노인가구여부    배우자코드 가구주_성별코드  가구주_연령  \
# 0      202000       1   근로자 가구     1      1    아니요       부재       남성      31
# 1      202000       2  비근로자 가구     2      0      예   현재(동거)       남성      74
# 2      202000       3   근로자 가구     4      2    아니요  현재(비동거)       여성      48
# 3      202000       4   근로자 가구     3      3    아니요   현재(동거)       남성      51
# 4      202000       5  비근로자 가구     3      3    아니요       부재       여성      56
# ...       ...     ...      ...   ...    ...    ...      ...      ...     ...
# 12117  202000   12118   근로자 가구     2      2    아니요   현재(동거)       남성      58
# 12118  202000   12119  비근로자 가구     2      2    아니요   현재(동거)       남성      60
# 12119  202000   12120  비근로자 가구     5      4    아니요   현재(동거)       남성      57
# 12120  202000   12121   근로자 가구     3      2    아니요   현재(동거)       남성      59
# 12121  202000   12122   근로자 가구     1      1      예       부재       여성      67
#
# ...

# %%
def age(가구주_연령):
    if 가구주_연령 < 20:
        return '10대'
    elif 20 <= 가구주_연령 < 30:
        return '20대'
    elif 30 <= 가구주_연령 < 40:
        return '30대'
    elif 40 <= 가구주_연령 < 50:
        return '40대'
    elif 50 <= 가구주_연령 < 60:
        return '50대'
    elif 60 <= 가구주_연령 < 70:
        return '60대'
    elif 70 <= 가구주_연령:
        return '70대 이상'

# 데이터 연령대별 구분
dat_2020.loc[:,'연령대'] = dat_2020['가구주_연령'].apply(age)
dat_2020.연령대
# Out:
# 0           30대
# 1        70대 이상
# 2           40대
# 3           50대
# 4           50대
#           ...
# 12117       50대
# 12118       60대
# 12119       50대
# 12120       50대
# 12121       60대
# Name: 연령대, Length: 12122, dtype: object

# %%
# 연령대별 가구원 수 분포
dat_2020.groupby('연령대')['가구원수'].value_counts().unstack().fillna(0).astype(int)
# Out:
# 가구원수      1     2    3    4    5   6  7  8
# 연령대
# 10대      13     1    0    0    0   0  0  0
# 20대     512   109   42   13    4   2  0  0
# 30대     471   321  338  333   58  12  2  0
# 40대     335   363  536  739  197  34  3  1
# 50대     586   936  693  464   74  11  1  0
# 60대     711  1301  379  113   22   7  1  0
# 70대 이상  987  1218  146   23    7   3  0  0

# %% [markdown]
# ##### 전체가구 지출 (total_expend) | 1인가구 지출 (single_expend )

# %% [markdown]
# 전체가구 소비지출

# %% [markdown]
# box plot 그려서 분포 확인해봐야 함

# %%
total_expend_2020 = dat_2020['소비지출']

total_expend_2020.info # 전체가구 소비지출
# Out:
# <bound method Series.info of 0        1673542
# 1        1589980
# 2        2503083
# 3        4129277
# 4        2992942
#           ...
# 12117    3241270
# 12118    1663596
# 12119    5364636
# 12120    2181344
# 12121    1361880
# Name: 소비지출, Length: 12122, dtype: int64>

# %% [markdown]
# --2차 전처리--
#
# 전체가구 소비지출 이상치확인 (9,510개중 6,730개) <2,780개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(total_expend_2020, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(total_expend_2020, 25)
Q3 = np.percentile(total_expend_2020, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(total_expend_2020), f'Median: {np.median(total_expend_2020):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(total_expend_2020):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(total_expend_2020):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('전체가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_total_expend_2020 = ((total_expend_2020 >= lower_limit) & (total_expend_2020 <= upper_limit))
total_expend_2020[cleaned_total_expend_2020]
# Out:
# 0        1673542
# 1        1589980
# 2        2503083
# 3        4129277
# 4        2992942
#           ...
# 12117    3241270
# 12118    1663596
# 12119    5364636
# 12120    2181344
# 12121    1361880
# Name: 소비지출, Length: 11622, dtype: int64

# %%
# 이상치 제거
cleaned_total_expend_2020 = total_expend_2020[(total_expend_2020 >= lower_limit) & (total_expend_2020 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_total_expend_2020, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_total_expend_2020, 25)
Q3 = np.percentile(cleaned_total_expend_2020, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_total_expend_2020), f'Median: {np.median(cleaned_total_expend_2020):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_total_expend_2020):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_total_expend_2020):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('전체가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 전체가구 평균 소비지출
total_expend_mean_2020 = int(total_expend_2020.mean())
print(f"전체가구의 평균 소비지출: {total_expend_mean_2020:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,294,703원

# %%
# 전체가구 평균 소비지출 이상치 제거 후
cleaned_total_expend_mean_2020 = int(cleaned_total_expend_2020.mean())
print(f"전체가구의 평균 소비지출: {cleaned_total_expend_mean_2020:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,034,512원

# %% [markdown]
# 1인가구 소비지출

# %%
# 가구원수 1로 설정하여 9510개에서 2827개의 데이터 전처리

single_expend_2020 = dat_2020.loc[dat['가구원수'] == 1, '소비지출']

single_expend_2020.info # 1인가구 소비지출
# Out:
# <bound method Series.info of 0        1673542
# 7        1211227
# 11       1297083
# 16       2282052
# 17       1740520
#           ...
# 12103     402238
# 12108    1371740
# 12109    1605377
# 12115     956353
# 12121    1361880
# Name: 소비지출, Length: 3615, dtype: int64>

# %%
# 1인가구 이상치 식별
(single_expend_2020 < lower_limit) & (single_expend_2020 > upper_limit)
# Out:
# 0        False
# 7        False
# 11       False
# 16       False
# 17       False
#          ...
# 12103    False
# 12108    False
# 12109    False
# 12115    False
# 12121    False
# Name: 소비지출, Length: 3615, dtype: bool

# %% [markdown]
# -- 2차전처리 --
#
# * 1인가구 소비지출 이상치확인 (2827개중 2701개) <126개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(single_expend_2020, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(single_expend_2020, 25)
Q3 = np.percentile(single_expend_2020, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(single_expend_2020), f'Median: {np.median(total_expend_2020):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(single_expend_2020):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(single_expend_2020):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('1인가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_single_expend_2020 = ((single_expend_2020 >= lower_limit) & (single_expend_2020 <= upper_limit))
single_expend_2020[cleaned_single_expend_2020]
# Out:
# 0        1673542
# 7        1211227
# 11       1297083
# 16       2282052
# 17       1740520
#           ...
# 12103     402238
# 12108    1371740
# 12109    1605377
# 12115     956353
# 12121    1361880
# Name: 소비지출, Length: 3466, dtype: int64

# %%
# 이상치 제거
cleaned_single_expend_2020 = single_expend_2020[(single_expend_2020 >= lower_limit) & (single_expend_2020 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_single_expend_2020, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_single_expend_2020, 25)
Q3 = np.percentile(cleaned_single_expend_2020, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_single_expend_2020), f'Median: {np.median(cleaned_single_expend_2020):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_single_expend_2020):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_single_expend_2020):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('1인가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 1인가구 평균 소비지출
single_expend_mean_2020 = int(single_expend_2020.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {single_expend_mean_2020:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,267,818원

# %%
# 1인가구 평균 소비지출 이상치 제거 후
cleaned_single_expend_mean_2020 = int(cleaned_single_expend_2020.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {cleaned_single_expend_mean_2020:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,143,200원

# %% [markdown]
# 전체가구 식료품음료구입 평균소비 비용, 비율

# %%
tot_식료품음료구입_2020 = dat_2020['식료품음료구입']
tot_식료품음료구입_mean_2020 = int(tot_식료품음료구입_2020.mean())
tot_식료품음료구입_per_2020 = (tot_식료품음료구입_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 식료품음료구입 소비 비율

print(tot_식료품음료구입_2020)
print(tot_식료품음료구입_mean_2020)
print(tot_식료품음료구입_per_2020)
# Out:
# 0         147537
# 1         531503
# 2         412510
# 3         378227
# 4         547546
#           ...
# 12117     293155
# 12118     717090
# 12119    1187880
# 12120     438720
# 12121     259520
# Name: 식료품음료구입, Length: 12122, dtype: int64
# 376312
# 16.39915928117931

# %% [markdown]
# 1인가구 식료품음료구입 평균소비 비용, 비율

# %%
sin_tot_식료품음료구입_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '식료품음료구입']
sin_tot_식료품음료구입_mean_2020 = int(sin_tot_식료품음료구입_2020.mean())
sin_tot_식료품음료구입_per_2020 = (sin_tot_식료품음료구입_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 식료품음료구입 소비 비율

print(sin_tot_식료품음료구입_2020)
print(sin_tot_식료품음료구입_mean_2020)
print(sin_tot_식료품음료구입_per_2020)
# Out:
# 0        147537
# 7         94038
# 11        67710
# 16       276002
# 17       228783
#           ...
# 12103     87945
# 12108    213753
# 12109    156898
# 12115    249535
# 12121    259520
# Name: 식료품음료구입, Length: 3615, dtype: int64
# 192714
# 15.200446751820845

# %%
print(f"전체가구 소비 중 식료품음료구입 소비지출, 비율: {tot_식료품음료구입_mean_2020:,}원 ({tot_식료품음료구입_per_2020:.2f}%)")
print(f"1인가구 소비 중 식료품음료구입 소비지출, 비율: {sin_tot_식료품음료구입_mean_2020:,}원 ({sin_tot_식료품음료구입_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 식료품음료구입 소비지출, 비율: 376,312원 (16.40%)
# 1인가구 소비 중 식료품음료구입 소비지출, 비율: 192,714원 (15.20%)

# %% [markdown]
# 전체가구 주류담배구입 평균소비 비용, 비율

# %%
tot_주류담배구입_2020 = dat_2020['주류담배구입']
tot_주류담배구입_mean_2020 = int(tot_주류담배구입_2020.mean())
tot_주류담배구입_per_2020 = (tot_주류담배구입_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 주류담배구입 소비 비율

print(tot_주류담배구입_2020)
print(tot_주류담배구입_mean_2020)
print(tot_주류담배구입_per_2020)
# Out:
# 0            0
# 1        38540
# 2         7650
# 3        68333
# 4          380
#          ...
# 12117     5000
# 12118     3900
# 12119    14800
# 12120        0
# 12121        0
# Name: 주류담배구입, Length: 12122, dtype: int64
# 36077
# 1.572186030174711

# %% [markdown]
# 1인가구 주류담배구입 평균소비 비용, 비율

# %%
sin_tot_주류담배구입_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '주류담배구입']
sin_tot_주류담배구입_mean_2020 = int(sin_tot_주류담배구입_2020.mean())
sin_tot_주류담배구입_per_2020 = (sin_tot_주류담배구입_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 주류담배구입 소비 비율

print(sin_tot_주류담배구입_2020)
print(sin_tot_주류담배구입_mean_2020)
print(sin_tot_주류담배구입_per_2020)
# Out:
# 0             0
# 7        118608
# 11       129122
# 16       104810
# 17        10345
#           ...
# 12103       325
# 12108         0
# 12109      6532
# 12115    145150
# 12121         0
# Name: 주류담배구입, Length: 3615, dtype: int64
# 28446
# 2.2436974392223488

# %%
print(f"전체가구 소비 중 주류담배구입 소비지출, 비율: {tot_주류담배구입_mean_2020:,}원 ({tot_주류담배구입_per_2020:.2f}%)")
print(f"1인가구 소비 중 주류담배구입 소비지출, 비율: {sin_tot_주류담배구입_mean_2020:,}원 ({sin_tot_주류담배구입_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 주류담배구입 소비지출, 비율: 36,077원 (1.57%)
# 1인가구 소비 중 주류담배구입 소비지출, 비율: 28,446원 (2.24%)

# %% [markdown]
# 전체가구 의류신발구입 평균소비 비용, 비율

# %%
tot_의류신발구입_2020 = dat_2020['의류신발구입']
tot_의류신발구입_mean_2020 = int(tot_의류신발구입_2020.mean())
tot_의류신발구입_per_2020 = (tot_의류신발구입_mean_2020/ total_expend_mean_2020) * 100  # 전체가구 소비 중 의류신발구입 소비 비율

print(tot_의류신발구입_2020)
print(tot_의류신발구입_mean_2020)
print(tot_의류신발구입_per_2020)
# Out:
# 0         43950
# 1        164967
# 2        119633
# 3        509636
# 4        150350
#           ...
# 12117    136200
# 12118         0
# 12119    211700
# 12120    525000
# 12121    324200
# Name: 의류신발구입, Length: 12122, dtype: int64
# 110233
# 4.803802496445074

# %% [markdown]
# 1인가구 의류신발구입 평균소비 비용, 비율

# %%
sin_tot_의류신발구입_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '의류신발구입']
sin_tot_의류신발구입_mean_2020 = int(sin_tot_의류신발구입_2020.mean())
sin_tot_의류신발구입_per_2020 = (sin_tot_의류신발구입_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 의류신발구입 소비 비율

print(sin_tot_의류신발구입_2020)
print(sin_tot_의류신발구입_mean_2020)
print(sin_tot_의류신발구입_per_2020)
# Out:
# 0         43950
# 7         37325
# 11       198972
# 16        85407
# 17        93929
#           ...
# 12103     42500
# 12108     39110
# 12109     80470
# 12115     27583
# 12121    324200
# Name: 의류신발구입, Length: 3615, dtype: int64
# 57543
# 4.538742942599017

# %%
print(f"전체가구 소비 중 의류신발구입 소비지출, 비율: {tot_의류신발구입_mean_2020:,}원 ({tot_의류신발구입_per_2020:.2f}%)")
print(f"1인가구 소비 중 의류신발구입 소비지출, 비율: {sin_tot_의류신발구입_mean_2020:,}원 ({sin_tot_의류신발구입_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 의류신발구입 소비지출, 비율: 110,233원 (4.80%)
# 1인가구 소비 중 의류신발구입 소비지출, 비율: 57,543원 (4.54%)

# %% [markdown]
# 전체가구 주거수도광열비 평균소비 비용, 비율

# %%
tot_주거수도광열비_2020 = dat_2020['주거수도광열비']
tot_주거수도광열비_mean_2020 = int(tot_주거수도광열비_2020.mean())
tot_주거수도광열비_per_2020 = (tot_주거수도광열비_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 주거수도광열비 소비 비율

print(tot_주거수도광열비_2020)
print(tot_주거수도광열비_mean_2020)
print(tot_주거수도광열비_per_2020)
# Out:
# 0        391107
# 1         91253
# 2        150497
# 3         71980
# 4        721405
#           ...
# 12117    474050
# 12118     62980
# 12119    617500
# 12120     94970
# 12121    353500
# Name: 주거수도광열비, Length: 12122, dtype: int64
# 282187
# 12.297321265540683

# %% [markdown]
# 1인가구 주거수도광열비 평균소비 비용, 비율

# %%
sin_tot_주거수도광열비_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '주거수도광열비']
sin_tot_주거수도광열비_mean_2020 = int(sin_tot_주거수도광열비_2020.mean())
sin_tot_주거수도광열비_per_2020 = (sin_tot_주거수도광열비_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 주거수도광열비 소비 비율

print(sin_tot_주거수도광열비_2020)
print(sin_tot_주거수도광열비_mean_2020)
print(sin_tot_주거수도광열비_per_2020)
# Out:
# 0        391107
# 7        340487
# 11       277638
# 16       896677
# 17       219145
#           ...
# 12103    145078
# 12108    176440
# 12109     92076
# 12115     90287
# 12121    353500
# Name: 주거수도광열비, Length: 3615, dtype: int64
# 244525
# 19.287074327703188

# %%
print(f"전체가구 소비 중 주거수도광열비 소비지출, 비율: {tot_주거수도광열비_mean_2020:,}원 ({tot_주거수도광열비_per_2020:.2f}%)")
print(f"1인가구 소비 중 주거수도광열비 소비지출, 비율: {sin_tot_주거수도광열비_mean_2020:,}원 ({sin_tot_주거수도광열비_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 주거수도광열비 소비지출, 비율: 282,187원 (12.30%)
# 1인가구 소비 중 주거수도광열비 소비지출, 비율: 244,525원 (19.29%)

# %% [markdown]
# 전체가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
tot_가정용품가사서비스이용_2020 = dat_2020['가정용품가사서비스이용']
tot_가정용품가사서비스이용_mean_2020 = int(tot_가정용품가사서비스이용_2020.mean())
tot_가정용품가사서비스이용_per_2020 = (tot_가정용품가사서비스이용_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 가정용품가사서비스이용 소비 비율

print(tot_가정용품가사서비스이용_2020)
print(tot_가정용품가사서비스이용_mean_2020)
print(tot_가정용품가사서비스이용_per_2020)
# Out:
# 0         46978
# 1         69497
# 2         44925
# 3        123872
# 4         43352
#           ...
# 12117     82890
# 12118     15100
# 12119    105900
# 12120     32500
# 12121     22000
# Name: 가정용품가사서비스이용, Length: 12122, dtype: int64
# 130262
# 5.676638763273504

# %% [markdown]
# 1인가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
sin_tot_가정용품가사서비스이용_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '가정용품가사서비스이용']
sin_tot_가정용품가사서비스이용_mean_2020 = int(sin_tot_가정용품가사서비스이용_2020.mean())
sin_tot_가정용품가사서비스이용_per_2020 = (sin_tot_가정용품가사서비스이용_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 가정용품가사서비스이용 소비 비율

print(sin_tot_가정용품가사서비스이용_2020)
print(sin_tot_가정용품가사서비스이용_mean_2020)
print(sin_tot_가정용품가사서비스이용_per_2020)
# Out:
# 0         46978
# 7           759
# 11        12732
# 16        51145
# 17       139931
#           ...
# 12103     14778
# 12108     85767
# 12109    361488
# 12115     30522
# 12121     22000
# Name: 가정용품가사서비스이용, Length: 3615, dtype: int64
# 59014
# 4.654769059912385

# %%
print(f"전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {tot_가정용품가사서비스이용_mean_2020:,}원 ({tot_가정용품가사서비스이용_per_2020:.2f}%)")
print(f"1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {sin_tot_가정용품가사서비스이용_mean_2020:,}원 ({sin_tot_가정용품가사서비스이용_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 130,262원 (5.68%)
# 1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 59,014원 (4.65%)

# %% [markdown]
# 전체가구 보건제품구입 평균소비 비용, 비율

# %%
tot_보건제품구입_2020 = dat_2020['보건제품구입']
tot_보건제품구입_mean_2020 = int(tot_보건제품구입_2020.mean())
tot_보건제품구입_per_2020 = (tot_보건제품구입_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 보건제품구입 소비 비율

print(tot_보건제품구입_2020)
print(tot_보건제품구입_mean_2020)
print(tot_보건제품구입_per_2020)
# Out:
# 0         80648
# 1        337917
# 2        125878
# 3        250311
# 4        236233
#           ...
# 12117    362250
# 12118    172890
# 12119    119100
# 12120     24700
# 12121     18000
# Name: 보건제품구입, Length: 12122, dtype: int64
# 219874
# 9.581806447283157

# %% [markdown]
# 1인가구 보건제품구입 평균소비 비용, 비율

# %%
sin_tot_보건제품구입_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '보건제품구입']
sin_tot_보건제품구입_mean_2020 = int(sin_tot_보건제품구입_2020.mean())
sin_tot_보건제품구입_per_2020 = (sin_tot_보건제품구입_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 보건제품구입 소비 비율

print(sin_tot_보건제품구입_2020)
print(sin_tot_보건제품구입_mean_2020)
print(sin_tot_보건제품구입_per_2020)
# Out:
# 0         80648
# 7         33715
# 11        31842
# 16         1650
# 17       253835
#           ...
# 12103     88725
# 12108    116650
# 12109    106860
# 12115     51323
# 12121     18000
# Name: 보건제품구입, Length: 3615, dtype: int64
# 122046
# 9.626460580304114

# %%
print(f"전체가구 소비 중 보건제품구입 소비지출, 비율: {tot_보건제품구입_mean_2020:,}원 ({tot_보건제품구입_per_2020:.2f}%)")
print(f"1인가구 소비 중 보건제품구입 소비지출, 비율: {sin_tot_보건제품구입_mean_2020:,}원 ({sin_tot_보건제품구입_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 보건제품구입 소비지출, 비율: 219,874원 (9.58%)
# 1인가구 소비 중 보건제품구입 소비지출, 비율: 122,046원 (9.63%)

# %% [markdown]
# 전체가구 교통비 평균소비 비용, 비율

# %%
tot_교통비_2020 = dat_2020['교통비']
tot_교통비_mean_2020 = int(tot_교통비_2020.mean())
tot_교통비_per_2020 = (tot_교통비_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 교통비 소비 비율

print(tot_교통비_2020)
print(tot_교통비_mean_2020)
print(tot_교통비_per_2020)
# Out:
# 0        267330
# 1         39167
# 2        183313
# 3        544370
# 4        609887
#           ...
# 12117    636250
# 12118    135270
# 12119    664000
# 12120    280000
# 12121     49900
# Name: 교통비, Length: 12122, dtype: int64
# 279250
# 12.169330845865456

# %% [markdown]
# 1인가구 교통비 평균소비 비용, 비율

# %%
sin_tot_교통비_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '교통비']
sin_tot_교통비_mean_2020 = int(sin_tot_교통비_2020.mean())
sin_tot_교통비_per_2020 = (sin_tot_교통비_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 교통비 소비 비율

print(sin_tot_교통비_2020)
print(sin_tot_교통비_mean_2020)
print(sin_tot_교통비_per_2020)
# Out:
# 0        267330
# 7        100060
# 11        41001
# 16        36350
# 17       165374
#           ...
# 12103       600
# 12108    122517
# 12109    133178
# 12115     46523
# 12121     49900
# Name: 교통비, Length: 3615, dtype: int64
# 133018
# 10.491884481842032

# %% [markdown]
# 전체가구 통신비 평균소비 비용, 비율

# %%
tot_통신비_2020 = dat_2020['통신비']
tot_통신비_mean_2020 = int(tot_통신비_2020.mean())
tot_통신비_per_2020 = (tot_통신비_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 통신비 소비 비율

print(tot_통신비_2020)
print(tot_통신비_mean_2020)
print(tot_통신비_per_2020)
# Out:
# 0         56492
# 1         31103
# 2        415879
# 3        185730
# 4         62463
#           ...
# 12117     99639
# 12118     72728
# 12119    160491
# 12120    125830
# 12121     21910
# Name: 통신비, Length: 12122, dtype: int64
# 111928
# 4.8776682646948215

# %% [markdown]
# 1인가구 통신비 평균소비 비용, 비율

# %%
sin_tot_통신비_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '통신비']
sin_tot_통신비_mean_2020 = int(sin_tot_통신비_2020.mean())
sin_tot_통신비_per_2020 = (sin_tot_통신비_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 통신비 소비 비율

print(sin_tot_통신비_2020)
print(sin_tot_통신비_mean_2020)
print(sin_tot_통신비_per_2020)
# Out:
# 0        56492
# 7            0
# 11       69272
# 16       85612
# 17       72297
#          ...
# 12103    12788
# 12108    50893
# 12109    58748
# 12115    51167
# 12121    21910
# Name: 통신비, Length: 3615, dtype: int64
# 55401
# 4.369791247639646

# %% [markdown]
# 전체가구 오락문화비 평균소비 비용, 비율

# %%
tot_오락문화비_2020 = dat_2020['오락문화비']
tot_오락문화비_mean_2020 = int(tot_오락문화비_2020.mean())
tot_오락문화비_per_2020 = (tot_오락문화비_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 오락문화비 소비 비율

print(tot_오락문화비_2020)
print(tot_오락문화비_mean_2020)
print(tot_오락문화비_per_2020)
# Out:
# 0        243197
# 1          8600
# 2         91400
# 3        305060
# 4         80352
#           ...
# 12117    111895
# 12118     36587
# 12119    733361
# 12120     45205
# 12121     12790
# Name: 오락문화비, Length: 12122, dtype: int64
# 129164
# 5.628789433752429

# %% [markdown]
# 1인가구 오락문화비 평균소비 비용, 비율

# %%
sin_tot_오락문화비_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '오락문화비']
sin_tot_오락문화비_mean_2020 = int(sin_tot_오락문화비_2020.mean())
sin_tot_오락문화비_per_2020 = (sin_tot_오락문화비_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 오락문화비 소비 비율

print(sin_tot_오락문화비_2020)
print(sin_tot_오락문화비_mean_2020)
print(sin_tot_오락문화비_per_2020)
# Out:
# 0        243197
# 7         42417
# 11        45693
# 16        96727
# 17        58972
#           ...
# 12103      2500
# 12108     63733
# 12109    116071
# 12115     33263
# 12121     12790
# Name: 오락문화비, Length: 3615, dtype: int64
# 73450
# 5.793418298209996

# %%
print(f"전체가구 소비 중 오락문화비 소비지출, 비율: {tot_오락문화비_mean_2020:,}원 ({tot_오락문화비_per_2020:.2f}%)")
print(f"1인가구 소비 중 오락문화비 소비지출, 비율: {sin_tot_오락문화비_mean_2020:,}원 ({sin_tot_오락문화비_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 오락문화비 소비지출, 비율: 129,164원 (5.63%)
# 1인가구 소비 중 오락문화비 소비지출, 비율: 73,450원 (5.79%)

# %% [markdown]
# 전체가구 교육비 평균소비 비용, 비율

# %%
tot_교육비_2020 = dat_2020['교육비']
tot_교육비_mean_2020 = int(tot_교육비_2020.mean())
tot_교육비_per_2020 = (tot_교육비_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 교육비 소비 비율

print(tot_교육비_2020)
print(tot_교육비_mean_2020)
print(tot_교육비_per_2020)
# Out:
# 0             0
# 1             0
# 2             0
# 3         60000
# 4         62762
#           ...
# 12117    280000
# 12118         0
# 12119    352700
# 12120         0
# 12121         0
# Name: 교육비, Length: 12122, dtype: int64
# 131572
# 5.73372676115384

# %% [markdown]
# 1인가구 교육비 평균소비 비용, 비율

# %%
sin_tot_교육비_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '교육비']
sin_tot_교육비_mean_2020 = int(sin_tot_교육비_2020.mean())
sin_tot_교육비_per_2020 = (sin_tot_교육비_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 교육비 소비 비율

print(sin_tot_교육비_2020)
print(sin_tot_교육비_mean_2020)
print(sin_tot_교육비_per_2020)
# Out:
# 0            0
# 7            0
# 11           0
# 16           0
# 17       29833
#          ...
# 12103        0
# 12108        0
# 12109        0
# 12115        0
# 12121        0
# Name: 교육비, Length: 3615, dtype: int64
# 14802
# 1.1675177351954302

# %%
print(f"전체가구 소비 중 교육비 소비지출, 비율: {tot_교육비_mean_2020:,}원 ({tot_교육비_per_2020:.2f}%)")
print(f"1인가구 소비 중 교육비 소비지출, 비율: {sin_tot_교육비_mean_2020:,}원 ({sin_tot_교육비_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 교육비 소비지출, 비율: 131,572원 (5.73%)
# 1인가구 소비 중 교육비 소비지출, 비율: 14,802원 (1.17%)

# %% [markdown]
# 전체가구 음식숙박비 평균소비 비용, 비율

# %%
tot_음식숙박비_2020 = dat_2020['음식숙박비']
tot_음식숙박비_mean_2020 = int(tot_음식숙박비_2020.mean())
tot_음식숙박비_per_2020 = (tot_음식숙박비_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 음식숙박비 소비 비율

print(tot_음식숙박비_2020)
print(tot_음식숙박비_mean_2020)
print(tot_음식숙박비_per_2020)
# Out:
# 0        325720
# 1        108150
# 2        448567
# 3        774107
# 4        379508
#           ...
# 12117    334000
# 12118    167000
# 12119    935100
# 12120    261000
# 12121    197100
# Name: 음식숙박비, Length: 12122, dtype: int64
# 291192
# 12.689746777687569

# %% [markdown]
# 1인가구 음식숙박비 평균소비 비용, 비율

# %%
sin_tot_음식숙박비_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '음식숙박비']
sin_tot_음식숙박비_mean_2020 = int(sin_tot_음식숙박비_2020.mean())
sin_tot_음식숙박비_per_2020 = (sin_tot_음식숙박비_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 음식숙박비 소비 비율

print(sin_tot_음식숙박비_2020)
print(sin_tot_음식숙박비_mean_2020)
print(sin_tot_음식숙박비_per_2020)
# Out:
# 0        325720
# 7        376064
# 11       407712
# 16       462027
# 17       251498
#           ...
# 12103         0
# 12108    413973
# 12109    238540
# 12115    121333
# 12121    197100
# Name: 음식숙박비, Length: 3615, dtype: int64
# 191942
# 15.139554731041837

# %%
print(f"전체가구 소비 중 음식숙박비 소비지출, 비율: {tot_음식숙박비_mean_2020:,}원 ({tot_음식숙박비_per_2020:.2f}%)")
print(f"1인가구 소비 중 음식숙박비 소비지출, 비율: {sin_tot_음식숙박비_mean_2020:,}원 ({sin_tot_음식숙박비_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 음식숙박비 소비지출, 비율: 291,192원 (12.69%)
# 1인가구 소비 중 음식숙박비 소비지출, 비율: 191,942원 (15.14%)

# %% [markdown]
# 전체가구 기타상품서비스이용 평균소비 비용, 비율

# %%
tot_기타상품서비스이용_2020 = dat_2020['기타상품서비스이용']
tot_기타상품서비스이용_mean_2020 = int(tot_기타상품서비스이용_2020.mean())
tot_기타상품서비스이용_per_2020 = (tot_기타상품서비스이용_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 기타상품서비스이용 소비 비율

print(tot_기타상품서비스이용_2020)
print(tot_기타상품서비스이용_mean_2020)
print(tot_기타상품서비스이용_per_2020)
# Out:
# 0         70584
# 1        169283
# 2        502831
# 3        857651
# 4         98704
#           ...
# 12117    425941
# 12118    280051
# 12119    262104
# 12120    353419
# 12121    102960
# Name: 기타상품서비스이용, Length: 12122, dtype: int64
# 196648
# 8.569649318452106

# %% [markdown]
# 1인가구 기타상품서비스이용 평균소비 비용, 비율

# %%
sin_tot_기타상품서비스이용_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '기타상품서비스이용']
sin_tot_기타상품서비스이용_mean_2020 = int(sin_tot_기타상품서비스이용_2020.mean())
sin_tot_기타상품서비스이용_per_2020 = (sin_tot_기타상품서비스이용_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 기타상품서비스이용 소비 비율

print(sin_tot_기타상품서비스이용_2020)
print(sin_tot_기타상품서비스이용_mean_2020)
print(sin_tot_기타상품서비스이용_per_2020)
# Out:
# 0         70584
# 7         67753
# 11        15390
# 16       185646
# 17       216580
#           ...
# 12103      7000
# 12108     88903
# 12109    254516
# 12115    109667
# 12121    102960
# Name: 기타상품서비스이용, Length: 3615, dtype: int64
# 94912
# 7.486248026136244

# %%
print(f"전체가구 소비 중 기타상품서비스이용 소비지출, 비율: {tot_기타상품서비스이용_mean_2020:,}원 ({tot_기타상품서비스이용_per_2020:.2f}%)")
print(f"1인가구 소비 중 기타상품서비스이용 소비지출, 비율: {sin_tot_기타상품서비스이용_mean_2020:,}원 ({sin_tot_기타상품서비스이용_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 기타상품서비스이용 소비지출, 비율: 196,648원 (8.57%)
# 1인가구 소비 중 기타상품서비스이용 소비지출, 비율: 94,912원 (7.49%)

# %% [markdown]
# 전체가구 비소비지출금액 평균소비 비용, 비율

# %%
tot_비소비지출금액_2020 = dat_2020['비소비지출금액']
tot_비소비지출금액_mean_2020 = int(tot_비소비지출금액_2020.mean())
tot_비소비지출금액_per_2020 = (tot_비소비지출금액_mean_2020 / total_expend_mean_2020) * 100  # 전체가구 소비 중 비소비지출금액 소비 비율

print(tot_비소비지출금액_2020)
print(tot_비소비지출금액_mean_2020)
print(tot_비소비지출금액_per_2020)
# Out:
# 0          95073
# 1          87325
# 2         234295
# 3        1868423
# 4         465232
#           ...
# 12117    4176270
# 12118    1230790
# 12119    1335260
# 12120    1417340
# 12121       6370
# Name: 비소비지출금액, Length: 12122, dtype: int64
# 793526
# 34.58077145495517

# %% [markdown]
# 1인가구 비소비지출금액 평균소비 비용, 비율

# %%
sin_tot_비소비지출금액_2020 = dat_2020.loc[dat_2020['가구원수'] == 1, '비소비지출금액']
sin_tot_비소비지출금액_mean_2020 = int(sin_tot_비소비지출금액_2020.mean())
sin_tot_비소비지출금액_per_2020 = (sin_tot_비소비지출금액_mean_2020 / single_expend_mean_2020) * 100  # 1인가구 소비 중 비소비지출금액 소비 비율

print(sin_tot_비소비지출금액_2020)
print(sin_tot_비소비지출금액_mean_2020)
print(sin_tot_비소비지출금액_per_2020)
# Out:
# 0          95073
# 7          39728
# 11        124700
# 16       1415207
# 17       1194955
#           ...
# 12103      62500
# 12108     214129
# 12109     476454
# 12115      77323
# 12121       6370
# Name: 비소비지출금액, Length: 3615, dtype: int64
# 440684
# 34.75924777846662

# %%
print(f"전체가구 소비 중 비소비지출금액 소비지출, 비율: {tot_비소비지출금액_mean_2020:,}원 ({tot_비소비지출금액_per_2020:.2f}%)")
print(f"1인가구 소비 중 비소비지출금액 소비지출, 비율: {sin_tot_비소비지출금액_mean_2020:,}원 ({sin_tot_비소비지출금액_per_2020:.2f}%)")
# Out:
# 전체가구 소비 중 비소비지출금액 소비지출, 비율: 793,526원 (34.58%)
# 1인가구 소비 중 비소비지출금액 소비지출, 비율: 440,684원 (34.76%)

# %%
# 조건으로 검색하기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat = pd.read_csv("./data/2021_1인가구.csv", encoding='cp949') ; dat
dat_2021 = dat.copy()

# %%
## [데이터 필요한 행만 전처리]

dat_2021.rename(columns={
    '가계지출금액' : '전체소비지출','가계지출_소비지출금액' : '소비지출','가계지출_소비지출_식료품비주류음료구입비' : '식료품음료구입',
    '가계지출_소비지출_식료품비주류음료_곡물구입비' : '식료품_곡물구입','가계지출_소비지출_식료품비주류음료_곡물가공품구입비' : '식료품_곡물가공품구입',
    '가계지출_소비지출_식료품비주류음료_빵떡류구입비' : '식료품_빵떡류구입','가계지출_소비지출_식료품비주류음료_육류구입비' : '식료품_육류구입',
    '가계지출_소비지출_식료품비주류음료_육류가공품구입비' : '식료품_육류가공품구입','가계지출_소비지출_식료품비주류음료_신선수산동물구입비' : '식료품_신선수산동물구입',
    '가계지출_소비지출_식료품비주류음료_염건수산동물구입비' : '식료품_염건수산동물구입','가계지출_소비지출_식료품비주류음료_기타수산동물가공구입비' : '식료품_기타수산동물가공구입',
    '가계지출_소비지출_식료품비주류음료_유제품및알구입비' : '식료품_유제품알구입','가계지출_소비지출_식료품비주류음료_유지류구입비' : '식료품_유지류구입',
    '가계지출_소비지출_식료품비주류음료_과일가공품구입비' : '식료품_과일가공품구입','가계지출_소비지출_식료품비주류음료_채소가공품구입비' : '식료품_채소가공품구입',
    '가계지출_소비지출_식료품비주류음료_해조가공품구입비' : '식료품_해조가공품구입','가계지출_소비지출_식료품비주류음료_당류과자류구입비' : '식료품_당류과자류구입',
    '가계지출_소비지출_식료품비주류음료_조미식품구입비' : '식료품_조미식품구입','가계지출_소비지출_식료품비주류음료_기타식품구입비' : '식료품_기타식품구입',
    '가계지출_소비지출_식료품비주류음료_커피차구입비' : '식료품_커피차구입','가계지출_소비지출_식료품비주류음료_쥬스기타음료구입비' : '식료품_쥬스음료구입',
    '가계지출_소비지출_주류담배구입비' : '주류담배구입','가계지출_소비지출_주류담배_주류구입비' : '주류구입','가계지출_소비지출_주류담배_담배구입비' : '담배구입',
    '가계지출_소비지출_의류신발구입비' : '의류신발구입','가계지출_소비지출_의류신발_직물및외의구입비' : '의류신발_직물및외의구입','가계지출_소비지출_의류신발_내의구입비' : '의류신발_내의구입',
    '가계지출_소비지출_의류신발_기타의복구입비' : '의류신발_기타의복구입','가계지출_소비지출_의류신발_의복관련서비스구입비' : '의류신발_의복관련서비스구입',
    '가계지출_소비지출_의류신발_신발구입비' : '의류신발_신발구입','가계지출_소비지출_의류신발_신발서비스구입비' : '의류신발_신발서비스구입','가계지출_소비지출_주거수도광열비' : '주거수도광열비',
    '가계지출_소비지출_주거수도광열_실제주거비구입비' : '주거수도광열_실제주거비구입','가계지출_소비지출_주거수도광열_주택유지수선구입비' : '주거수도광열_주택유지수선구입',
    '가계지출_소비지출_주거수도광열_상하수도폐기물처리비' : '주거수도광열_상하수도폐기물처리','가계지출_소비지출_주거수도광열_기타주거관련서비스구입비' : '주거수도광열_기타주거관련서비스구입',
    '가계지출_소비지출_주거수도광열_연료비구입비' : '주거수도광열_연료비구입','가계지출_소비지출_가정용품가사서비스이용금액' : '가정용품가사서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가구조명구입비' : '가정용품가사서비스_가구조명구입','가계지출_소비지출_가정용품가사서비스_실내장식구입비' : '가정용품가사서비스_실내장식구입',
    '가계지출_소비지출_가정용품가사서비스_가구조명장식서비스이용금액' : '가정용품가사서비스_가구조명장식서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가정용섬유구입비' : '가정용품가사서비스_가정용섬유구입','가계지출_소비지출_가정용품가사서비스_가전가정용기기구입비' : '가정용품가사서비스_가전가정용기기구입',
    '가계지출_소비지출_가정용품가사서비스_가전관련서비스이용금액' : '가정용품가사서비스_가전관련서비스이용','가계지출_소비지출_가정용품가사서비스_가사용품구입비' : '가정용품가사서비스_가사용품구입',
    '가계지출_소비지출_가정용품가사서비스_가정용공구기타구입비' : '가정용품가사서비스_가정용공구기타구입','가계지출_소비지출_가정용품가사서비스_가사소모품구입비' : '가정용품가사서비스_가사소모품구입',
    '가계지출_소비지출_가정용품가사서비스_가사서비스금액' : '가정용품가사서비스_가사서비스','가계지출_소비지출_보건제품구입비' : '보건제품구입',
    '가계지출_소비지출_보건_의약품구입비' : '보건_의약품구입','가계지출_소비지출_보건_의료용소모품구입비' : '보건_의료용소모품구입',
    '가계지출_소비지출_보건_보건의료용품기구구입비' : '보건_보건의료용품기구구입','가계지출_소비지출_보건_외래의료서비스이용금액' : '보건_외래의료서비스이용',
    '가계지출_소비지출_보건_치과서비스이용금액' : '보건_치과서비스이용','가계지출_소비지출_보건_기타의료서비스이용금액' : '보건_기타의료서비스이용',
    '가계지출_소비지출_보건_입원서비스이용금액' : '보건_입원서비스이용','가계지출_소비지출_교통비' : '교통비','가계지출_소비지출_교통_자동차구입비' : '교통_자동차구입',
    '가계지출_소비지출_교통_기타운송기구구입비' : '교통_기타운송기구구입','가계지출_소비지출_교통_운송기구유지수리비' : '교통_운송기구유지수리',
    '가계지출_소비지출_교통_운송기구연료비' : '교통_운송기구연료','가계지출_소비지출_교통_기타개인교통서비스이용금액' : '교통_기타개인교통서비스이용',
    '가계지출_소비지출_교통_철도운송금액' : '교통_철도운송','가계지출_소비지출_교통_육상운송금액' : '교통_육상운송','가계지출_소비지출_교통_기타운송금액' : '교통_기타운송',
    '가계지출_소비지출_교통_기타교통관련서비스이용금액' : '교통_기타교통관련서비스이용','가계지출_소비지출_통신비' : '통신비','가계지출_소비지출_통신_우편서비스이용금액' : '통신_우편서비스이용',
    '가계지출_소비지출_통신_통신장비구입비' : '통신_통신장비구입','가계지출_소비지출_통신_통신서비스이용금액' : '통신_통신서비스이용','가계지출_소비지출_오락문화비' : '오락문화비',
    '가계지출_소비지출_오락문화_영상음향기기구입비' : '오락문화_영상음향기기구입','가계지출_소비지출_오락문화_사진광학장비구입비' : '오락문화_사진광학장비구입',
    '가계지출_소비지출_오락문화_정보처리장치구입비' : '오락문화_정보처리장치구입','가계지출_소비지출_오락문화_기록매체구입비' : '오락문화_기록매체구입',
    '가계지출_소비지출_오락문화_영상음향정보기기수리비' : '오락문화_영상음향정보기기수리','가계지출_소비지출_오락문화_내구재구입비' : '오락문화_내구재구입',
    '가계지출_소비지출_오락문화_악기기구구입비' : '오락문화_악기기구구입','가계지출_소비지출_오락문화_오락문화내구재유지수리비' : '오락문화_오락문화내구재유지수리',
    '가계지출_소비지출_오락문화_장난감취미용품구입비' : '오락문화_장난감취미용품구입','가계지출_소비지출_오락문화_캠핑운동관련용품구입비' : '오락문화_캠핑운동관련용품구입',
    '가계지출_소비지출_오락문화_화훼관련용품구입비' : '오락문화_화훼관련용품구입','가계지출_소비지출_오락문화_애완동물관련물품구입비' : '애완동물_물품구입',
    '가계지출_소비지출_오락문화_화훼애완동물서비스이용금액' : '애완동물_서비스이용','가계지출_소비지출_오락문화_운동오락서비스이용금액' : '운동오락_서비스이용',
    '가계지출_소비지출_오락문화_문화서비스이용금액' : '문화_서비스이용','가계지출_소비지출_오락문화_복권구입비' : '복권_구입비','가계지출_소비지출_오락문화_서적구입비' : '서적_구입비',
    '가계지출_소비지출_오락문화_기타인쇄물구입비' : '인쇄물_구입비','가계지출_소비지출_오락문화_문구구입비' : '문구_구입비','가계지출_소비지출_오락문화_단체여행경비' : '단체여행_경비',
    '가계지출_소비지출_교육비' : '교육비','가계지출_소비지출_교육_정규교육비' : '정규교육비','가계지출_소비지출_교육_초등교육비' : '초등교육비','가계지출_소비지출_교육_중등교육비' : '중등교육비',
    '가계지출_소비지출_교육_고등교육비' : '고등교육비','가계지출_소비지출_교육_학원보습교육비' : '학원보습교육비','가계지출_소비지출_교육_학생학원교육비' : '학생학원교육비',
    '가계지출_소비지출_교육_성인학원비' : '성인학원비','가계지출_소비지출_교육_기타교육비' : '기타교육비','가계지출_소비지출_음식숙박비' : '음식숙박비','가계지출_소비지출_음식숙박_식대' : '식대',
    '가계지출_소비지출_음식숙박_숙박비' : '숙박비','가계지출_소비지출_기타상품서비스이용금액' : '기타상품서비스이용','가계지출_소비지출_기타상품서비스_이미용서비스이용금액' : '이미용서비스이용',
    '가계지출_소비지출_기타상품서비스_이미용기기구입비' : '이미용기기구입','가계지출_소비지출_기타상품서비스_위생이미용용품구입비' : '위생이미용용품구입',
    '가계지출_소비지출_기타상품서비스_시계장신구구입비' : '시계장신구구입','가계지출_소비지출_기타상품서비스_기타개인용품구입비' : '기타개인용품구입',
    '가계지출_소비지출_기타상품서비스_복지시설비용금액' : '복지시설비용','가계지출_소비지출_기타상품서비스_보험료' : '보험료','가계지출_소비지출_기타상품서비스_기타금융구입비' : '기타금융구입',
    '가계지출_소비지출_기타상품서비스_기타서비스금액구입비' : '기타서비스금액구입','가계지출_비소비지출금액' : '비소비지출금액','가계지출_비소비지출_경상조세' : '비경상조세',
    '가계지출_비소비지출_비경상조세' : '비경상조세','가계지출_비소비지출_연금기여금' : '연금기여금','가계지출_비소비지출_사회보장구입비' : '사회보장구입비',
    '가계지출_비소비지출_이자비용' : '이자비용','가계지출_비소비지출_가구간이전지출금액' : '가구간이전지출금액','가계지출_비소비지출_비영리단체이전지출금액' : '비영리단체이전지출금액'
}, inplace=True
)

# %%
dat_2021.columns
# Out:
# Index(['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드',
#        '가구주_성별코드', '가구주_연령', '가구주_취업여부',
#        ...
#        '기타서비스금액구입', '비소비지출금액', '비경상조세', '비경상조세', '연금기여금', '사회보장구입비', '이자비용',
#        '가구간이전지출금액', '비영리단체이전지출금액', '도시읍면부구분코드'],
#       dtype='object', length=139)

# %%
# 행 전처리

dat_2021 = dat_2021[['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드', '가구주_성별코드', '가구주_연령', '가구주_취업여부', '거처구분코드',
                     '자동차보유대수','입주형태코드', '월세평가금액', '전세보증금', '소득구간코드', '전체소비지출', '소비지출','식료품음료구입','식료품_곡물구입',
                     '식료품_곡물가공품구입','식료품_빵떡류구입','식료품_육류구입','식료품_육류가공품구입','식료품_신선수산동물구입','식료품_염건수산동물구입','식료품_기타수산동물가공구입',
                     '식료품_유제품알구입','식료품_유지류구입','식료품_과일가공품구입','식료품_채소가공품구입','식료품_해조가공품구입','식료품_당류과자류구입','식료품_조미식품구입',
                     '식료품_기타식품구입','식료품_커피차구입','식료품_쥬스음료구입','주류담배구입','주류구입','담배구입','의류신발구입','의류신발_직물및외의구입','의류신발_내의구입',
                     '의류신발_기타의복구입','의류신발_의복관련서비스구입','의류신발_신발구입','의류신발_신발서비스구입','주거수도광열비','주거수도광열_실제주거비구입',
                     '주거수도광열_주택유지수선구입','주거수도광열_상하수도폐기물처리','주거수도광열_기타주거관련서비스구입','주거수도광열_연료비구입','가정용품가사서비스이용',
                     '가정용품가사서비스_가구조명구입','가정용품가사서비스_실내장식구입','가정용품가사서비스_가구조명장식서비스이용','가정용품가사서비스_가정용섬유구입',
                     '가정용품가사서비스_가전가정용기기구입','가정용품가사서비스_가전관련서비스이용','가정용품가사서비스_가사용품구입','가정용품가사서비스_가정용공구기타구입',
                     '가정용품가사서비스_가사소모품구입','가정용품가사서비스_가사서비스','보건제품구입','보건_의약품구입','보건_의료용소모품구입','보건_보건의료용품기구구입',
                     '보건_외래의료서비스이용','보건_치과서비스이용','보건_기타의료서비스이용','보건_입원서비스이용','교통비','교통_자동차구입','교통_기타운송기구구입','교통_운송기구유지수리',
                     '교통_운송기구연료','교통_기타개인교통서비스이용','교통_철도운송','교통_육상운송','교통_기타운송','교통_기타교통관련서비스이용','통신비','통신_우편서비스이용',
                     '통신_통신장비구입','통신_통신서비스이용','오락문화비','오락문화_영상음향기기구입','오락문화_사진광학장비구입','오락문화_정보처리장치구입','오락문화_기록매체구입',
                     '오락문화_영상음향정보기기수리','오락문화_내구재구입','오락문화_악기기구구입','오락문화_오락문화내구재유지수리','오락문화_장난감취미용품구입','오락문화_캠핑운동관련용품구입',
                     '오락문화_화훼관련용품구입','애완동물_물품구입','애완동물_서비스이용','운동오락_서비스이용','문화_서비스이용','복권_구입비','서적_구입비','인쇄물_구입비','문구_구입비',
                     '단체여행_경비','교육비','정규교육비','초등교육비','중등교육비','고등교육비','학원보습교육비','학생학원교육비','성인학원비','기타교육비','음식숙박비','식대','숙박비',
                     '기타상품서비스이용','이미용서비스이용','이미용기기구입','위생이미용용품구입','시계장신구구입','기타개인용품구입','복지시설비용','보험료','기타금융구입','기타서비스금액구입',
                     '비소비지출금액','비경상조세','비경상조세','연금기여금','사회보장구입비','이자비용','가구간이전지출금액','비영리단체이전지출금액']]

# %%
dat_2021['가구구분코드'] = dat_2021['가구구분코드'].replace({1: '근로자 가구', 2: '비근로자 가구'})
dat_2021['노인가구여부'] = dat_2021['노인가구여부'].replace({0: '아니요', 1: '예'})
dat_2021['배우자코드'] = dat_2021['배우자코드'].replace({1: '현재(동거)', 2: '현재(비동거)', 3:'부재'})
dat_2021['가구주_성별코드'] = dat_2021['가구주_성별코드'].replace({1: '남성', 2: '여성'})
dat_2021['가구주_취업여부'] = dat_2021['가구주_취업여부'].replace({1: '취업', 2: '실업자'})
dat_2021['거처구분코드'] = dat_2021['거처구분코드'].replace({1: '단독주택(다세대 포함)', 2: '아파트', 3: '연립주택', 4: '다가구주택', 5: '비주거용 건물', 6: '오피스텔', 7: '기타'})
dat_2021['입주형태코드'] = dat_2021['입주형태코드'].replace({1: '내 집', 2: '무료주택', 3: '회사주택', 4: '임대', 5: '영구임대', 6: '보증금 월세', 7: '보증금 없는 월세'})
dat_2021['소득구간코드'] = dat_2021['소득구간코드'].replace({1: '100만원 미만', 2: '100~200만원', 3: '200~300만원', 4: '300~400만원', 5: '400~500만원', 6: '500~600만원', 7: '600~700만원', 8: '700만원 이상'})
# dat_2021['도시읍면부구분코드'] = dat_2021['도시읍면부구분코드'].replace({0: '비도시', 1: '도시'})

# %%
dat_2021
# Out:
#          조사연월  가구일련번호   가구구분코드  가구원수  취업인원수 노인가구여부   배우자코드 가구주_성별코드  가구주_연령  \
# 0      202100       1   근로자 가구     3      3    아니요  현재(동거)       남성      51
# 1      202100       2  비근로자 가구     3      3    아니요      부재       여성      57
# 2      202100       3   근로자 가구     2      1    아니요  현재(동거)       남성      27
# 3      202100       4   근로자 가구     1      1    아니요      부재       남성      30
# 4      202100       5   근로자 가구     1      1    아니요      부재       여성      37
# ...       ...     ...      ...   ...    ...    ...     ...      ...     ...
# 12386  202100   12387   근로자 가구     3      2    아니요  현재(동거)       남성      43
# 12387  202100   12388   근로자 가구     3      2    아니요  현재(동거)       남성      37
# 12388  202100   12389   근로자 가구     2      1    아니요  현재(동거)       남성      51
# 12389  202100   12390  비근로자 가구     2      2      예  현재(동거)       남성      65
# 12390  202100   12391   근로자 가구     2      2    아니요  현재(동거)       남성      52
#
# ...

# %%
def age(가구주_연령):
    if 가구주_연령 < 20:
        return '10대'
    elif 20 <= 가구주_연령 < 30:
        return '20대'
    elif 30 <= 가구주_연령 < 40:
        return '30대'
    elif 40 <= 가구주_연령 < 50:
        return '40대'
    elif 50 <= 가구주_연령 < 60:
        return '50대'
    elif 60 <= 가구주_연령 < 70:
        return '60대'
    elif 70 <= 가구주_연령:
        return '70대 이상'

# 데이터 연령대별 구분
dat_2021.loc[:,'연령대'] = dat_2021['가구주_연령'].apply(age)
dat_2021.연령대
# Out:
# 0        50대
# 1        50대
# 2        20대
# 3        30대
# 4        30대
#         ...
# 12386    40대
# 12387    30대
# 12388    50대
# 12389    60대
# 12390    50대
# Name: 연령대, Length: 12391, dtype: object

# %%
# 연령대별 가구원 수 분포
dat_2021.groupby('연령대')['가구원수'].value_counts().unstack().fillna(0).astype(int)
# Out:
# 가구원수      1     2    3    4    5   6  7  8
# 연령대
# 10대      12     0    0    0    0   0  0  0
# 20대     528   138   36    7    2   1  0  0
# 30대     563   346  336  297   44  10  1  0
# 40대     403   392  534  758  188  26  4  1
# 50대     595   913  700  438   72   7  1  1
# 60대     736  1388  430  119   22   7  1  0
# 70대 이상  939  1237  126   19   10   3  0  0

# %% [markdown]
# ##### 전체가구 지출 (total_expend) | 1인가구 지출 (single_expend )

# %% [markdown]
# 전체가구 소비지출

# %% [markdown]
# box plot 그려서 분포 확인해봐야 함

# %%
total_expend_2021 = dat_2021['소비지출']

total_expend_2021.info # 전체가구 소비지출
# Out:
# <bound method Series.info of 0         2836079
# 1         2508842
# 2         1309204
# 3         1519135
# 4         1835615
#            ...
# 12386     3484296
# 12387     2874832
# 12388     3264042
# 12389     3810289
# 12390    15702022
# Name: 소비지출, Length: 12391, dtype: int64>

# %% [markdown]
# --2차 전처리--
#
# 전체가구 소비지출 이상치확인 (9,510개중 6,730개) <2,780개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(total_expend_2021, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(total_expend_2021, 25)
Q3 = np.percentile(total_expend_2021, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(total_expend_2021), f'Median: {np.median(total_expend_2021):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(total_expend_2021):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(total_expend_2021):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('전체가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_total_expend_2021 = ((total_expend_2021 >= lower_limit) & (total_expend_2021 <= upper_limit))
total_expend_2021[cleaned_total_expend_2021]
# Out:
# 0        2836079
# 1        2508842
# 2        1309204
# 3        1519135
# 4        1835615
#           ...
# 12385    2313811
# 12386    3484296
# 12387    2874832
# 12388    3264042
# 12389    3810289
# Name: 소비지출, Length: 11847, dtype: int64

# %%
# 이상치 제거
cleaned_total_expend_2021 = total_expend_2021[(total_expend_2021 >= lower_limit) & (total_expend_2021 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_total_expend_2021, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_total_expend_2021, 25)
Q3 = np.percentile(cleaned_total_expend_2021, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_total_expend_2021), f'Median: {np.median(cleaned_total_expend_2021):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_total_expend_2021):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_total_expend_2021):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('전체가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 전체가구 평균 소비지출
total_expend_mean_2021 = int(total_expend_2021.mean())
print(f"전체가구의 평균 소비지출: {total_expend_mean_2021:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,379,894원

# %%
# 전체가구 평균 소비지출 이상치 제거 후
cleaned_total_expend_mean_2021 = int(cleaned_total_expend_2021.mean())
print(f"전체가구의 평균 소비지출: {cleaned_total_expend_mean_2021:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,105,662원

# %% [markdown]
# 1인가구 소비지출

# %%
# 가구원수 1로 설정하여 9510개에서 2827개의 데이터 전처리

single_expend_2021 = dat_2021.loc[dat['가구원수'] == 1, '소비지출']

single_expend_2021.info # 1인가구 소비지출
# Out:
# <bound method Series.info of 3        1519135
# 4        1835615
# 5        1724898
# 7        1281383
# 19       2095606
#           ...
# 12369    1329498
# 12370     792687
# 12373     309390
# 12377     513738
# 12385    2313811
# Name: 소비지출, Length: 3776, dtype: int64>

# %%
# 1인가구 이상치 식별
(single_expend_2021 < lower_limit) & (single_expend_2021 > upper_limit)
# Out:
# 3        False
# 4        False
# 5        False
# 7        False
# 19       False
#          ...
# 12369    False
# 12370    False
# 12373    False
# 12377    False
# 12385    False
# Name: 소비지출, Length: 3776, dtype: bool

# %% [markdown]
# -- 2차전처리 --
#
# * 1인가구 소비지출 이상치확인 (2827개중 2701개) <126개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(single_expend_2021, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(single_expend_2021, 25)
Q3 = np.percentile(single_expend_2021, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(single_expend_2021), f'Median: {np.median(total_expend_2021):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(single_expend_2021):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(single_expend_2021):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('1인가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_single_expend_2021 = ((single_expend_2021 >= lower_limit) & (single_expend_2021 <= upper_limit))
single_expend_2021[cleaned_single_expend_2021]
# Out:
# 3        1519135
# 4        1835615
# 5        1724898
# 7        1281383
# 19       2095606
#           ...
# 12369    1329498
# 12370     792687
# 12373     309390
# 12377     513738
# 12385    2313811
# Name: 소비지출, Length: 3619, dtype: int64

# %%
# 이상치 제거
cleaned_single_expend_2021 = single_expend_2021[(single_expend_2021 >= lower_limit) & (single_expend_2021 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_single_expend_2021, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_single_expend_2021, 25)
Q3 = np.percentile(cleaned_single_expend_2021, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_single_expend_2021), f'Median: {np.median(cleaned_single_expend_2021):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_single_expend_2021):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_single_expend_2021):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('1인가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 1인가구 평균 소비지출
single_expend_mean_2021 = int(single_expend_2021.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {single_expend_mean_2021:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,360,988원

# %%
# 1인가구 평균 소비지출 이상치 제거 후
cleaned_single_expend_mean_2021 = int(cleaned_single_expend_2021.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {cleaned_single_expend_mean_2021:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,223,621원

# %% [markdown]
# 전체가구 식료품음료구입 평균소비 비용, 비율

# %%
tot_식료품음료구입_2021 = dat_2021['식료품음료구입']
tot_식료품음료구입_mean_2021 = int(tot_식료품음료구입_2021.mean())
tot_식료품음료구입_per_2021 = (tot_식료품음료구입_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 식료품음료구입 소비 비율

print(tot_식료품음료구입_2021)
print(tot_식료품음료구입_mean_2021)
print(tot_식료품음료구입_per_2021)
# Out:
# 0        383850
# 1        523663
# 2        362020
# 3         45020
# 4        381768
#           ...
# 12386    439167
# 12387    434323
# 12388    380222
# 12389    694372
# 12390    782715
# Name: 식료품음료구입, Length: 12391, dtype: int64
# 388651
# 16.33060127888049

# %% [markdown]
# 1인가구 식료품음료구입 평균소비 비용, 비율

# %%
sin_tot_식료품음료구입_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '식료품음료구입']
sin_tot_식료품음료구입_mean_2021 = int(sin_tot_식료품음료구입_2021.mean())
sin_tot_식료품음료구입_per_2021 = (sin_tot_식료품음료구입_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 식료품음료구입 소비 비율

print(sin_tot_식료품음료구입_2021)
print(sin_tot_식료품음료구입_mean_2021)
print(sin_tot_식료품음료구입_per_2021)
# Out:
# 3         45020
# 4        381768
# 5         88605
# 7         37527
# 19       224620
#           ...
# 12369    170480
# 12370    175483
# 12373    116085
# 12377    301018
# 12385    329982
# Name: 식료품음료구입, Length: 3776, dtype: int64
# 204345
# 15.014460083409995

# %%
print(f"전체가구 소비 중 식료품음료구입 소비지출, 비율: {tot_식료품음료구입_mean_2021:,}원 ({tot_식료품음료구입_per_2021:.2f}%)")
print(f"1인가구 소비 중 식료품음료구입 소비지출, 비율: {sin_tot_식료품음료구입_mean_2021:,}원 ({sin_tot_식료품음료구입_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 식료품음료구입 소비지출, 비율: 388,651원 (16.33%)
# 1인가구 소비 중 식료품음료구입 소비지출, 비율: 204,345원 (15.01%)

# %% [markdown]
# 전체가구 주류담배구입 평균소비 비용, 비율

# %%
tot_주류담배구입_2021 = dat_2021['주류담배구입']
tot_주류담배구입_mean_2021 = int(tot_주류담배구입_2021.mean())
tot_주류담배구입_per_2021 = (tot_주류담배구입_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 주류담배구입 소비 비율

print(tot_주류담배구입_2021)
print(tot_주류담배구입_mean_2021)
print(tot_주류담배구입_per_2021)
# Out:
# 0             0
# 1             0
# 2         17050
# 3        133904
# 4             0
#           ...
# 12386    133127
# 12387     30577
# 12388     22942
# 12389    170490
# 12390    229288
# Name: 주류담배구입, Length: 12391, dtype: int64
# 37719
# 1.5849025208685765

# %% [markdown]
# 1인가구 주류담배구입 평균소비 비용, 비율

# %%
sin_tot_주류담배구입_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '주류담배구입']
sin_tot_주류담배구입_mean_2021 = int(sin_tot_주류담배구입_2021.mean())
sin_tot_주류담배구입_per_2021 = (sin_tot_주류담배구입_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 주류담배구입 소비 비율

print(sin_tot_주류담배구입_2021)
print(sin_tot_주류담배구입_mean_2021)
print(sin_tot_주류담배구입_per_2021)
# Out:
# 3        133904
# 4             0
# 5         67668
# 7        147422
# 19       105900
#           ...
# 12369     95167
# 12370     87750
# 12373         0
# 12377      6322
# 12385      7878
# Name: 주류담배구입, Length: 3776, dtype: int64
# 31483
# 2.313245965430996

# %%
print(f"전체가구 소비 중 주류담배구입 소비지출, 비율: {tot_주류담배구입_mean_2021:,}원 ({tot_주류담배구입_per_2021:.2f}%)")
print(f"1인가구 소비 중 주류담배구입 소비지출, 비율: {sin_tot_주류담배구입_mean_2021:,}원 ({sin_tot_주류담배구입_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 주류담배구입 소비지출, 비율: 37,719원 (1.58%)
# 1인가구 소비 중 주류담배구입 소비지출, 비율: 31,483원 (2.31%)

# %% [markdown]
# 전체가구 의류신발구입 평균소비 비용, 비율

# %%
tot_의류신발구입_2021 = dat_2021['의류신발구입']
tot_의류신발구입_mean_2021 = int(tot_의류신발구입_2021.mean())
tot_의류신발구입_per_2021 = (tot_의류신발구입_mean_2021/ total_expend_mean_2021) * 100  # 전체가구 소비 중 의류신발구입 소비 비율

print(tot_의류신발구입_2021)
print(tot_의류신발구입_mean_2021)
print(tot_의류신발구입_per_2021)
# Out:
# 0        198000
# 1         20800
# 2             0
# 3        191806
# 4        121183
#           ...
# 12386    122713
# 12387     78042
# 12388    484655
# 12389    180272
# 12390    111572
# Name: 의류신발구입, Length: 12391, dtype: int64
# 117356
# 4.931143992127381

# %% [markdown]
# 1인가구 의류신발구입 평균소비 비용, 비율

# %%
sin_tot_의류신발구입_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '의류신발구입']
sin_tot_의류신발구입_mean_2021 = int(sin_tot_의류신발구입_2021.mean())
sin_tot_의류신발구입_per_2021 = (sin_tot_의류신발구입_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 의류신발구입 소비 비율

print(sin_tot_의류신발구입_2021)
print(sin_tot_의류신발구입_mean_2021)
print(sin_tot_의류신발구입_per_2021)
# Out:
# 3        191806
# 4        121183
# 5        110047
# 7         64847
# 19        90000
#           ...
# 12369     43467
# 12370      6667
# 12373     10493
# 12377     32500
# 12385     74817
# Name: 의류신발구입, Length: 3776, dtype: int64
# 62391
# 4.584243211549257

# %%
print(f"전체가구 소비 중 의류신발구입 소비지출, 비율: {tot_의류신발구입_mean_2021:,}원 ({tot_의류신발구입_per_2021:.2f}%)")
print(f"1인가구 소비 중 의류신발구입 소비지출, 비율: {sin_tot_의류신발구입_mean_2021:,}원 ({sin_tot_의류신발구입_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 의류신발구입 소비지출, 비율: 117,356원 (4.93%)
# 1인가구 소비 중 의류신발구입 소비지출, 비율: 62,391원 (4.58%)

# %% [markdown]
# 전체가구 주거수도광열비 평균소비 비용, 비율

# %%
tot_주거수도광열비_2021 = dat_2021['주거수도광열비']
tot_주거수도광열비_mean_2021 = int(tot_주거수도광열비_2021.mean())
tot_주거수도광열비_per_2021 = (tot_주거수도광열비_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 주거수도광열비 소비 비율

print(tot_주거수도광열비_2021)
print(tot_주거수도광열비_mean_2021)
print(tot_주거수도광열비_per_2021)
# Out:
# 0        128900
# 1        877600
# 2         59780
# 3        385642
# 4         77895
#           ...
# 12386    154380
# 12387    143783
# 12388     76152
# 12389    254547
# 12390    201812
# Name: 주거수도광열비, Length: 12391, dtype: int64
# 292074
# 12.272563399882516

# %% [markdown]
# 1인가구 주거수도광열비 평균소비 비용, 비율

# %%
sin_tot_주거수도광열비_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '주거수도광열비']
sin_tot_주거수도광열비_mean_2021 = int(sin_tot_주거수도광열비_2021.mean())
sin_tot_주거수도광열비_per_2021 = (sin_tot_주거수도광열비_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 주거수도광열비 소비 비율

print(sin_tot_주거수도광열비_2021)
print(sin_tot_주거수도광열비_mean_2021)
print(sin_tot_주거수도광열비_per_2021)
# Out:
# 3        385642
# 4         77895
# 5        585440
# 7        234650
# 19       955800
#           ...
# 12369    224500
# 12370     75050
# 12373     65303
# 12377     14816
# 12385    347165
# Name: 주거수도광열비, Length: 3776, dtype: int64
# 257078
# 18.889071762572485

# %%
print(f"전체가구 소비 중 주거수도광열비 소비지출, 비율: {tot_주거수도광열비_mean_2021:,}원 ({tot_주거수도광열비_per_2021:.2f}%)")
print(f"1인가구 소비 중 주거수도광열비 소비지출, 비율: {sin_tot_주거수도광열비_mean_2021:,}원 ({sin_tot_주거수도광열비_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 주거수도광열비 소비지출, 비율: 292,074원 (12.27%)
# 1인가구 소비 중 주거수도광열비 소비지출, 비율: 257,078원 (18.89%)

# %% [markdown]
# 전체가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
tot_가정용품가사서비스이용_2021 = dat_2021['가정용품가사서비스이용']
tot_가정용품가사서비스이용_mean_2021 = int(tot_가정용품가사서비스이용_2021.mean())
tot_가정용품가사서비스이용_per_2021 = (tot_가정용품가사서비스이용_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 가정용품가사서비스이용 소비 비율

print(tot_가정용품가사서비스이용_2021)
print(tot_가정용품가사서비스이용_mean_2021)
print(tot_가정용품가사서비스이용_per_2021)
# Out:
# 0         34100
# 1         18220
# 2         22390
# 3          3192
# 4        233152
#           ...
# 12386    142898
# 12387    150767
# 12388    237977
# 12389    245327
# 12390     86345
# Name: 가정용품가사서비스이용, Length: 12391, dtype: int64
# 128857
# 5.414400809447815

# %% [markdown]
# 1인가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
sin_tot_가정용품가사서비스이용_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '가정용품가사서비스이용']
sin_tot_가정용품가사서비스이용_mean_2021 = int(sin_tot_가정용품가사서비스이용_2021.mean())
sin_tot_가정용품가사서비스이용_per_2021 = (sin_tot_가정용품가사서비스이용_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 가정용품가사서비스이용 소비 비율

print(sin_tot_가정용품가사서비스이용_2021)
print(sin_tot_가정용품가사서비스이용_mean_2021)
print(sin_tot_가정용품가사서비스이용_per_2021)
# Out:
# 3          3192
# 4        233152
# 5         17167
# 7         15825
# 19        28850
#           ...
# 12369     27165
# 12370     28467
# 12373     12985
# 12377      8227
# 12385     47963
# Name: 가정용품가사서비스이용, Length: 3776, dtype: int64
# 64682
# 4.752576804497909

# %%
print(f"전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {tot_가정용품가사서비스이용_mean_2021:,}원 ({tot_가정용품가사서비스이용_per_2021:.2f}%)")
print(f"1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {sin_tot_가정용품가사서비스이용_mean_2021:,}원 ({sin_tot_가정용품가사서비스이용_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 128,857원 (5.41%)
# 1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 64,682원 (4.75%)

# %% [markdown]
# 전체가구 보건제품구입 평균소비 비용, 비율

# %%
tot_보건제품구입_2021 = dat_2021['보건제품구입']
tot_보건제품구입_mean_2021 = int(tot_보건제품구입_2021.mean())
tot_보건제품구입_per_2021 = (tot_보건제품구입_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 보건제품구입 소비 비율

print(tot_보건제품구입_2021)
print(tot_보건제품구입_mean_2021)
print(tot_보건제품구입_per_2021)
# Out:
# 0        279100
# 1         86870
# 2             0
# 3        141947
# 4        167895
#           ...
# 12386    257318
# 12387     17330
# 12388    104682
# 12389    327833
# 12390    285255
# Name: 보건제품구입, Length: 12391, dtype: int64
# 223207
# 9.378863092221755

# %% [markdown]
# 1인가구 보건제품구입 평균소비 비용, 비율

# %%
sin_tot_보건제품구입_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '보건제품구입']
sin_tot_보건제품구입_mean_2021 = int(sin_tot_보건제품구입_2021.mean())
sin_tot_보건제품구입_per_2021 = (sin_tot_보건제품구입_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 보건제품구입 소비 비율

print(sin_tot_보건제품구입_2021)
print(sin_tot_보건제품구입_mean_2021)
print(sin_tot_보건제품구입_per_2021)
# Out:
# 3        141947
# 4        167895
# 5         55118
# 7         44327
# 19            0
#           ...
# 12369    545550
# 12370     82500
# 12373     74983
# 12377     42250
# 12385    985233
# Name: 보건제품구입, Length: 3776, dtype: int64
# 121820
# 8.95085041161274

# %%
print(f"전체가구 소비 중 보건제품구입 소비지출, 비율: {tot_보건제품구입_mean_2021:,}원 ({tot_보건제품구입_per_2021:.2f}%)")
print(f"1인가구 소비 중 보건제품구입 소비지출, 비율: {sin_tot_보건제품구입_mean_2021:,}원 ({sin_tot_보건제품구입_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 보건제품구입 소비지출, 비율: 223,207원 (9.38%)
# 1인가구 소비 중 보건제품구입 소비지출, 비율: 121,820원 (8.95%)

# %% [markdown]
# 전체가구 교통비 평균소비 비용, 비율

# %%
tot_교통비_2021 = dat_2021['교통비']
tot_교통비_mean_2021 = int(tot_교통비_2021.mean())
tot_교통비_per_2021 = (tot_교통비_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 교통비 소비 비율

print(tot_교통비_2021)
print(tot_교통비_mean_2021)
print(tot_교통비_per_2021)
# Out:
# 0          439200
# 1          289160
# 2          138674
# 3          174584
# 4          158025
#            ...
# 12386      430947
# 12387      343757
# 12388      464020
# 12389      578775
# 12390    12571688
# Name: 교통비, Length: 12391, dtype: int64
# 286067
# 12.020157200278668

# %% [markdown]
# 1인가구 교통비 평균소비 비용, 비율

# %%
sin_tot_교통비_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '교통비']
sin_tot_교통비_mean_2021 = int(sin_tot_교통비_2021.mean())
sin_tot_교통비_per_2021 = (sin_tot_교통비_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 교통비 소비 비율

print(sin_tot_교통비_2021)
print(sin_tot_교통비_mean_2021)
print(sin_tot_교통비_per_2021)
# Out:
# 3        174584
# 4        158025
# 5         46567
# 7        130445
# 19        30000
#           ...
# 12369      4742
# 12370     76667
# 12373         0
# 12377     13350
# 12385     54483
# Name: 교통비, Length: 3776, dtype: int64
# 144317
# 10.603840739227678

# %% [markdown]
# 전체가구 통신비 평균소비 비용, 비율

# %%
tot_통신비_2021 = dat_2021['통신비']
tot_통신비_mean_2021 = int(tot_통신비_2021.mean())
tot_통신비_per_2021 = (tot_통신비_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 통신비 소비 비율

print(tot_통신비_2021)
print(tot_통신비_mean_2021)
print(tot_통신비_per_2021)
# Out:
# 0        163762
# 1         88989
# 2         93390
# 3             0
# 4         61907
#           ...
# 12386    118679
# 12387     93672
# 12388    388939
# 12389    121094
# 12390    134914
# Name: 통신비, Length: 12391, dtype: int64
# 114891
# 4.827567950505358

# %% [markdown]
# 1인가구 통신비 평균소비 비용, 비율

# %%
sin_tot_통신비_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '통신비']
sin_tot_통신비_mean_2021 = int(sin_tot_통신비_2021.mean())
sin_tot_통신비_per_2021 = (sin_tot_통신비_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 통신비 소비 비율

print(sin_tot_통신비_2021)
print(sin_tot_통신비_mean_2021)
print(sin_tot_통신비_per_2021)
# Out:
# 3             0
# 4         61907
# 5        213523
# 7         88952
# 19        78299
#           ...
# 12369     43090
# 12370     24641
# 12373      4373
# 12377     29239
# 12385     29948
# Name: 통신비, Length: 3776, dtype: int64
# 59044
# 4.338318927132348

# %% [markdown]
# 전체가구 오락문화비 평균소비 비용, 비율

# %%
tot_오락문화비_2021 = dat_2021['오락문화비']
tot_오락문화비_mean_2021 = int(tot_오락문화비_2021.mean())
tot_오락문화비_per_2021 = (tot_오락문화비_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 오락문화비 소비 비율

print(tot_오락문화비_2021)
print(tot_오락문화비_mean_2021)
print(tot_오락문화비_per_2021)
# Out:
# 0         81361
# 1         97830
# 2        257200
# 3         15141
# 4        104555
#           ...
# 12386    136095
# 12387    522965
# 12388    334736
# 12389     99870
# 12390    465679
# Name: 오락문화비, Length: 12391, dtype: int64
# 130236
# 5.472344566606748

# %% [markdown]
# 1인가구 오락문화비 평균소비 비용, 비율

# %%
sin_tot_오락문화비_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '오락문화비']
sin_tot_오락문화비_mean_2021 = int(sin_tot_오락문화비_2021.mean())
sin_tot_오락문화비_per_2021 = (sin_tot_오락문화비_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 오락문화비 소비 비율

print(sin_tot_오락문화비_2021)
print(sin_tot_오락문화비_mean_2021)
print(sin_tot_오락문화비_per_2021)
# Out:
# 3         15141
# 4        104555
# 5        224603
# 7        135231
# 19        53500
#           ...
# 12369     28767
# 12370     17740
# 12373      2833
# 12377     11800
# 12385     27073
# Name: 오락문화비, Length: 3776, dtype: int64
# 80112
# 5.886312002750943

# %%
print(f"전체가구 소비 중 오락문화비 소비지출, 비율: {tot_오락문화비_mean_2021:,}원 ({tot_오락문화비_per_2021:.2f}%)")
print(f"1인가구 소비 중 오락문화비 소비지출, 비율: {sin_tot_오락문화비_mean_2021:,}원 ({sin_tot_오락문화비_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 오락문화비 소비지출, 비율: 130,236원 (5.47%)
# 1인가구 소비 중 오락문화비 소비지출, 비율: 80,112원 (5.89%)

# %% [markdown]
# 전체가구 교육비 평균소비 비용, 비율

# %%
tot_교육비_2021 = dat_2021['교육비']
tot_교육비_mean_2021 = int(tot_교육비_2021.mean())
tot_교육비_per_2021 = (tot_교육비_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 교육비 소비 비율

print(tot_교육비_2021)
print(tot_교육비_mean_2021)
print(tot_교육비_per_2021)
# Out:
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
#           ...
# 12386    303000
# 12387    165833
# 12388     50000
# 12389         0
# 12390         0
# Name: 교육비, Length: 12391, dtype: int64
# 148275
# 6.230319501624862

# %% [markdown]
# 1인가구 교육비 평균소비 비용, 비율

# %%
sin_tot_교육비_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '교육비']
sin_tot_교육비_mean_2021 = int(sin_tot_교육비_2021.mean())
sin_tot_교육비_per_2021 = (sin_tot_교육비_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 교육비 소비 비율

print(sin_tot_교육비_2021)
print(sin_tot_교육비_mean_2021)
print(sin_tot_교육비_per_2021)
# Out:
# 3        0
# 4        0
# 5        0
# 7        0
# 19       0
#         ..
# 12369    0
# 12370    0
# 12373    0
# 12377    0
# 12385    0
# Name: 교육비, Length: 3776, dtype: int64
# 16504
# 1.2126484583258632

# %%
print(f"전체가구 소비 중 교육비 소비지출, 비율: {tot_교육비_mean_2021:,}원 ({tot_교육비_per_2021:.2f}%)")
print(f"1인가구 소비 중 교육비 소비지출, 비율: {sin_tot_교육비_mean_2021:,}원 ({sin_tot_교육비_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 교육비 소비지출, 비율: 148,275원 (6.23%)
# 1인가구 소비 중 교육비 소비지출, 비율: 16,504원 (1.21%)

# %% [markdown]
# 전체가구 음식숙박비 평균소비 비용, 비율

# %%
tot_음식숙박비_2021 = dat_2021['음식숙박비']
tot_음식숙박비_mean_2021 = int(tot_음식숙박비_2021.mean())
tot_음식숙박비_per_2021 = (tot_음식숙박비_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 음식숙박비 소비 비율

print(tot_음식숙박비_2021)
print(tot_음식숙박비_mean_2021)
print(tot_음식숙박비_per_2021)
# Out:
# 0        497000
# 1        387900
# 2        142000
# 3        282319
# 4        232593
#           ...
# 12386    878937
# 12387    627067
# 12388    513337
# 12389    601800
# 12390    577467
# Name: 음식숙박비, Length: 12391, dtype: int64
# 310994
# 13.067556790344446

# %% [markdown]
# 1인가구 음식숙박비 평균소비 비용, 비율

# %%
sin_tot_음식숙박비_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '음식숙박비']
sin_tot_음식숙박비_mean_2021 = int(sin_tot_음식숙박비_2021.mean())
sin_tot_음식숙박비_per_2021 = (sin_tot_음식숙박비_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 음식숙박비 소비 비율

print(sin_tot_음식숙박비_2021)
print(sin_tot_음식숙박비_mean_2021)
print(sin_tot_음식숙박비_per_2021)
# Out:
# 3        282319
# 4        232593
# 5        292975
# 7        359148
# 19       395910
#           ...
# 12369    107692
# 12370    107000
# 12373      1167
# 12377     28833
# 12385    253833
# Name: 음식숙박비, Length: 3776, dtype: int64
# 211781
# 15.560827869165635

# %%
print(f"전체가구 소비 중 음식숙박비 소비지출, 비율: {tot_음식숙박비_mean_2021:,}원 ({tot_음식숙박비_per_2021:.2f}%)")
print(f"1인가구 소비 중 음식숙박비 소비지출, 비율: {sin_tot_음식숙박비_mean_2021:,}원 ({sin_tot_음식숙박비_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 음식숙박비 소비지출, 비율: 310,994원 (13.07%)
# 1인가구 소비 중 음식숙박비 소비지출, 비율: 211,781원 (15.56%)

# %% [markdown]
# 전체가구 기타상품서비스이용 평균소비 비용, 비율

# %%
tot_기타상품서비스이용_2021 = dat_2021['기타상품서비스이용']
tot_기타상품서비스이용_mean_2021 = int(tot_기타상품서비스이용_2021.mean())
tot_기타상품서비스이용_per_2021 = (tot_기타상품서비스이용_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 기타상품서비스이용 소비 비율

print(tot_기타상품서비스이용_2021)
print(tot_기타상품서비스이용_mean_2021)
print(tot_기타상품서비스이용_per_2021)
# Out:
# 0        630806
# 1        117810
# 2        216700
# 3        145580
# 4        296642
#           ...
# 12386    367036
# 12387    266717
# 12388    206383
# 12389    535910
# 12390    255287
# Name: 기타상품서비스이용, Length: 12391, dtype: int64
# 201562
# 8.469368803820675

# %% [markdown]
# 1인가구 기타상품서비스이용 평균소비 비용, 비율

# %%
sin_tot_기타상품서비스이용_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '기타상품서비스이용']
sin_tot_기타상품서비스이용_mean_2021 = int(sin_tot_기타상품서비스이용_2021.mean())
sin_tot_기타상품서비스이용_per_2021 = (sin_tot_기타상품서비스이용_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 기타상품서비스이용 소비 비율

print(sin_tot_기타상품서비스이용_2021)
print(sin_tot_기타상품서비스이용_mean_2021)
print(sin_tot_기타상품서비스이용_per_2021)
# Out:
# 3        145580
# 4        296642
# 5         23187
# 7         23010
# 19       132727
#           ...
# 12369     38880
# 12370    110723
# 12373     21167
# 12377     25383
# 12385    155435
# Name: 기타상품서비스이용, Length: 3776, dtype: int64
# 107427
# 7.893309860189804

# %%
print(f"전체가구 소비 중 기타상품서비스이용 소비지출, 비율: {tot_기타상품서비스이용_mean_2021:,}원 ({tot_기타상품서비스이용_per_2021:.2f}%)")
print(f"1인가구 소비 중 기타상품서비스이용 소비지출, 비율: {sin_tot_기타상품서비스이용_mean_2021:,}원 ({sin_tot_기타상품서비스이용_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 기타상품서비스이용 소비지출, 비율: 201,562원 (8.47%)
# 1인가구 소비 중 기타상품서비스이용 소비지출, 비율: 107,427원 (7.89%)

# %% [markdown]
# 전체가구 비소비지출금액 평균소비 비용, 비율

# %%
tot_비소비지출금액_2021 = dat_2021['비소비지출금액']
tot_비소비지출금액_mean_2021 = int(tot_비소비지출금액_2021.mean())
tot_비소비지출금액_per_2021 = (tot_비소비지출금액_mean_2021 / total_expend_mean_2021) * 100  # 전체가구 소비 중 비소비지출금액 소비 비율

print(tot_비소비지출금액_2021)
print(tot_비소비지출금액_mean_2021)
print(tot_비소비지출금액_per_2021)
# Out:
# 0        1501096
# 1        1466245
# 2         674190
# 3          59038
# 4         393095
#           ...
# 12386    1291748
# 12387    1068047
# 12388    1577490
# 12389    2399282
# 12390    3060138
# Name: 비소비지출금액, Length: 12391, dtype: int64
# 820709
# 34.48510731990584

# %% [markdown]
# 1인가구 비소비지출금액 평균소비 비용, 비율

# %%
sin_tot_비소비지출금액_2021 = dat_2021.loc[dat_2021['가구원수'] == 1, '비소비지출금액']
sin_tot_비소비지출금액_mean_2021 = int(sin_tot_비소비지출금액_2021.mean())
sin_tot_비소비지출금액_per_2021 = (sin_tot_비소비지출금액_mean_2021 / single_expend_mean_2021) * 100  # 1인가구 소비 중 비소비지출금액 소비 비율

print(sin_tot_비소비지출금액_2021)
print(sin_tot_비소비지출금액_mean_2021)
print(sin_tot_비소비지출금액_per_2021)
# Out:
# 3          59038
# 4         393095
# 5         517001
# 7          18700
# 19       1123073
#           ...
# 12369      33333
# 12370      90147
# 12373     243333
# 12377     171655
# 12385     132632
# Name: 비소비지출금액, Length: 3776, dtype: int64
# 469837
# 34.52175919258656

# %%
print(f"전체가구 소비 중 비소비지출금액 소비지출, 비율: {tot_비소비지출금액_mean_2021:,}원 ({tot_비소비지출금액_per_2021:.2f}%)")
print(f"1인가구 소비 중 비소비지출금액 소비지출, 비율: {sin_tot_비소비지출금액_mean_2021:,}원 ({sin_tot_비소비지출금액_per_2021:.2f}%)")
# Out:
# 전체가구 소비 중 비소비지출금액 소비지출, 비율: 820,709원 (34.49%)
# 1인가구 소비 중 비소비지출금액 소비지출, 비율: 469,837원 (34.52%)

# %%
# 조건으로 검색하기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat = pd.read_csv("./data/2022_1인가구.csv", encoding='cp949') ; dat
dat_2022 = dat.copy()

# %%
## [데이터 필요한 행만 전처리]

dat_2022.rename(columns={
    '가계지출금액' : '전체소비지출','가계지출_소비지출금액' : '소비지출','가계지출_소비지출_식료품비주류음료구입비' : '식료품음료구입',
    '가계지출_소비지출_식료품비주류음료_곡물구입비' : '식료품_곡물구입','가계지출_소비지출_식료품비주류음료_곡물가공품구입비' : '식료품_곡물가공품구입',
    '가계지출_소비지출_식료품비주류음료_빵떡류구입비' : '식료품_빵떡류구입','가계지출_소비지출_식료품비주류음료_육류구입비' : '식료품_육류구입',
    '가계지출_소비지출_식료품비주류음료_육류가공품구입비' : '식료품_육류가공품구입','가계지출_소비지출_식료품비주류음료_신선수산동물구입비' : '식료품_신선수산동물구입',
    '가계지출_소비지출_식료품비주류음료_염건수산동물구입비' : '식료품_염건수산동물구입','가계지출_소비지출_식료품비주류음료_기타수산동물가공구입비' : '식료품_기타수산동물가공구입',
    '가계지출_소비지출_식료품비주류음료_유제품및알구입비' : '식료품_유제품알구입','가계지출_소비지출_식료품비주류음료_유지류구입비' : '식료품_유지류구입',
    '가계지출_소비지출_식료품비주류음료_과일가공품구입비' : '식료품_과일가공품구입','가계지출_소비지출_식료품비주류음료_채소가공품구입비' : '식료품_채소가공품구입',
    '가계지출_소비지출_식료품비주류음료_해조가공품구입비' : '식료품_해조가공품구입','가계지출_소비지출_식료품비주류음료_당류과자류구입비' : '식료품_당류과자류구입',
    '가계지출_소비지출_식료품비주류음료_조미식품구입비' : '식료품_조미식품구입','가계지출_소비지출_식료품비주류음료_기타식품구입비' : '식료품_기타식품구입',
    '가계지출_소비지출_식료품비주류음료_커피차구입비' : '식료품_커피차구입','가계지출_소비지출_식료품비주류음료_쥬스기타음료구입비' : '식료품_쥬스음료구입',
    '가계지출_소비지출_주류담배구입비' : '주류담배구입','가계지출_소비지출_주류담배_주류구입비' : '주류구입','가계지출_소비지출_주류담배_담배구입비' : '담배구입',
    '가계지출_소비지출_의류신발구입비' : '의류신발구입','가계지출_소비지출_의류신발_직물및외의구입비' : '의류신발_직물및외의구입','가계지출_소비지출_의류신발_내의구입비' : '의류신발_내의구입',
    '가계지출_소비지출_의류신발_기타의복구입비' : '의류신발_기타의복구입','가계지출_소비지출_의류신발_의복관련서비스구입비' : '의류신발_의복관련서비스구입',
    '가계지출_소비지출_의류신발_신발구입비' : '의류신발_신발구입','가계지출_소비지출_의류신발_신발서비스구입비' : '의류신발_신발서비스구입','가계지출_소비지출_주거수도광열비' : '주거수도광열비',
    '가계지출_소비지출_주거수도광열_실제주거비구입비' : '주거수도광열_실제주거비구입','가계지출_소비지출_주거수도광열_주택유지수선구입비' : '주거수도광열_주택유지수선구입',
    '가계지출_소비지출_주거수도광열_상하수도폐기물처리비' : '주거수도광열_상하수도폐기물처리','가계지출_소비지출_주거수도광열_기타주거관련서비스구입비' : '주거수도광열_기타주거관련서비스구입',
    '가계지출_소비지출_주거수도광열_연료비구입비' : '주거수도광열_연료비구입','가계지출_소비지출_가정용품가사서비스이용금액' : '가정용품가사서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가구조명구입비' : '가정용품가사서비스_가구조명구입','가계지출_소비지출_가정용품가사서비스_실내장식구입비' : '가정용품가사서비스_실내장식구입',
    '가계지출_소비지출_가정용품가사서비스_가구조명장식서비스이용금액' : '가정용품가사서비스_가구조명장식서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가정용섬유구입비' : '가정용품가사서비스_가정용섬유구입','가계지출_소비지출_가정용품가사서비스_가전가정용기기구입비' : '가정용품가사서비스_가전가정용기기구입',
    '가계지출_소비지출_가정용품가사서비스_가전관련서비스이용금액' : '가정용품가사서비스_가전관련서비스이용','가계지출_소비지출_가정용품가사서비스_가사용품구입비' : '가정용품가사서비스_가사용품구입',
    '가계지출_소비지출_가정용품가사서비스_가정용공구기타구입비' : '가정용품가사서비스_가정용공구기타구입','가계지출_소비지출_가정용품가사서비스_가사소모품구입비' : '가정용품가사서비스_가사소모품구입',
    '가계지출_소비지출_가정용품가사서비스_가사서비스금액' : '가정용품가사서비스_가사서비스','가계지출_소비지출_보건제품구입비' : '보건제품구입',
    '가계지출_소비지출_보건_의약품구입비' : '보건_의약품구입','가계지출_소비지출_보건_의료용소모품구입비' : '보건_의료용소모품구입',
    '가계지출_소비지출_보건_보건의료용품기구구입비' : '보건_보건의료용품기구구입','가계지출_소비지출_보건_외래의료서비스이용금액' : '보건_외래의료서비스이용',
    '가계지출_소비지출_보건_치과서비스이용금액' : '보건_치과서비스이용','가계지출_소비지출_보건_기타의료서비스이용금액' : '보건_기타의료서비스이용',
    '가계지출_소비지출_보건_입원서비스이용금액' : '보건_입원서비스이용','가계지출_소비지출_교통비' : '교통비','가계지출_소비지출_교통_자동차구입비' : '교통_자동차구입',
    '가계지출_소비지출_교통_기타운송기구구입비' : '교통_기타운송기구구입','가계지출_소비지출_교통_운송기구유지수리비' : '교통_운송기구유지수리',
    '가계지출_소비지출_교통_운송기구연료비' : '교통_운송기구연료','가계지출_소비지출_교통_기타개인교통서비스이용금액' : '교통_기타개인교통서비스이용',
    '가계지출_소비지출_교통_철도운송금액' : '교통_철도운송','가계지출_소비지출_교통_육상운송금액' : '교통_육상운송','가계지출_소비지출_교통_기타운송금액' : '교통_기타운송',
    '가계지출_소비지출_교통_기타교통관련서비스이용금액' : '교통_기타교통관련서비스이용','가계지출_소비지출_통신비' : '통신비','가계지출_소비지출_통신_우편서비스이용금액' : '통신_우편서비스이용',
    '가계지출_소비지출_통신_통신장비구입비' : '통신_통신장비구입','가계지출_소비지출_통신_통신서비스이용금액' : '통신_통신서비스이용','가계지출_소비지출_오락문화비' : '오락문화비',
    '가계지출_소비지출_오락문화_영상음향기기구입비' : '오락문화_영상음향기기구입','가계지출_소비지출_오락문화_사진광학장비구입비' : '오락문화_사진광학장비구입',
    '가계지출_소비지출_오락문화_정보처리장치구입비' : '오락문화_정보처리장치구입','가계지출_소비지출_오락문화_기록매체구입비' : '오락문화_기록매체구입',
    '가계지출_소비지출_오락문화_영상음향정보기기수리비' : '오락문화_영상음향정보기기수리','가계지출_소비지출_오락문화_내구재구입비' : '오락문화_내구재구입',
    '가계지출_소비지출_오락문화_악기기구구입비' : '오락문화_악기기구구입','가계지출_소비지출_오락문화_오락문화내구재유지수리비' : '오락문화_오락문화내구재유지수리',
    '가계지출_소비지출_오락문화_장난감취미용품구입비' : '오락문화_장난감취미용품구입','가계지출_소비지출_오락문화_캠핑운동관련용품구입비' : '오락문화_캠핑운동관련용품구입',
    '가계지출_소비지출_오락문화_화훼관련용품구입비' : '오락문화_화훼관련용품구입','가계지출_소비지출_오락문화_애완동물관련물품구입비' : '애완동물_물품구입',
    '가계지출_소비지출_오락문화_화훼애완동물서비스이용금액' : '애완동물_서비스이용','가계지출_소비지출_오락문화_운동오락서비스이용금액' : '운동오락_서비스이용',
    '가계지출_소비지출_오락문화_문화서비스이용금액' : '문화_서비스이용','가계지출_소비지출_오락문화_복권구입비' : '복권_구입비','가계지출_소비지출_오락문화_서적구입비' : '서적_구입비',
    '가계지출_소비지출_오락문화_기타인쇄물구입비' : '인쇄물_구입비','가계지출_소비지출_오락문화_문구구입비' : '문구_구입비','가계지출_소비지출_오락문화_단체여행경비' : '단체여행_경비',
    '가계지출_소비지출_교육비' : '교육비','가계지출_소비지출_교육_정규교육비' : '정규교육비','가계지출_소비지출_교육_초등교육비' : '초등교육비','가계지출_소비지출_교육_중등교육비' : '중등교육비',
    '가계지출_소비지출_교육_고등교육비' : '고등교육비','가계지출_소비지출_교육_학원보습교육비' : '학원보습교육비','가계지출_소비지출_교육_학생학원교육비' : '학생학원교육비',
    '가계지출_소비지출_교육_성인학원비' : '성인학원비','가계지출_소비지출_교육_기타교육비' : '기타교육비','가계지출_소비지출_음식숙박비' : '음식숙박비','가계지출_소비지출_음식숙박_식대' : '식대',
    '가계지출_소비지출_음식숙박_숙박비' : '숙박비','가계지출_소비지출_기타상품서비스이용금액' : '기타상품서비스이용','가계지출_소비지출_기타상품서비스_이미용서비스이용금액' : '이미용서비스이용',
    '가계지출_소비지출_기타상품서비스_이미용기기구입비' : '이미용기기구입','가계지출_소비지출_기타상품서비스_위생이미용용품구입비' : '위생이미용용품구입',
    '가계지출_소비지출_기타상품서비스_시계장신구구입비' : '시계장신구구입','가계지출_소비지출_기타상품서비스_기타개인용품구입비' : '기타개인용품구입',
    '가계지출_소비지출_기타상품서비스_복지시설비용금액' : '복지시설비용','가계지출_소비지출_기타상품서비스_보험료' : '보험료','가계지출_소비지출_기타상품서비스_기타금융구입비' : '기타금융구입',
    '가계지출_소비지출_기타상품서비스_기타서비스금액구입비' : '기타서비스금액구입','가계지출_비소비지출금액' : '비소비지출금액','가계지출_비소비지출_경상조세' : '비경상조세',
    '가계지출_비소비지출_비경상조세' : '비경상조세','가계지출_비소비지출_연금기여금' : '연금기여금','가계지출_비소비지출_사회보장구입비' : '사회보장구입비',
    '가계지출_비소비지출_이자비용' : '이자비용','가계지출_비소비지출_가구간이전지출금액' : '가구간이전지출금액','가계지출_비소비지출_비영리단체이전지출금액' : '비영리단체이전지출금액'
}, inplace=True
)

# %%
dat_2022.columns
# Out:
# Index(['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드',
#        '가구주_성별코드', '가구주_연령', '가구주_취업여부',
#        ...
#        '기타서비스금액구입', '비소비지출금액', '비경상조세', '비경상조세', '연금기여금', '사회보장구입비', '이자비용',
#        '가구간이전지출금액', '비영리단체이전지출금액', '도시읍면부구분코드'],
#       dtype='object', length=139)

# %%
# 행 전처리

dat_2022 = dat_2022[['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드', '가구주_성별코드', '가구주_연령', '가구주_취업여부', '거처구분코드',
                     '자동차보유대수','입주형태코드', '월세평가금액', '전세보증금', '소득구간코드', '전체소비지출', '소비지출','식료품음료구입','식료품_곡물구입',
                     '식료품_곡물가공품구입','식료품_빵떡류구입','식료품_육류구입','식료품_육류가공품구입','식료품_신선수산동물구입','식료품_염건수산동물구입','식료품_기타수산동물가공구입',
                     '식료품_유제품알구입','식료품_유지류구입','식료품_과일가공품구입','식료품_채소가공품구입','식료품_해조가공품구입','식료품_당류과자류구입','식료품_조미식품구입',
                     '식료품_기타식품구입','식료품_커피차구입','식료품_쥬스음료구입','주류담배구입','주류구입','담배구입','의류신발구입','의류신발_직물및외의구입','의류신발_내의구입',
                     '의류신발_기타의복구입','의류신발_의복관련서비스구입','의류신발_신발구입','의류신발_신발서비스구입','주거수도광열비','주거수도광열_실제주거비구입',
                     '주거수도광열_주택유지수선구입','주거수도광열_상하수도폐기물처리','주거수도광열_기타주거관련서비스구입','주거수도광열_연료비구입','가정용품가사서비스이용',
                     '가정용품가사서비스_가구조명구입','가정용품가사서비스_실내장식구입','가정용품가사서비스_가구조명장식서비스이용','가정용품가사서비스_가정용섬유구입',
                     '가정용품가사서비스_가전가정용기기구입','가정용품가사서비스_가전관련서비스이용','가정용품가사서비스_가사용품구입','가정용품가사서비스_가정용공구기타구입',
                     '가정용품가사서비스_가사소모품구입','가정용품가사서비스_가사서비스','보건제품구입','보건_의약품구입','보건_의료용소모품구입','보건_보건의료용품기구구입',
                     '보건_외래의료서비스이용','보건_치과서비스이용','보건_기타의료서비스이용','보건_입원서비스이용','교통비','교통_자동차구입','교통_기타운송기구구입','교통_운송기구유지수리',
                     '교통_운송기구연료','교통_기타개인교통서비스이용','교통_철도운송','교통_육상운송','교통_기타운송','교통_기타교통관련서비스이용','통신비','통신_우편서비스이용',
                     '통신_통신장비구입','통신_통신서비스이용','오락문화비','오락문화_영상음향기기구입','오락문화_사진광학장비구입','오락문화_정보처리장치구입','오락문화_기록매체구입',
                     '오락문화_영상음향정보기기수리','오락문화_내구재구입','오락문화_악기기구구입','오락문화_오락문화내구재유지수리','오락문화_장난감취미용품구입','오락문화_캠핑운동관련용품구입',
                     '오락문화_화훼관련용품구입','애완동물_물품구입','애완동물_서비스이용','운동오락_서비스이용','문화_서비스이용','복권_구입비','서적_구입비','인쇄물_구입비','문구_구입비',
                     '단체여행_경비','교육비','정규교육비','초등교육비','중등교육비','고등교육비','학원보습교육비','학생학원교육비','성인학원비','기타교육비','음식숙박비','식대','숙박비',
                     '기타상품서비스이용','이미용서비스이용','이미용기기구입','위생이미용용품구입','시계장신구구입','기타개인용품구입','복지시설비용','보험료','기타금융구입','기타서비스금액구입',
                     '비소비지출금액','비경상조세','비경상조세','연금기여금','사회보장구입비','이자비용','가구간이전지출금액','비영리단체이전지출금액']]

# %%
dat_2022['가구구분코드'] = dat_2022['가구구분코드'].replace({1: '근로자 가구', 2: '비근로자 가구'})
dat_2022['노인가구여부'] = dat_2022['노인가구여부'].replace({0: '아니요', 1: '예'})
dat_2022['배우자코드'] = dat_2022['배우자코드'].replace({1: '현재(동거)', 2: '현재(비동거)', 3:'부재'})
dat_2022['가구주_성별코드'] = dat_2022['가구주_성별코드'].replace({1: '남성', 2: '여성'})
dat_2022['가구주_취업여부'] = dat_2022['가구주_취업여부'].replace({1: '취업', 2: '실업자'})
dat_2022['거처구분코드'] = dat_2022['거처구분코드'].replace({1: '단독주택(다세대 포함)', 2: '아파트', 3: '연립주택', 4: '다가구주택', 5: '비주거용 건물', 6: '오피스텔', 7: '기타'})
dat_2022['입주형태코드'] = dat_2022['입주형태코드'].replace({1: '내 집', 2: '무료주택', 3: '회사주택', 4: '임대', 5: '영구임대', 6: '보증금 월세', 7: '보증금 없는 월세'})
dat_2022['소득구간코드'] = dat_2022['소득구간코드'].replace({1: '100만원 미만', 2: '100~200만원', 3: '200~300만원', 4: '300~400만원', 5: '400~500만원', 6: '500~600만원', 7: '600~700만원', 8: '700만원 이상'})
# dat_2022['도시읍면부구분코드'] = dat_2022['도시읍면부구분코드'].replace({0: '비도시', 1: '도시'})

# %%
dat_2022
# Out:
#          조사연월  가구일련번호   가구구분코드  가구원수  취업인원수 노인가구여부    배우자코드 가구주_성별코드  가구주_연령  \
# 0      202200       1  비근로자 가구     4      1    아니요   현재(동거)       남성      49
# 1      202200       2  비근로자 가구     2      0    아니요       부재       여성      50
# 2      202200       3   근로자 가구     3      2    아니요   현재(동거)       남성      49
# 3      202200       4   근로자 가구     2      1    아니요       부재       여성      56
# 4      202200       5   근로자 가구     4      2    아니요   현재(동거)       여성      42
# ...       ...     ...      ...   ...    ...    ...      ...      ...     ...
# 12695  202200   12696  비근로자 가구     6      2    아니요   현재(동거)       남성      44
# 12696  202200   12697  비근로자 가구     2      1    아니요  현재(비동거)       여성      60
# 12697  202200   12698   근로자 가구     4      1    아니요       부재       여성      68
# 12698  202200   12699  비근로자 가구     1      1      예       부재       여성      71
# 12699  202200   12700  비근로자 가구     2      2    아니요       부재       여성      82
#
# ...

# %%
def age(가구주_연령):
    if 가구주_연령 < 20:
        return '10대'
    elif 20 <= 가구주_연령 < 30:
        return '20대'
    elif 30 <= 가구주_연령 < 40:
        return '30대'
    elif 40 <= 가구주_연령 < 50:
        return '40대'
    elif 50 <= 가구주_연령 < 60:
        return '50대'
    elif 60 <= 가구주_연령 < 70:
        return '60대'
    elif 70 <= 가구주_연령:
        return '70대 이상'

# 데이터 연령대별 구분
dat_2022.loc[:,'연령대'] = dat_2022['가구주_연령'].apply(age)
dat_2022.연령대
# Out:
# 0           40대
# 1           50대
# 2           40대
# 3           50대
# 4           40대
#           ...
# 12695       40대
# 12696       60대
# 12697       60대
# 12698    70대 이상
# 12699    70대 이상
# Name: 연령대, Length: 12700, dtype: object

# %%
# 연령대별 가구원 수 분포
dat_2022.groupby('연령대')['가구원수'].value_counts().unstack().fillna(0).astype(int)
# Out:
# 가구원수      1     2    3    4    5   6  7  8
# 연령대
# 10대      12     1    1    0    0   0  0  0
# 20대     588   152   36    9    3   0  0  0
# 30대     551   367  348  295   39   6  2  0
# 40대     402   385  556  803  160  32  2  0
# 50대     583   898  696  425   64  10  1  1
# 60대     756  1466  417  107   19   5  1  0
# 70대 이상  961  1368  135   24    8   4  1  0

# %% [markdown]
# ##### 전체가구 지출 (total_expend) | 1인가구 지출 (single_expend )

# %% [markdown]
# 전체가구 소비지출

# %% [markdown]
# box plot 그려서 분포 확인해봐야 함

# %%
total_expend_2022 = dat_2022['소비지출']

total_expend_2022.info # 전체가구 소비지출
# Out:
# <bound method Series.info of 0        4112204
# 1        1308728
# 2        3986468
# 3        2100261
# 4        4501788
#           ...
# 12695    3563502
# 12696    2029644
# 12697    2875224
# 12698     614900
# 12699     734064
# Name: 소비지출, Length: 12700, dtype: int64>

# %% [markdown]
# --2차 전처리--
#
# 전체가구 소비지출 이상치확인 (9,510개중 6,730개) <2,780개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(total_expend_2022, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(total_expend_2022, 25)
Q3 = np.percentile(total_expend_2022, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(total_expend_2022), f'Median: {np.median(total_expend_2022):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(total_expend_2022):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(total_expend_2022):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('전체가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_total_expend_2022 = ((total_expend_2022 >= lower_limit) & (total_expend_2022 <= upper_limit))
total_expend_2022[cleaned_total_expend_2022]
# Out:
# 0        4112204
# 1        1308728
# 2        3986468
# 3        2100261
# 4        4501788
#           ...
# 12695    3563502
# 12696    2029644
# 12697    2875224
# 12698     614900
# 12699     734064
# Name: 소비지출, Length: 12206, dtype: int64

# %%
# 이상치 제거
cleaned_total_expend_2022 = total_expend_2022[(total_expend_2022 >= lower_limit) & (total_expend_2022 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_total_expend_2022, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_total_expend_2022, 25)
Q3 = np.percentile(cleaned_total_expend_2022, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_total_expend_2022), f'Median: {np.median(cleaned_total_expend_2022):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_total_expend_2022):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_total_expend_2022):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('전체가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 전체가구 평균 소비지출
total_expend_mean_2022 = int(total_expend_2022.mean())
print(f"전체가구의 평균 소비지출: {total_expend_mean_2022:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,484,244원

# %%
# 전체가구 평균 소비지출 이상치 제거 후
cleaned_total_expend_mean_2022 = int(cleaned_total_expend_2022.mean())
print(f"전체가구의 평균 소비지출: {cleaned_total_expend_mean_2022:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,233,190원

# %% [markdown]
# 1인가구 소비지출

# %%
# 가구원수 1로 설정하여 9510개에서 2827개의 데이터 전처리

single_expend_2022 = dat_2022.loc[dat['가구원수'] == 1, '소비지출']

single_expend_2022.info # 1인가구 소비지출
# Out:
# <bound method Series.info of 15       1539156
# 20       1448996
# 26        936126
# 29        558724
# 30        955259
#           ...
# 12673    1155175
# 12682     736353
# 12683     316981
# 12688    1532878
# 12698     614900
# Name: 소비지출, Length: 3853, dtype: int64>

# %%
# 1인가구 이상치 식별
(single_expend_2022 < lower_limit) & (single_expend_2022 > upper_limit)
# Out:
# 15       False
# 20       False
# 26       False
# 29       False
# 30       False
#          ...
# 12673    False
# 12682    False
# 12683    False
# 12688    False
# 12698    False
# Name: 소비지출, Length: 3853, dtype: bool

# %% [markdown]
# -- 2차전처리 --
#
# * 1인가구 소비지출 이상치확인 (2827개중 2701개) <126개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(single_expend_2022, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(single_expend_2022, 25)
Q3 = np.percentile(single_expend_2022, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(single_expend_2022), f'Median: {np.median(total_expend_2022):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(single_expend_2022):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(single_expend_2022):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('1인가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_single_expend_2022 = ((single_expend_2022 >= lower_limit) & (single_expend_2022 <= upper_limit))
single_expend_2022[cleaned_single_expend_2022]
# Out:
# 15       1539156
# 20       1448996
# 26        936126
# 29        558724
# 30        955259
#           ...
# 12673    1155175
# 12682     736353
# 12683     316981
# 12688    1532878
# 12698     614900
# Name: 소비지출, Length: 3675, dtype: int64

# %%
# 이상치 제거
cleaned_single_expend_2022 = single_expend_2022[(single_expend_2022 >= lower_limit) & (single_expend_2022 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_single_expend_2022, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_single_expend_2022, 25)
Q3 = np.percentile(cleaned_single_expend_2022, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_single_expend_2022), f'Median: {np.median(cleaned_single_expend_2022):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_single_expend_2022):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_single_expend_2022):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('1인가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 1인가구 평균 소비지출
single_expend_mean_2022 = int(single_expend_2022.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {single_expend_mean_2022:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,461,217원

# %%
# 1인가구 평균 소비지출 이상치 제거 후
cleaned_single_expend_mean_2022 = int(cleaned_single_expend_2022.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {cleaned_single_expend_mean_2022:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,313,776원

# %% [markdown]
# 전체가구 식료품음료구입 평균소비 비용, 비율

# %%
tot_식료품음료구입_2022 = dat_2022['식료품음료구입']
tot_식료품음료구입_mean_2022 = int(tot_식료품음료구입_2022.mean())
tot_식료품음료구입_per_2022 = (tot_식료품음료구입_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 식료품음료구입 소비 비율

print(tot_식료품음료구입_2022)
print(tot_식료품음료구입_mean_2022)
print(tot_식료품음료구입_per_2022)
# Out:
# 0         334823
# 1         537233
# 2         650875
# 3         737000
# 4        1024174
#           ...
# 12695     881574
# 12696     553581
# 12697     838958
# 12698     334205
# 12699     335770
# Name: 식료품음료구입, Length: 12700, dtype: int64
# 389564
# 15.68139039482434

# %% [markdown]
# 1인가구 식료품음료구입 평균소비 비용, 비율

# %%
sin_tot_식료품음료구입_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '식료품음료구입']
sin_tot_식료품음료구입_mean_2022 = int(sin_tot_식료품음료구입_2022.mean())
sin_tot_식료품음료구입_per_2022 = (sin_tot_식료품음료구입_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 식료품음료구입 소비 비율

print(sin_tot_식료품음료구입_2022)
print(sin_tot_식료품음료구입_mean_2022)
print(sin_tot_식료품음료구입_per_2022)
# Out:
# 15       265593
# 20        64175
# 26       255295
# 29       334435
# 30       256067
#           ...
# 12673    165930
# 12682    193580
# 12683    115860
# 12688    346856
# 12698    334205
# Name: 식료품음료구입, Length: 3853, dtype: int64
# 207640
# 14.210072836546523

# %%
print(f"전체가구 소비 중 식료품음료구입 소비지출, 비율: {tot_식료품음료구입_mean_2022:,}원 ({tot_식료품음료구입_per_2022:.2f}%)")
print(f"1인가구 소비 중 식료품음료구입 소비지출, 비율: {sin_tot_식료품음료구입_mean_2022:,}원 ({sin_tot_식료품음료구입_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 식료품음료구입 소비지출, 비율: 389,564원 (15.68%)
# 1인가구 소비 중 식료품음료구입 소비지출, 비율: 207,640원 (14.21%)

# %% [markdown]
# 전체가구 주류담배구입 평균소비 비용, 비율

# %%
tot_주류담배구입_2022 = dat_2022['주류담배구입']
tot_주류담배구입_mean_2022 = int(tot_주류담배구입_2022.mean())
tot_주류담배구입_per_2022 = (tot_주류담배구입_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 주류담배구입 소비 비율

print(tot_주류담배구입_2022)
print(tot_주류담배구입_mean_2022)
print(tot_주류담배구입_per_2022)
# Out:
# 0        200387
# 1         13933
# 2        127200
# 3          7517
# 4             0
#           ...
# 12695    129570
# 12696      3585
# 12697    110710
# 12698         0
# 12699     36000
# Name: 주류담배구입, Length: 12700, dtype: int64
# 37535
# 1.5109224375705446

# %% [markdown]
# 1인가구 주류담배구입 평균소비 비용, 비율

# %%
sin_tot_주류담배구입_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '주류담배구입']
sin_tot_주류담배구입_mean_2022 = int(sin_tot_주류담배구입_2022.mean())
sin_tot_주류담배구입_per_2022 = (sin_tot_주류담배구입_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 주류담배구입 소비 비율

print(sin_tot_주류담배구입_2022)
print(sin_tot_주류담배구입_mean_2022)
print(sin_tot_주류담배구입_per_2022)
# Out:
# 15            0
# 20            0
# 26         5500
# 29            0
# 30       108000
#           ...
# 12673      5717
# 12682         0
# 12683         0
# 12688         0
# 12698         0
# Name: 주류담배구입, Length: 3853, dtype: int64
# 32405
# 2.2176719816426993

# %%
print(f"전체가구 소비 중 주류담배구입 소비지출, 비율: {tot_주류담배구입_mean_2022:,}원 ({tot_주류담배구입_per_2022:.2f}%)")
print(f"1인가구 소비 중 주류담배구입 소비지출, 비율: {sin_tot_주류담배구입_mean_2022:,}원 ({sin_tot_주류담배구입_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 주류담배구입 소비지출, 비율: 37,535원 (1.51%)
# 1인가구 소비 중 주류담배구입 소비지출, 비율: 32,405원 (2.22%)

# %% [markdown]
# 전체가구 의류신발구입 평균소비 비용, 비율

# %%
tot_의류신발구입_2022 = dat_2022['의류신발구입']
tot_의류신발구입_mean_2022 = int(tot_의류신발구입_2022.mean())
tot_의류신발구입_per_2022 = (tot_의류신발구입_mean_2022/ total_expend_mean_2022) * 100  # 전체가구 소비 중 의류신발구입 소비 비율

print(tot_의류신발구입_2022)
print(tot_의류신발구입_mean_2022)
print(tot_의류신발구입_per_2022)
# Out:
# 0        108083
# 1         18167
# 2        138590
# 3         92518
# 4        178982
#           ...
# 12695     41750
# 12696    190905
# 12697     16000
# 12698     19500
# 12699      6000
# Name: 의류신발구입, Length: 12700, dtype: int64
# 124142
# 4.997174190618956

# %% [markdown]
# 1인가구 의류신발구입 평균소비 비용, 비율

# %%
sin_tot_의류신발구입_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '의류신발구입']
sin_tot_의류신발구입_mean_2022 = int(sin_tot_의류신발구입_2022.mean())
sin_tot_의류신발구입_per_2022 = (sin_tot_의류신발구입_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 의류신발구입 소비 비율

print(sin_tot_의류신발구입_2022)
print(sin_tot_의류신발구입_mean_2022)
print(sin_tot_의류신발구입_per_2022)
# Out:
# 15       94067
# 20       46100
# 26        5950
# 29       56333
# 30       14500
#          ...
# 12673     6167
# 12682        0
# 12683     8050
# 12688    44530
# 12698    19500
# Name: 의류신발구입, Length: 3853, dtype: int64
# 70884
# 4.85102486489002

# %%
print(f"전체가구 소비 중 의류신발구입 소비지출, 비율: {tot_의류신발구입_mean_2022:,}원 ({tot_의류신발구입_per_2022:.2f}%)")
print(f"1인가구 소비 중 의류신발구입 소비지출, 비율: {sin_tot_의류신발구입_mean_2022:,}원 ({sin_tot_의류신발구입_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 의류신발구입 소비지출, 비율: 124,142원 (5.00%)
# 1인가구 소비 중 의류신발구입 소비지출, 비율: 70,884원 (4.85%)

# %% [markdown]
# 전체가구 주거수도광열비 평균소비 비용, 비율

# %%
tot_주거수도광열비_2022 = dat_2022['주거수도광열비']
tot_주거수도광열비_mean_2022 = int(tot_주거수도광열비_2022.mean())
tot_주거수도광열비_per_2022 = (tot_주거수도광열비_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 주거수도광열비 소비 비율

print(tot_주거수도광열비_2022)
print(tot_주거수도광열비_mean_2022)
print(tot_주거수도광열비_per_2022)
# Out:
# 0        173195
# 1        109903
# 2        124470
# 3        103217
# 4        139142
#           ...
# 12695    270135
# 12696    158655
# 12697    286318
# 12698     87815
# 12699     10675
# Name: 주거수도광열비, Length: 12700, dtype: int64
# 294624
# 11.859704602285444

# %% [markdown]
# 1인가구 주거수도광열비 평균소비 비용, 비율

# %%
sin_tot_주거수도광열비_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '주거수도광열비']
sin_tot_주거수도광열비_mean_2022 = int(sin_tot_주거수도광열비_2022.mean())
sin_tot_주거수도광열비_per_2022 = (sin_tot_주거수도광열비_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 주거수도광열비 소비 비율

print(sin_tot_주거수도광열비_2022)
print(sin_tot_주거수도광열비_mean_2022)
print(sin_tot_주거수도광열비_per_2022)
# Out:
# 15       223738
# 20       399482
# 26        43065
# 29        45100
# 30       434573
#           ...
# 12673     50357
# 12682    292750
# 12683     30000
# 12688    370796
# 12698     87815
# Name: 주거수도광열비, Length: 3853, dtype: int64
# 264540
# 18.104087209497287

# %%
print(f"전체가구 소비 중 주거수도광열비 소비지출, 비율: {tot_주거수도광열비_mean_2022:,}원 ({tot_주거수도광열비_per_2022:.2f}%)")
print(f"1인가구 소비 중 주거수도광열비 소비지출, 비율: {sin_tot_주거수도광열비_mean_2022:,}원 ({sin_tot_주거수도광열비_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 주거수도광열비 소비지출, 비율: 294,624원 (11.86%)
# 1인가구 소비 중 주거수도광열비 소비지출, 비율: 264,540원 (18.10%)

# %% [markdown]
# 전체가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
tot_가정용품가사서비스이용_2022 = dat_2022['가정용품가사서비스이용']
tot_가정용품가사서비스이용_mean_2022 = int(tot_가정용품가사서비스이용_2022.mean())
tot_가정용품가사서비스이용_per_2022 = (tot_가정용품가사서비스이용_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 가정용품가사서비스이용 소비 비율

print(tot_가정용품가사서비스이용_2022)
print(tot_가정용품가사서비스이용_mean_2022)
print(tot_가정용품가사서비스이용_per_2022)
# Out:
# 0        114995
# 1         58000
# 2        661745
# 3         64372
# 4        390347
#           ...
# 12695    100670
# 12696     50870
# 12697     20640
# 12698     13930
# 12699      5370
# Name: 가정용품가사서비스이용, Length: 12700, dtype: int64
# 114133
# 4.594274958498441

# %% [markdown]
# 1인가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
sin_tot_가정용품가사서비스이용_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '가정용품가사서비스이용']
sin_tot_가정용품가사서비스이용_mean_2022 = int(sin_tot_가정용품가사서비스이용_2022.mean())
sin_tot_가정용품가사서비스이용_per_2022 = (sin_tot_가정용품가사서비스이용_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 가정용품가사서비스이용 소비 비율

print(sin_tot_가정용품가사서비스이용_2022)
print(sin_tot_가정용품가사서비스이용_mean_2022)
print(sin_tot_가정용품가사서비스이용_per_2022)
# Out:
# 15       160615
# 20        57118
# 26         6610
# 29        55677
# 30        15205
#           ...
# 12673    125662
# 12682    125400
# 12683         0
# 12688     16532
# 12698     13930
# Name: 가정용품가사서비스이용, Length: 3853, dtype: int64
# 64146
# 4.389902389583478

# %%
print(f"전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {tot_가정용품가사서비스이용_mean_2022:,}원 ({tot_가정용품가사서비스이용_per_2022:.2f}%)")
print(f"1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {sin_tot_가정용품가사서비스이용_mean_2022:,}원 ({sin_tot_가정용품가사서비스이용_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 114,133원 (4.59%)
# 1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 64,146원 (4.39%)

# %% [markdown]
# 전체가구 보건제품구입 평균소비 비용, 비율

# %%
tot_보건제품구입_2022 = dat_2022['보건제품구입']
tot_보건제품구입_mean_2022 = int(tot_보건제품구입_2022.mean())
tot_보건제품구입_per_2022 = (tot_보건제품구입_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 보건제품구입 소비 비율

print(tot_보건제품구입_2022)
print(tot_보건제품구입_mean_2022)
print(tot_보건제품구입_per_2022)
# Out:
# 0        138467
# 1        175867
# 2        150485
# 3        636283
# 4        395515
#           ...
# 12695    252295
# 12696    225630
# 12697    408295
# 12698         0
# 12699     46300
# Name: 보건제품구입, Length: 12700, dtype: int64
# 233825
# 9.412320206871788

# %% [markdown]
# 1인가구 보건제품구입 평균소비 비용, 비율

# %%
sin_tot_보건제품구입_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '보건제품구입']
sin_tot_보건제품구입_mean_2022 = int(sin_tot_보건제품구입_2022.mean())
sin_tot_보건제품구입_per_2022 = (sin_tot_보건제품구입_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 보건제품구입 소비 비율

print(sin_tot_보건제품구입_2022)
print(sin_tot_보건제품구입_mean_2022)
print(sin_tot_보건제품구입_per_2022)
# Out:
# 15       125333
# 20        78063
# 26       234150
# 29        37733
# 30         1167
#           ...
# 12673     73050
# 12682     58733
# 12683     34400
# 12688    353796
# 12698         0
# Name: 보건제품구입, Length: 3853, dtype: int64
# 134451
# 9.201302749694262

# %%
print(f"전체가구 소비 중 보건제품구입 소비지출, 비율: {tot_보건제품구입_mean_2022:,}원 ({tot_보건제품구입_per_2022:.2f}%)")
print(f"1인가구 소비 중 보건제품구입 소비지출, 비율: {sin_tot_보건제품구입_mean_2022:,}원 ({sin_tot_보건제품구입_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 보건제품구입 소비지출, 비율: 233,825원 (9.41%)
# 1인가구 소비 중 보건제품구입 소비지출, 비율: 134,451원 (9.20%)

# %% [markdown]
# 전체가구 교통비 평균소비 비용, 비율

# %%
tot_교통비_2022 = dat_2022['교통비']
tot_교통비_mean_2022 = int(tot_교통비_2022.mean())
tot_교통비_per_2022 = (tot_교통비_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 교통비 소비 비율

print(tot_교통비_2022)
print(tot_교통비_mean_2022)
print(tot_교통비_per_2022)
# Out:
# 0        166230
# 1         21267
# 2        416061
# 3         23200
# 4        202591
#           ...
# 12695    457695
# 12696    289642
# 12697    342000
# 12698     31200
# 12699    177000
# Name: 교통비, Length: 12700, dtype: int64
# 302091
# 12.160278942004087

# %% [markdown]
# 1인가구 교통비 평균소비 비용, 비율

# %%
sin_tot_교통비_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '교통비']
sin_tot_교통비_mean_2022 = int(sin_tot_교통비_2022.mean())
sin_tot_교통비_per_2022 = (sin_tot_교통비_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 교통비 소비 비율

print(sin_tot_교통비_2022)
print(sin_tot_교통비_mean_2022)
print(sin_tot_교통비_per_2022)
# Out:
# 15       113752
# 20       140432
# 26        76700
# 29            0
# 30        49333
#           ...
# 12673      3667
# 12682     20000
# 12683     25000
# 12688     13760
# 12698     31200
# Name: 교통비, Length: 3853, dtype: int64
# 159293
# 10.901392469427881

# %% [markdown]
# 전체가구 통신비 평균소비 비용, 비율

# %%
tot_통신비_2022 = dat_2022['통신비']
tot_통신비_mean_2022 = int(tot_통신비_2022.mean())
tot_통신비_per_2022 = (tot_통신비_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 통신비 소비 비율

print(tot_통신비_2022)
print(tot_통신비_mean_2022)
print(tot_통신비_per_2022)
# Out:
# 0        494085
# 1         98067
# 2        196580
# 3         84590
# 4        127810
#           ...
# 12695    102331
# 12696    113500
# 12697    109796
# 12698     39100
# 12699     42949
# Name: 통신비, Length: 12700, dtype: int64
# 116984
# 4.70903824262029

# %% [markdown]
# 1인가구 통신비 평균소비 비용, 비율

# %%
sin_tot_통신비_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '통신비']
sin_tot_통신비_mean_2022 = int(sin_tot_통신비_2022.mean())
sin_tot_통신비_per_2022 = (sin_tot_통신비_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 통신비 소비 비율

print(sin_tot_통신비_2022)
print(sin_tot_통신비_mean_2022)
print(sin_tot_통신비_per_2022)
# Out:
# 15       62577
# 20       90587
# 26       41960
# 29       14071
# 30       15306
#          ...
# 12673    19560
# 12682    30690
# 12683    33000
# 12688    21872
# 12698    39100
# Name: 통신비, Length: 3853, dtype: int64
# 60068
# 4.11081995350451

# %% [markdown]
# 전체가구 오락문화비 평균소비 비용, 비율

# %%
tot_오락문화비_2022 = dat_2022['오락문화비']
tot_오락문화비_mean_2022 = int(tot_오락문화비_2022.mean())
tot_오락문화비_per_2022 = (tot_오락문화비_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 오락문화비 소비 비율

print(tot_오락문화비_2022)
print(tot_오락문화비_mean_2022)
print(tot_오락문화비_per_2022)
# Out:
# 0        134673
# 1         62500
# 2         70200
# 3        211963
# 4        506442
#           ...
# 12695    197560
# 12696     98220
# 12697     29308
# 12698     36850
# 12699         0
# Name: 오락문화비, Length: 12700, dtype: int64
# 147422
# 5.934280207580254

# %% [markdown]
# 1인가구 오락문화비 평균소비 비용, 비율

# %%
sin_tot_오락문화비_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '오락문화비']
sin_tot_오락문화비_mean_2022 = int(sin_tot_오락문화비_2022.mean())
sin_tot_오락문화비_per_2022 = (sin_tot_오락문화비_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 오락문화비 소비 비율

print(sin_tot_오락문화비_2022)
print(sin_tot_오락문화비_mean_2022)
print(sin_tot_오락문화비_per_2022)
# Out:
# 15       114912
# 20       192458
# 26        50890
# 29         2500
# 30        19000
#           ...
# 12673     95625
# 12682     10200
# 12683     12400
# 12688     37990
# 12698     36850
# Name: 오락문화비, Length: 3853, dtype: int64
# 92003
# 6.296326965810007

# %%
print(f"전체가구 소비 중 오락문화비 소비지출, 비율: {tot_오락문화비_mean_2022:,}원 ({tot_오락문화비_per_2022:.2f}%)")
print(f"1인가구 소비 중 오락문화비 소비지출, 비율: {sin_tot_오락문화비_mean_2022:,}원 ({sin_tot_오락문화비_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 오락문화비 소비지출, 비율: 147,422원 (5.93%)
# 1인가구 소비 중 오락문화비 소비지출, 비율: 92,003원 (6.30%)

# %% [markdown]
# 전체가구 교육비 평균소비 비용, 비율

# %%
tot_교육비_2022 = dat_2022['교육비']
tot_교육비_mean_2022 = int(tot_교육비_2022.mean())
tot_교육비_per_2022 = (tot_교육비_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 교육비 소비 비율

print(tot_교육비_2022)
print(tot_교육비_mean_2022)
print(tot_교육비_per_2022)
# Out:
# 0        931583
# 1             0
# 2        475000
# 3             0
# 4        171667
#           ...
# 12695    720000
# 12696         0
# 12697    231451
# 12698         0
# 12699         0
# Name: 교육비, Length: 12700, dtype: int64
# 164532
# 6.623020927090898

# %% [markdown]
# 1인가구 교육비 평균소비 비용, 비율

# %%
sin_tot_교육비_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '교육비']
sin_tot_교육비_mean_2022 = int(sin_tot_교육비_2022.mean())
sin_tot_교육비_per_2022 = (sin_tot_교육비_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 교육비 소비 비율

print(sin_tot_교육비_2022)
print(sin_tot_교육비_mean_2022)
print(sin_tot_교육비_per_2022)
# Out:
# 15       13500
# 20       17500
# 26           0
# 29           0
# 30           0
#          ...
# 12673        0
# 12682        0
# 12683        0
# 12688        0
# 12698        0
# Name: 교육비, Length: 3853, dtype: int64
# 22372
# 1.5310525404508708

# %%
print(f"전체가구 소비 중 교육비 소비지출, 비율: {tot_교육비_mean_2022:,}원 ({tot_교육비_per_2022:.2f}%)")
print(f"1인가구 소비 중 교육비 소비지출, 비율: {sin_tot_교육비_mean_2022:,}원 ({sin_tot_교육비_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 교육비 소비지출, 비율: 164,532원 (6.62%)
# 1인가구 소비 중 교육비 소비지출, 비율: 22,372원 (1.53%)

# %% [markdown]
# 전체가구 음식숙박비 평균소비 비용, 비율

# %%
tot_음식숙박비_2022 = dat_2022['음식숙박비']
tot_음식숙박비_mean_2022 = int(tot_음식숙박비_2022.mean())
tot_음식숙박비_per_2022 = (tot_음식숙박비_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 음식숙박비 소비 비율

print(tot_음식숙박비_2022)
print(tot_음식숙박비_mean_2022)
print(tot_음식숙박비_per_2022)
# Out:
# 0        1097310
# 1         147300
# 2         764650
# 3         104517
# 4        1121385
#           ...
# 12695     202950
# 12696     189750
# 12697     425150
# 12698      30000
# 12699      64000
# Name: 음식숙박비, Length: 12700, dtype: int64
# 356781
# 14.361753515355174

# %% [markdown]
# 1인가구 음식숙박비 평균소비 비용, 비율

# %%
sin_tot_음식숙박비_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '음식숙박비']
sin_tot_음식숙박비_mean_2022 = int(sin_tot_음식숙박비_2022.mean())
sin_tot_음식숙박비_per_2022 = (sin_tot_음식숙박비_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 음식숙박비 소비 비율

print(sin_tot_음식숙박비_2022)
print(sin_tot_음식숙박비_mean_2022)
print(sin_tot_음식숙박비_per_2022)
# Out:
# 15       158702
# 20       169992
# 26        97700
# 29         4750
# 30         8250
#           ...
# 12673     68083
# 12682      3000
# 12683         0
# 12688    200500
# 12698     30000
# Name: 음식숙박비, Length: 3853, dtype: int64
# 240916
# 16.487352665620506

# %%
print(f"전체가구 소비 중 음식숙박비 소비지출, 비율: {tot_음식숙박비_mean_2022:,}원 ({tot_음식숙박비_per_2022:.2f}%)")
print(f"1인가구 소비 중 음식숙박비 소비지출, 비율: {sin_tot_음식숙박비_mean_2022:,}원 ({sin_tot_음식숙박비_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 음식숙박비 소비지출, 비율: 356,781원 (14.36%)
# 1인가구 소비 중 음식숙박비 소비지출, 비율: 240,916원 (16.49%)

# %% [markdown]
# 전체가구 기타상품서비스이용 평균소비 비용, 비율

# %%
tot_기타상품서비스이용_2022 = dat_2022['기타상품서비스이용']
tot_기타상품서비스이용_mean_2022 = int(tot_기타상품서비스이용_2022.mean())
tot_기타상품서비스이용_per_2022 = (tot_기타상품서비스이용_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 기타상품서비스이용 소비 비율

print(tot_기타상품서비스이용_2022)
print(tot_기타상품서비스이용_mean_2022)
print(tot_기타상품서비스이용_per_2022)
# Out:
# 0        218373
# 1         66492
# 2        210612
# 3         35083
# 4        243735
#           ...
# 12695    206972
# 12696    155306
# 12697     56600
# 12698     22300
# 12699     10000
# Name: 기타상품서비스이용, Length: 12700, dtype: int64
# 202607
# 8.155680359900236

# %% [markdown]
# 1인가구 기타상품서비스이용 평균소비 비용, 비율

# %%
sin_tot_기타상품서비스이용_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '기타상품서비스이용']
sin_tot_기타상품서비스이용_mean_2022 = int(sin_tot_기타상품서비스이용_2022.mean())
sin_tot_기타상품서비스이용_per_2022 = (sin_tot_기타상품서비스이용_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 기타상품서비스이용 소비 비율

print(sin_tot_기타상품서비스이용_2022)
print(sin_tot_기타상품서비스이용_mean_2022)
print(sin_tot_기타상품서비스이용_per_2022)
# Out:
# 15       206368
# 20       193088
# 26       118306
# 29         8125
# 30        33858
#           ...
# 12673    541358
# 12682      2000
# 12683     58271
# 12688    126246
# 12698     22300
# Name: 기타상품서비스이용, Length: 3853, dtype: int64
# 112494
# 7.698651192807092

# %%
print(f"전체가구 소비 중 기타상품서비스이용 소비지출, 비율: {tot_기타상품서비스이용_mean_2022:,}원 ({tot_기타상품서비스이용_per_2022:.2f}%)")
print(f"1인가구 소비 중 기타상품서비스이용 소비지출, 비율: {sin_tot_기타상품서비스이용_mean_2022:,}원 ({sin_tot_기타상품서비스이용_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 기타상품서비스이용 소비지출, 비율: 202,607원 (8.16%)
# 1인가구 소비 중 기타상품서비스이용 소비지출, 비율: 112,494원 (7.70%)

# %% [markdown]
# 전체가구 비소비지출금액 평균소비 비용, 비율

# %%
tot_비소비지출금액_2022 = dat_2022['비소비지출금액']
tot_비소비지출금액_mean_2022 = int(tot_비소비지출금액_2022.mean())
tot_비소비지출금액_per_2022 = (tot_비소비지출금액_mean_2022 / total_expend_mean_2022) * 100  # 전체가구 소비 중 비소비지출금액 소비 비율

print(tot_비소비지출금액_2022)
print(tot_비소비지출금액_mean_2022)
print(tot_비소비지출금액_per_2022)
# Out:
# 0         610316
# 1          58827
# 2        1175323
# 3         528052
# 4        1499057
#           ...
# 12695     783940
# 12696     203000
# 12697     270710
# 12698     320000
# 12699     178430
# Name: 비소비지출금액, Length: 12700, dtype: int64
# 874210
# 35.190182606861484

# %% [markdown]
# 1인가구 비소비지출금액 평균소비 비용, 비율

# %%
sin_tot_비소비지출금액_2022 = dat_2022.loc[dat_2022['가구원수'] == 1, '비소비지출금액']
sin_tot_비소비지출금액_mean_2022 = int(sin_tot_비소비지출금액_2022.mean())
sin_tot_비소비지출금액_per_2022 = (sin_tot_비소비지출금액_mean_2022 / single_expend_mean_2022) * 100  # 1인가구 소비 중 비소비지출금액 소비 비율

print(sin_tot_비소비지출금액_2022)
print(sin_tot_비소비지출금액_mean_2022)
print(sin_tot_비소비지출금액_per_2022)
# Out:
# 15       393009
# 20       524757
# 26        45640
# 29            0
# 30            0
#           ...
# 12673     94363
# 12682      3333
# 12683     73000
# 12688    129088
# 12698    320000
# Name: 비소비지출금액, Length: 3853, dtype: int64
# 517172
# 35.3932372809788

# %%
print(f"전체가구 소비 중 비소비지출금액 소비지출, 비율: {tot_비소비지출금액_mean_2022:,}원 ({tot_비소비지출금액_per_2022:.2f}%)")
print(f"1인가구 소비 중 비소비지출금액 소비지출, 비율: {sin_tot_비소비지출금액_mean_2022:,}원 ({sin_tot_비소비지출금액_per_2022:.2f}%)")
# Out:
# 전체가구 소비 중 비소비지출금액 소비지출, 비율: 874,210원 (35.19%)
# 1인가구 소비 중 비소비지출금액 소비지출, 비율: 517,172원 (35.39%)

# %%
# 조건으로 검색하기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat = pd.read_csv("./data/2023_1인가구.csv", encoding='cp949') ; dat
dat_2023 = dat.copy()

# %%
## [데이터 필요한 행만 전처리]

dat_2023.rename(columns={
    '가계지출금액' : '전체소비지출','가계지출_소비지출금액' : '소비지출','가계지출_소비지출_식료품비주류음료구입비' : '식료품음료구입',
    '가계지출_소비지출_식료품비주류음료_곡물구입비' : '식료품_곡물구입','가계지출_소비지출_식료품비주류음료_곡물가공품구입비' : '식료품_곡물가공품구입',
    '가계지출_소비지출_식료품비주류음료_빵떡류구입비' : '식료품_빵떡류구입','가계지출_소비지출_식료품비주류음료_육류구입비' : '식료품_육류구입',
    '가계지출_소비지출_식료품비주류음료_육류가공품구입비' : '식료품_육류가공품구입','가계지출_소비지출_식료품비주류음료_신선수산동물구입비' : '식료품_신선수산동물구입',
    '가계지출_소비지출_식료품비주류음료_염건수산동물구입비' : '식료품_염건수산동물구입','가계지출_소비지출_식료품비주류음료_기타수산동물가공구입비' : '식료품_기타수산동물가공구입',
    '가계지출_소비지출_식료품비주류음료_유제품및알구입비' : '식료품_유제품알구입','가계지출_소비지출_식료품비주류음료_유지류구입비' : '식료품_유지류구입',
    '가계지출_소비지출_식료품비주류음료_과일가공품구입비' : '식료품_과일가공품구입','가계지출_소비지출_식료품비주류음료_채소가공품구입비' : '식료품_채소가공품구입',
    '가계지출_소비지출_식료품비주류음료_해조가공품구입비' : '식료품_해조가공품구입','가계지출_소비지출_식료품비주류음료_당류과자류구입비' : '식료품_당류과자류구입',
    '가계지출_소비지출_식료품비주류음료_조미식품구입비' : '식료품_조미식품구입','가계지출_소비지출_식료품비주류음료_기타식품구입비' : '식료품_기타식품구입',
    '가계지출_소비지출_식료품비주류음료_커피차구입비' : '식료품_커피차구입','가계지출_소비지출_식료품비주류음료_쥬스기타음료구입비' : '식료품_쥬스음료구입',
    '가계지출_소비지출_주류담배구입비' : '주류담배구입','가계지출_소비지출_주류담배_주류구입비' : '주류구입','가계지출_소비지출_주류담배_담배구입비' : '담배구입',
    '가계지출_소비지출_의류신발구입비' : '의류신발구입','가계지출_소비지출_의류신발_직물및외의구입비' : '의류신발_직물및외의구입','가계지출_소비지출_의류신발_내의구입비' : '의류신발_내의구입',
    '가계지출_소비지출_의류신발_기타의복구입비' : '의류신발_기타의복구입','가계지출_소비지출_의류신발_의복관련서비스구입비' : '의류신발_의복관련서비스구입',
    '가계지출_소비지출_의류신발_신발구입비' : '의류신발_신발구입','가계지출_소비지출_의류신발_신발서비스구입비' : '의류신발_신발서비스구입','가계지출_소비지출_주거수도광열비' : '주거수도광열비',
    '가계지출_소비지출_주거수도광열_실제주거비구입비' : '주거수도광열_실제주거비구입','가계지출_소비지출_주거수도광열_주택유지수선구입비' : '주거수도광열_주택유지수선구입',
    '가계지출_소비지출_주거수도광열_상하수도폐기물처리비' : '주거수도광열_상하수도폐기물처리','가계지출_소비지출_주거수도광열_기타주거관련서비스구입비' : '주거수도광열_기타주거관련서비스구입',
    '가계지출_소비지출_주거수도광열_연료비구입비' : '주거수도광열_연료비구입','가계지출_소비지출_가정용품가사서비스이용금액' : '가정용품가사서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가구조명구입비' : '가정용품가사서비스_가구조명구입','가계지출_소비지출_가정용품가사서비스_실내장식구입비' : '가정용품가사서비스_실내장식구입',
    '가계지출_소비지출_가정용품가사서비스_가구조명장식서비스이용금액' : '가정용품가사서비스_가구조명장식서비스이용',
    '가계지출_소비지출_가정용품가사서비스_가정용섬유구입비' : '가정용품가사서비스_가정용섬유구입','가계지출_소비지출_가정용품가사서비스_가전가정용기기구입비' : '가정용품가사서비스_가전가정용기기구입',
    '가계지출_소비지출_가정용품가사서비스_가전관련서비스이용금액' : '가정용품가사서비스_가전관련서비스이용','가계지출_소비지출_가정용품가사서비스_가사용품구입비' : '가정용품가사서비스_가사용품구입',
    '가계지출_소비지출_가정용품가사서비스_가정용공구기타구입비' : '가정용품가사서비스_가정용공구기타구입','가계지출_소비지출_가정용품가사서비스_가사소모품구입비' : '가정용품가사서비스_가사소모품구입',
    '가계지출_소비지출_가정용품가사서비스_가사서비스금액' : '가정용품가사서비스_가사서비스','가계지출_소비지출_보건제품구입비' : '보건제품구입',
    '가계지출_소비지출_보건_의약품구입비' : '보건_의약품구입','가계지출_소비지출_보건_의료용소모품구입비' : '보건_의료용소모품구입',
    '가계지출_소비지출_보건_보건의료용품기구구입비' : '보건_보건의료용품기구구입','가계지출_소비지출_보건_외래의료서비스이용금액' : '보건_외래의료서비스이용',
    '가계지출_소비지출_보건_치과서비스이용금액' : '보건_치과서비스이용','가계지출_소비지출_보건_기타의료서비스이용금액' : '보건_기타의료서비스이용',
    '가계지출_소비지출_보건_입원서비스이용금액' : '보건_입원서비스이용','가계지출_소비지출_교통비' : '교통비','가계지출_소비지출_교통_자동차구입비' : '교통_자동차구입',
    '가계지출_소비지출_교통_기타운송기구구입비' : '교통_기타운송기구구입','가계지출_소비지출_교통_운송기구유지수리비' : '교통_운송기구유지수리',
    '가계지출_소비지출_교통_운송기구연료비' : '교통_운송기구연료','가계지출_소비지출_교통_기타개인교통서비스이용금액' : '교통_기타개인교통서비스이용',
    '가계지출_소비지출_교통_철도운송금액' : '교통_철도운송','가계지출_소비지출_교통_육상운송금액' : '교통_육상운송','가계지출_소비지출_교통_기타운송금액' : '교통_기타운송',
    '가계지출_소비지출_교통_기타교통관련서비스이용금액' : '교통_기타교통관련서비스이용','가계지출_소비지출_통신비' : '통신비','가계지출_소비지출_통신_우편서비스이용금액' : '통신_우편서비스이용',
    '가계지출_소비지출_통신_통신장비구입비' : '통신_통신장비구입','가계지출_소비지출_통신_통신서비스이용금액' : '통신_통신서비스이용','가계지출_소비지출_오락문화비' : '오락문화비',
    '가계지출_소비지출_오락문화_영상음향기기구입비' : '오락문화_영상음향기기구입','가계지출_소비지출_오락문화_사진광학장비구입비' : '오락문화_사진광학장비구입',
    '가계지출_소비지출_오락문화_정보처리장치구입비' : '오락문화_정보처리장치구입','가계지출_소비지출_오락문화_기록매체구입비' : '오락문화_기록매체구입',
    '가계지출_소비지출_오락문화_영상음향정보기기수리비' : '오락문화_영상음향정보기기수리','가계지출_소비지출_오락문화_내구재구입비' : '오락문화_내구재구입',
    '가계지출_소비지출_오락문화_악기기구구입비' : '오락문화_악기기구구입','가계지출_소비지출_오락문화_오락문화내구재유지수리비' : '오락문화_오락문화내구재유지수리',
    '가계지출_소비지출_오락문화_장난감취미용품구입비' : '오락문화_장난감취미용품구입','가계지출_소비지출_오락문화_캠핑운동관련용품구입비' : '오락문화_캠핑운동관련용품구입',
    '가계지출_소비지출_오락문화_화훼관련용품구입비' : '오락문화_화훼관련용품구입','가계지출_소비지출_오락문화_애완동물관련물품구입비' : '애완동물_물품구입',
    '가계지출_소비지출_오락문화_화훼애완동물서비스이용금액' : '애완동물_서비스이용','가계지출_소비지출_오락문화_운동오락서비스이용금액' : '운동오락_서비스이용',
    '가계지출_소비지출_오락문화_문화서비스이용금액' : '문화_서비스이용','가계지출_소비지출_오락문화_복권구입비' : '복권_구입비','가계지출_소비지출_오락문화_서적구입비' : '서적_구입비',
    '가계지출_소비지출_오락문화_기타인쇄물구입비' : '인쇄물_구입비','가계지출_소비지출_오락문화_문구구입비' : '문구_구입비','가계지출_소비지출_오락문화_단체여행경비' : '단체여행_경비',
    '가계지출_소비지출_교육비' : '교육비','가계지출_소비지출_교육_정규교육비' : '정규교육비','가계지출_소비지출_교육_초등교육비' : '초등교육비','가계지출_소비지출_교육_중등교육비' : '중등교육비',
    '가계지출_소비지출_교육_고등교육비' : '고등교육비','가계지출_소비지출_교육_학원보습교육비' : '학원보습교육비','가계지출_소비지출_교육_학생학원교육비' : '학생학원교육비',
    '가계지출_소비지출_교육_성인학원비' : '성인학원비','가계지출_소비지출_교육_기타교육비' : '기타교육비','가계지출_소비지출_음식숙박비' : '음식숙박비','가계지출_소비지출_음식숙박_식대' : '식대',
    '가계지출_소비지출_음식숙박_숙박비' : '숙박비','가계지출_소비지출_기타상품서비스이용금액' : '기타상품서비스이용','가계지출_소비지출_기타상품서비스_이미용서비스이용금액' : '이미용서비스이용',
    '가계지출_소비지출_기타상품서비스_이미용기기구입비' : '이미용기기구입','가계지출_소비지출_기타상품서비스_위생이미용용품구입비' : '위생이미용용품구입',
    '가계지출_소비지출_기타상품서비스_시계장신구구입비' : '시계장신구구입','가계지출_소비지출_기타상품서비스_기타개인용품구입비' : '기타개인용품구입',
    '가계지출_소비지출_기타상품서비스_복지시설비용금액' : '복지시설비용','가계지출_소비지출_기타상품서비스_보험료' : '보험료','가계지출_소비지출_기타상품서비스_기타금융구입비' : '기타금융구입',
    '가계지출_소비지출_기타상품서비스_기타서비스금액구입비' : '기타서비스금액구입','가계지출_비소비지출금액' : '비소비지출금액','가계지출_비소비지출_경상조세' : '비경상조세',
    '가계지출_비소비지출_비경상조세' : '비경상조세','가계지출_비소비지출_연금기여금' : '연금기여금','가계지출_비소비지출_사회보장구입비' : '사회보장구입비',
    '가계지출_비소비지출_이자비용' : '이자비용','가계지출_비소비지출_가구간이전지출금액' : '가구간이전지출금액','가계지출_비소비지출_비영리단체이전지출금액' : '비영리단체이전지출금액'
}, inplace=True
)

# %%
dat_2023.columns
# Out:
# Index(['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드',
#        '가구주_성별코드', '가구주_연령', '가구주_취업여부',
#        ...
#        '기타서비스금액구입', '비소비지출금액', '비경상조세', '비경상조세', '연금기여금', '사회보장구입비', '이자비용',
#        '가구간이전지출금액', '비영리단체이전지출금액', '도시읍면부구분코드'],
#       dtype='object', length=139)

# %%
# 행 전처리

dat_2023 = dat_2023[['조사연월', '가구일련번호', '가구구분코드', '가구원수', '취업인원수', '노인가구여부', '배우자코드', '가구주_성별코드', '가구주_연령', '가구주_취업여부', '거처구분코드',
                     '자동차보유대수','입주형태코드', '월세평가금액', '전세보증금', '소득구간코드', '전체소비지출', '소비지출','식료품음료구입','식료품_곡물구입',
                     '식료품_곡물가공품구입','식료품_빵떡류구입','식료품_육류구입','식료품_육류가공품구입','식료품_신선수산동물구입','식료품_염건수산동물구입','식료품_기타수산동물가공구입',
                     '식료품_유제품알구입','식료품_유지류구입','식료품_과일가공품구입','식료품_채소가공품구입','식료품_해조가공품구입','식료품_당류과자류구입','식료품_조미식품구입',
                     '식료품_기타식품구입','식료품_커피차구입','식료품_쥬스음료구입','주류담배구입','주류구입','담배구입','의류신발구입','의류신발_직물및외의구입','의류신발_내의구입',
                     '의류신발_기타의복구입','의류신발_의복관련서비스구입','의류신발_신발구입','의류신발_신발서비스구입','주거수도광열비','주거수도광열_실제주거비구입',
                     '주거수도광열_주택유지수선구입','주거수도광열_상하수도폐기물처리','주거수도광열_기타주거관련서비스구입','주거수도광열_연료비구입','가정용품가사서비스이용',
                     '가정용품가사서비스_가구조명구입','가정용품가사서비스_실내장식구입','가정용품가사서비스_가구조명장식서비스이용','가정용품가사서비스_가정용섬유구입',
                     '가정용품가사서비스_가전가정용기기구입','가정용품가사서비스_가전관련서비스이용','가정용품가사서비스_가사용품구입','가정용품가사서비스_가정용공구기타구입',
                     '가정용품가사서비스_가사소모품구입','가정용품가사서비스_가사서비스','보건제품구입','보건_의약품구입','보건_의료용소모품구입','보건_보건의료용품기구구입',
                     '보건_외래의료서비스이용','보건_치과서비스이용','보건_기타의료서비스이용','보건_입원서비스이용','교통비','교통_자동차구입','교통_기타운송기구구입','교통_운송기구유지수리',
                     '교통_운송기구연료','교통_기타개인교통서비스이용','교통_철도운송','교통_육상운송','교통_기타운송','교통_기타교통관련서비스이용','통신비','통신_우편서비스이용',
                     '통신_통신장비구입','통신_통신서비스이용','오락문화비','오락문화_영상음향기기구입','오락문화_사진광학장비구입','오락문화_정보처리장치구입','오락문화_기록매체구입',
                     '오락문화_영상음향정보기기수리','오락문화_내구재구입','오락문화_악기기구구입','오락문화_오락문화내구재유지수리','오락문화_장난감취미용품구입','오락문화_캠핑운동관련용품구입',
                     '오락문화_화훼관련용품구입','애완동물_물품구입','애완동물_서비스이용','운동오락_서비스이용','문화_서비스이용','복권_구입비','서적_구입비','인쇄물_구입비','문구_구입비',
                     '단체여행_경비','교육비','정규교육비','초등교육비','중등교육비','고등교육비','학원보습교육비','학생학원교육비','성인학원비','기타교육비','음식숙박비','식대','숙박비',
                     '기타상품서비스이용','이미용서비스이용','이미용기기구입','위생이미용용품구입','시계장신구구입','기타개인용품구입','복지시설비용','보험료','기타금융구입','기타서비스금액구입',
                     '비소비지출금액','비경상조세','비경상조세','연금기여금','사회보장구입비','이자비용','가구간이전지출금액','비영리단체이전지출금액']]

# %%
dat_2023['가구구분코드'] = dat_2023['가구구분코드'].replace({1: '근로자 가구', 2: '비근로자 가구'})
dat_2023['노인가구여부'] = dat_2023['노인가구여부'].replace({0: '아니요', 1: '예'})
dat_2023['배우자코드'] = dat_2023['배우자코드'].replace({1: '현재(동거)', 2: '현재(비동거)', 3:'부재'})
dat_2023['가구주_성별코드'] = dat_2023['가구주_성별코드'].replace({1: '남성', 2: '여성'})
dat_2023['가구주_취업여부'] = dat_2023['가구주_취업여부'].replace({1: '취업', 2: '실업자'})
dat_2023['거처구분코드'] = dat_2023['거처구분코드'].replace({1: '단독주택(다세대 포함)', 2: '아파트', 3: '연립주택', 4: '다가구주택', 5: '비주거용 건물', 6: '오피스텔', 7: '기타'})
dat_2023['입주형태코드'] = dat_2023['입주형태코드'].replace({1: '내 집', 2: '무료주택', 3: '회사주택', 4: '임대', 5: '영구임대', 6: '보증금 월세', 7: '보증금 없는 월세'})
dat_2023['소득구간코드'] = dat_2023['소득구간코드'].replace({1: '100만원 미만', 2: '100~200만원', 3: '200~300만원', 4: '300~400만원', 5: '400~500만원', 6: '500~600만원', 7: '600~700만원', 8: '700만원 이상'})
# dat_2023['도시읍면부구분코드'] = dat_2023['도시읍면부구분코드'].replace({0: '비도시', 1: '도시'})

# %%
dat_2023
# Out:
#          조사연월  가구일련번호   가구구분코드  가구원수  취업인원수 노인가구여부   배우자코드 가구주_성별코드  가구주_연령  \
# 0      202300       1   근로자 가구     3      2    아니요  현재(동거)       남성      43
# 1      202300       2   근로자 가구     2      1    아니요  현재(동거)       남성      66
# 2      202300       3  비근로자 가구     5      5    아니요  현재(동거)       여성      51
# 3      202300       4   근로자 가구     2      2    아니요      부재       여성      50
# 4      202300       5   근로자 가구     1      1    아니요      부재       여성      34
# ...       ...     ...      ...   ...    ...    ...     ...      ...     ...
# 13139  202300   13140  비근로자 가구     1      0      예      부재       여성      80
# 13140  202300   13141  비근로자 가구     2      2    아니요      부재       여성      56
# 13141  202300   13142  비근로자 가구     2      2      예  현재(동거)       남성      73
# 13142  202300   13143  비근로자 가구     3      2    아니요  현재(동거)       남성      47
# 13143  202300   13144   근로자 가구     1      1    아니요      부재       남성      55
#
# ...

# %%
def age(가구주_연령):
    if 가구주_연령 < 20:
        return '10대'
    elif 20 <= 가구주_연령 < 30:
        return '20대'
    elif 30 <= 가구주_연령 < 40:
        return '30대'
    elif 40 <= 가구주_연령 < 50:
        return '40대'
    elif 50 <= 가구주_연령 < 60:
        return '50대'
    elif 60 <= 가구주_연령 < 70:
        return '60대'
    elif 70 <= 가구주_연령:
        return '70대 이상'

# 데이터 연령대별 구분
dat_2023.loc[:,'연령대'] = dat_2023['가구주_연령'].apply(age)
dat_2023.연령대
# Out:
# 0           40대
# 1           60대
# 2           50대
# 3           50대
# 4           30대
#           ...
# 13139    70대 이상
# 13140       50대
# 13141    70대 이상
# 13142       40대
# 13143       50대
# Name: 연령대, Length: 13144, dtype: object

# %%
# 연령대별 가구원 수 분포
dat_2023.groupby('연령대')['가구원수'].value_counts().unstack().fillna(0).astype(int)
# Out:
# 가구원수       1     2    3    4    5   6  7  8  9
# 연령대
# 10대       16     0    1    0    0   0  0  0  0
# 20대      658   119   47   10    0   0  0  0  0
# 30대      598   369  357  252   33   3  1  0  0
# 40대      367   371  556  760  159  22  1  0  1
# 50대      620   950  709  408   80  12  2  0  0
# 60대      868  1506  439   87   15   5  0  0  0
# 70대 이상  1106  1465  143   19    7   1  0  1  0

# %% [markdown]
# ##### 전체가구 지출 (total_expend) | 1인가구 지출 (single_expend )

# %% [markdown]
# 전체가구 소비지출

# %% [markdown]
# box plot 그려서 분포 확인해봐야 함

# %%
total_expend_2023 = dat_2023['소비지출']

total_expend_2023.info # 전체가구 소비지출
# Out:
# <bound method Series.info of 0        3743449
# 1        1568344
# 2        2549069
# 3        1646044
# 4        2110320
#           ...
# 13139     874224
# 13140    1380757
# 13141    2390831
# 13142    3606455
# 13143    1707926
# Name: 소비지출, Length: 13144, dtype: int64>

# %% [markdown]
# --2차 전처리--
#
# 전체가구 소비지출 이상치확인 (9,510개중 6,730개) <2,780개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(total_expend_2023, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(total_expend_2023, 25)
Q3 = np.percentile(total_expend_2023, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(total_expend_2023), f'Median: {np.median(total_expend_2023):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(total_expend_2023):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(total_expend_2023):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('전체가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_total_expend_2023 = ((total_expend_2023 >= lower_limit) & (total_expend_2023 <= upper_limit))
total_expend_2023[cleaned_total_expend_2023]
# Out:
# 0        3743449
# 1        1568344
# 2        2549069
# 3        1646044
# 4        2110320
#           ...
# 13139     874224
# 13140    1380757
# 13141    2390831
# 13142    3606455
# 13143    1707926
# Name: 소비지출, Length: 12583, dtype: int64

# %%
# 이상치 제거
cleaned_total_expend_2023 = total_expend_2023[(total_expend_2023 >= lower_limit) & (total_expend_2023 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_total_expend_2023, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_total_expend_2023, 25)
Q3 = np.percentile(cleaned_total_expend_2023, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_total_expend_2023), f'Median: {np.median(cleaned_total_expend_2023):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_total_expend_2023):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_total_expend_2023):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('전체가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 전체가구 평균 소비지출
total_expend_mean_2023 = int(total_expend_2023.mean())
print(f"전체가구의 평균 소비지출: {total_expend_mean_2023:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,650,865원

# %%
# 전체가구 평균 소비지출 이상치 제거 후
cleaned_total_expend_mean_2023 = int(cleaned_total_expend_2023.mean())
print(f"전체가구의 평균 소비지출: {cleaned_total_expend_mean_2023:,}원")
# Out:
# 전체가구의 평균 소비지출: 2,347,347원

# %% [markdown]
# 1인가구 소비지출

# %%
# 가구원수 1로 설정하여 9510개에서 2827개의 데이터 전처리

single_expend_2023 = dat_2023.loc[dat['가구원수'] == 1, '소비지출']

single_expend_2023.info # 1인가구 소비지출
# Out:
# <bound method Series.info of 4        2110320
# 13       1114844
# 18       1934069
# 20       1163093
# 25        966224
#           ...
# 13127    3230432
# 13130     782346
# 13134     532728
# 13139     874224
# 13143    1707926
# Name: 소비지출, Length: 4233, dtype: int64>

# %%
# 1인가구 이상치 식별
(single_expend_2023 < lower_limit) & (single_expend_2023 > upper_limit)
# Out:
# 4        False
# 13       False
# 18       False
# 20       False
# 25       False
#          ...
# 13127    False
# 13130    False
# 13134    False
# 13139    False
# 13143    False
# Name: 소비지출, Length: 4233, dtype: bool

# %% [markdown]
# -- 2차전처리 --
#
# * 1인가구 소비지출 이상치확인 (2827개중 2701개) <126개 이상치 식별>

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(single_expend_2023, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(single_expend_2023, 25)
Q3 = np.percentile(single_expend_2023, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')  # 오른쪽에 출력
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, np.median(single_expend_2023), f'Median: {np.median(total_expend_2023):,}원', color='black', verticalalignment='center', horizontalalignment='left')  # 왼쪽에 출력
plt.text(1, lower_limit, f'Min: {np.min(single_expend_2023):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력
plt.text(1, upper_limit, f'Max: {np.max(single_expend_2023):,}원', verticalalignment='center', horizontalalignment='right')  # 왼쪽에 출력

plt.title('1인가구 소비지출')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_single_expend_2023 = ((single_expend_2023 >= lower_limit) & (single_expend_2023 <= upper_limit))
single_expend_2023[cleaned_single_expend_2023]
# Out:
# 4        2110320
# 13       1114844
# 18       1934069
# 20       1163093
# 25        966224
#           ...
# 13127    3230432
# 13130     782346
# 13134     532728
# 13139     874224
# 13143    1707926
# Name: 소비지출, Length: 4029, dtype: int64

# %%
# 이상치 제거
cleaned_single_expend_2023 = single_expend_2023[(single_expend_2023 >= lower_limit) & (single_expend_2023 <= upper_limit)]

plt.figure(figsize=(10, 8))  # 그림 크기 조정

plt.boxplot(cleaned_single_expend_2023, showmeans=True)

# 이상치 기준 라인을 그립니다.
Q1 = np.percentile(cleaned_single_expend_2023, 25)
Q3 = np.percentile(cleaned_single_expend_2023, 75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

plt.axhline(y=upper_limit, color='r', linestyle='--', label='Upper Limit')
plt.axhline(y=lower_limit, color='r', linestyle='--', label='Lower Limit')

# 특정 값 출력
plt.text(1.05, Q1, f'Q1: {Q1:,}원', verticalalignment='center', horizontalalignment='left')
plt.text(0.95, Q3, f'Q3: {Q3:,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, np.median(cleaned_single_expend_2023), f'Median: {np.median(cleaned_single_expend_2023):,}원', color='black', verticalalignment='center', horizontalalignment='left')
plt.text(1, lower_limit, f'Min: {np.min(cleaned_single_expend_2023):,}원', verticalalignment='center', horizontalalignment='right')
plt.text(1, upper_limit, f'Max: {np.max(cleaned_single_expend_2023):,}원', verticalalignment='center', horizontalalignment='right')

plt.title('1인가구 소비지출 (이상치 제거)')
plt.xlabel('소비지출 금액')
plt.yticks([])
plt.legend()
plt.show()

# %%
# 1인가구 평균 소비지출
single_expend_mean_2023 = int(single_expend_2023.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {single_expend_mean_2023:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,557,413원

# %%
# 1인가구 평균 소비지출 이상치 제거 후
cleaned_single_expend_mean_2023 = int(cleaned_single_expend_2023.mean())
print('-' * 50)
print(f"1인가구의 평균 소비지출: {cleaned_single_expend_mean_2023:,}원")
# Out:
# --------------------------------------------------
# 1인가구의 평균 소비지출: 1,376,064원

# %% [markdown]
# 전체가구 식료품음료구입 평균소비 비용, 비율

# %%
tot_식료품음료구입_2023 = dat_2023['식료품음료구입']
tot_식료품음료구입_mean_2023 = int(tot_식료품음료구입_2023.mean())
tot_식료품음료구입_per_2023 = (tot_식료품음료구입_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 식료품음료구입 소비 비율

print(tot_식료품음료구입_2023)
print(tot_식료품음료구입_mean_2023)
print(tot_식료품음료구입_per_2023)
# Out:
# 0        713290
# 1        867930
# 2        351080
# 3        438190
# 4        322078
#           ...
# 13139    248233
# 13140    355633
# 13141    403937
# 13142    583286
# 13143     94860
# Name: 식료품음료구입, Length: 13144, dtype: int64
# 394255
# 14.872692498486343

# %% [markdown]
# 1인가구 식료품음료구입 평균소비 비용, 비율

# %%
sin_tot_식료품음료구입_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '식료품음료구입']
sin_tot_식료품음료구입_mean_2023 = int(sin_tot_식료품음료구입_2023.mean())
sin_tot_식료품음료구입_per_2023 = (sin_tot_식료품음료구입_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 식료품음료구입 소비 비율

print(sin_tot_식료품음료구입_2023)
print(sin_tot_식료품음료구입_mean_2023)
print(sin_tot_식료품음료구입_per_2023)
# Out:
# 4        322078
# 13       223825
# 18       101840
# 20       405520
# 25       183027
#           ...
# 13127    411795
# 13130     89050
# 13134    280213
# 13139    248233
# 13143     94860
# Name: 식료품음료구입, Length: 4233, dtype: int64
# 211686
# 13.592155709500306

# %%
print(f"전체가구 소비 중 식료품음료구입 소비지출, 비율: {tot_식료품음료구입_mean_2023:,}원 ({tot_식료품음료구입_per_2023:.2f}%)")
print(f"1인가구 소비 중 식료품음료구입 소비지출, 비율: {sin_tot_식료품음료구입_mean_2023:,}원 ({sin_tot_식료품음료구입_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 식료품음료구입 소비지출, 비율: 394,255원 (14.87%)
# 1인가구 소비 중 식료품음료구입 소비지출, 비율: 211,686원 (13.59%)

# %% [markdown]
# 전체가구 주류담배구입 평균소비 비용, 비율

# %%
tot_주류담배구입_2023 = dat_2023['주류담배구입']
tot_주류담배구입_mean_2023 = int(tot_주류담배구입_2023.mean())
tot_주류담배구입_per_2023 = (tot_주류담배구입_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 주류담배구입 소비 비율

print(tot_주류담배구입_2023)
print(tot_주류담배구입_mean_2023)
print(tot_주류담배구입_per_2023)
# Out:
# 0         74300
# 1         56250
# 2             0
# 3         15200
# 4        128207
#           ...
# 13139       550
# 13140      1390
# 13141      9500
# 13142    103538
# 13143      7415
# Name: 주류담배구입, Length: 13144, dtype: int64
# 37021
# 1.3965630086782994

# %% [markdown]
# 1인가구 주류담배구입 평균소비 비용, 비율

# %%
sin_tot_주류담배구입_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '주류담배구입']
sin_tot_주류담배구입_mean_2023 = int(sin_tot_주류담배구입_2023.mean())
sin_tot_주류담배구입_per_2023 = (sin_tot_주류담배구입_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 주류담배구입 소비 비율

print(sin_tot_주류담배구입_2023)
print(sin_tot_주류담배구입_mean_2023)
print(sin_tot_주류담배구입_per_2023)
# Out:
# 4        128207
# 13            0
# 18            0
# 20        41350
# 25         3333
#           ...
# 13127         0
# 13130      2740
# 13134         0
# 13139       550
# 13143      7415
# Name: 주류담배구입, Length: 4233, dtype: int64
# 32109
# 2.061688197029304

# %%
print(f"전체가구 소비 중 주류담배구입 소비지출, 비율: {tot_주류담배구입_mean_2023:,}원 ({tot_주류담배구입_per_2023:.2f}%)")
print(f"1인가구 소비 중 주류담배구입 소비지출, 비율: {sin_tot_주류담배구입_mean_2023:,}원 ({sin_tot_주류담배구입_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 주류담배구입 소비지출, 비율: 37,021원 (1.40%)
# 1인가구 소비 중 주류담배구입 소비지출, 비율: 32,109원 (2.06%)

# %% [markdown]
# 전체가구 의류신발구입 평균소비 비용, 비율

# %%
tot_의류신발구입_2023 = dat_2023['의류신발구입']
tot_의류신발구입_mean_2023 = int(tot_의류신발구입_2023.mean())
tot_의류신발구입_per_2023 = (tot_의류신발구입_mean_2023/ total_expend_mean_2023) * 100  # 전체가구 소비 중 의류신발구입 소비 비율

print(tot_의류신발구입_2023)
print(tot_의류신발구입_mean_2023)
print(tot_의류신발구입_per_2023)
# Out:
# 0        161700
# 1             0
# 2          3900
# 3             0
# 4        282761
#           ...
# 13139      3333
# 13140     77267
# 13141      6667
# 13142     62567
# 13143     12167
# Name: 의류신발구입, Length: 13144, dtype: int64
# 129684
# 4.892138981049582

# %% [markdown]
# 1인가구 의류신발구입 평균소비 비용, 비율

# %%
sin_tot_의류신발구입_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '의류신발구입']
sin_tot_의류신발구입_mean_2023 = int(sin_tot_의류신발구입_2023.mean())
sin_tot_의류신발구입_per_2023 = (sin_tot_의류신발구입_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 의류신발구입 소비 비율

print(sin_tot_의류신발구입_2023)
print(sin_tot_의류신발구입_mean_2023)
print(sin_tot_의류신발구입_per_2023)
# Out:
# 4        282761
# 13        25000
# 18       141973
# 20        53435
# 25        27967
#           ...
# 13127    196567
# 13130      1200
# 13134      5500
# 13139      3333
# 13143     12167
# Name: 의류신발구입, Length: 4233, dtype: int64
# 76137
# 4.888683990694825

# %%
print(f"전체가구 소비 중 의류신발구입 소비지출, 비율: {tot_의류신발구입_mean_2023:,}원 ({tot_의류신발구입_per_2023:.2f}%)")
print(f"1인가구 소비 중 의류신발구입 소비지출, 비율: {sin_tot_의류신발구입_mean_2023:,}원 ({sin_tot_의류신발구입_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 의류신발구입 소비지출, 비율: 129,684원 (4.89%)
# 1인가구 소비 중 의류신발구입 소비지출, 비율: 76,137원 (4.89%)

# %% [markdown]
# 전체가구 주거수도광열비 평균소비 비용, 비율

# %%
tot_주거수도광열비_2023 = dat_2023['주거수도광열비']
tot_주거수도광열비_mean_2023 = int(tot_주거수도광열비_2023.mean())
tot_주거수도광열비_per_2023 = (tot_주거수도광열비_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 주거수도광열비 소비 비율

print(tot_주거수도광열비_2023)
print(tot_주거수도광열비_mean_2023)
print(tot_주거수도광열비_per_2023)
# Out:
# 0        379150
# 1        186120
# 2        197210
# 3        538410
# 4        349990
#           ...
# 13139    391720
# 13140    122402
# 13141    279666
# 13142    716432
# 13143    981983
# Name: 주거수도광열비, Length: 13144, dtype: int64
# 324096
# 12.226046969574082

# %% [markdown]
# 1인가구 주거수도광열비 평균소비 비용, 비율

# %%
sin_tot_주거수도광열비_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '주거수도광열비']
sin_tot_주거수도광열비_mean_2023 = int(sin_tot_주거수도광열비_2023.mean())
sin_tot_주거수도광열비_per_2023 = (sin_tot_주거수도광열비_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 주거수도광열비 소비 비율

print(sin_tot_주거수도광열비_2023)
print(sin_tot_주거수도광열비_mean_2023)
print(sin_tot_주거수도광열비_per_2023)
# Out:
# 4        349990
# 13       251704
# 18       438040
# 20        81435
# 25        48420
#           ...
# 13127     48682
# 13130    522244
# 13134     81497
# 13139    391720
# 13143    981983
# Name: 주거수도광열비, Length: 4233, dtype: int64
# 284772
# 18.284937906643904

# %%
print(f"전체가구 소비 중 주거수도광열비 소비지출, 비율: {tot_주거수도광열비_mean_2023:,}원 ({tot_주거수도광열비_per_2023:.2f}%)")
print(f"1인가구 소비 중 주거수도광열비 소비지출, 비율: {sin_tot_주거수도광열비_mean_2023:,}원 ({sin_tot_주거수도광열비_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 주거수도광열비 소비지출, 비율: 324,096원 (12.23%)
# 1인가구 소비 중 주거수도광열비 소비지출, 비율: 284,772원 (18.28%)

# %% [markdown]
# 전체가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
tot_가정용품가사서비스이용_2023 = dat_2023['가정용품가사서비스이용']
tot_가정용품가사서비스이용_mean_2023 = int(tot_가정용품가사서비스이용_2023.mean())
tot_가정용품가사서비스이용_per_2023 = (tot_가정용품가사서비스이용_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 가정용품가사서비스이용 소비 비율

print(tot_가정용품가사서비스이용_2023)
print(tot_가정용품가사서비스이용_mean_2023)
print(tot_가정용품가사서비스이용_per_2023)
# Out:
# 0         56380
# 1         48910
# 2         57200
# 3         80980
# 4         46591
#           ...
# 13139     15130
# 13140     29955
# 13141     22983
# 13142    138097
# 13143      4050
# Name: 가정용품가사서비스이용, Length: 13144, dtype: int64
# 119594
# 4.511508507600349

# %% [markdown]
# 1인가구 가정용품가사서비스이용 평균소비 비용, 비율

# %%
sin_tot_가정용품가사서비스이용_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '가정용품가사서비스이용']
sin_tot_가정용품가사서비스이용_mean_2023 = int(sin_tot_가정용품가사서비스이용_2023.mean())
sin_tot_가정용품가사서비스이용_per_2023 = (sin_tot_가정용품가사서비스이용_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 가정용품가사서비스이용 소비 비율

print(sin_tot_가정용품가사서비스이용_2023)
print(sin_tot_가정용품가사서비스이용_mean_2023)
print(sin_tot_가정용품가사서비스이용_per_2023)
# Out:
# 4         46591
# 13        14250
# 18        60180
# 20        47595
# 25        14738
#           ...
# 13127    168547
# 13130      4708
# 13134     35483
# 13139     15130
# 13143      4050
# Name: 가정용품가사서비스이용, Length: 4233, dtype: int64
# 64320
# 4.12992571655688

# %%
print(f"전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {tot_가정용품가사서비스이용_mean_2023:,}원 ({tot_가정용품가사서비스이용_per_2023:.2f}%)")
print(f"1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: {sin_tot_가정용품가사서비스이용_mean_2023:,}원 ({sin_tot_가정용품가사서비스이용_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 119,594원 (4.51%)
# 1인가구 소비 중 가정용품가사서비스이용 소비지출, 비율: 64,320원 (4.13%)

# %% [markdown]
# 전체가구 보건제품구입 평균소비 비용, 비율

# %%
tot_보건제품구입_2023 = dat_2023['보건제품구입']
tot_보건제품구입_mean_2023 = int(tot_보건제품구입_2023.mean())
tot_보건제품구입_per_2023 = (tot_보건제품구입_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 보건제품구입 소비 비율

print(tot_보건제품구입_2023)
print(tot_보건제품구입_mean_2023)
print(tot_보건제품구입_per_2023)
# Out:
# 0          5100
# 1         20900
# 2         26800
# 3         14000
# 4        140190
#           ...
# 13139    107043
# 13140     76955
# 13141    530700
# 13142    170247
# 13143     63880
# Name: 보건제품구입, Length: 13144, dtype: int64
# 241749
# 9.119626989680727

# %% [markdown]
# 1인가구 보건제품구입 평균소비 비용, 비율

# %%
sin_tot_보건제품구입_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '보건제품구입']
sin_tot_보건제품구입_mean_2023 = int(sin_tot_보건제품구입_2023.mean())
sin_tot_보건제품구입_per_2023 = (sin_tot_보건제품구입_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 보건제품구입 소비 비율

print(sin_tot_보건제품구입_2023)
print(sin_tot_보건제품구입_mean_2023)
print(sin_tot_보건제품구입_per_2023)
# Out:
# 4        140190
# 13            0
# 18       511373
# 20        63400
# 25       257462
#           ...
# 13127    457750
# 13130    108820
# 13134       417
# 13139    107043
# 13143     63880
# Name: 보건제품구입, Length: 4233, dtype: int64
# 138641
# 8.902006083164839

# %%
print(f"전체가구 소비 중 보건제품구입 소비지출, 비율: {tot_보건제품구입_mean_2023:,}원 ({tot_보건제품구입_per_2023:.2f}%)")
print(f"1인가구 소비 중 보건제품구입 소비지출, 비율: {sin_tot_보건제품구입_mean_2023:,}원 ({sin_tot_보건제품구입_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 보건제품구입 소비지출, 비율: 241,749원 (9.12%)
# 1인가구 소비 중 보건제품구입 소비지출, 비율: 138,641원 (8.90%)

# %% [markdown]
# 전체가구 교통비 평균소비 비용, 비율

# %%
tot_교통비_2023 = dat_2023['교통비']
tot_교통비_mean_2023 = int(tot_교통비_2023.mean())
tot_교통비_per_2023 = (tot_교통비_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 교통비 소비 비율

print(tot_교통비_2023)
print(tot_교통비_mean_2023)
print(tot_교통비_per_2023)
# Out:
# 0        181400
# 1         60000
# 2        278140
# 3         63700
# 4        192633
#           ...
# 13139      1333
# 13140    137333
# 13141    122316
# 13142    281162
# 13143    280025
# Name: 교통비, Length: 13144, dtype: int64
# 327989
# 12.372904693373671

# %% [markdown]
# 1인가구 교통비 평균소비 비용, 비율

# %%
sin_tot_교통비_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '교통비']
sin_tot_교통비_mean_2023 = int(sin_tot_교통비_2023.mean())
sin_tot_교통비_per_2023 = (sin_tot_교통비_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 교통비 소비 비율

print(sin_tot_교통비_2023)
print(sin_tot_교통비_mean_2023)
print(sin_tot_교통비_per_2023)
# Out:
# 4        192633
# 13       154450
# 18        95331
# 20        57410
# 25        71683
#           ...
# 13127     45348
# 13130         0
# 13134     28550
# 13139      1333
# 13143    280025
# Name: 교통비, Length: 4233, dtype: int64
# 169453
# 10.880415149995537

# %% [markdown]
# 전체가구 통신비 평균소비 비용, 비율

# %%
tot_통신비_2023 = dat_2023['통신비']
tot_통신비_mean_2023 = int(tot_통신비_2023.mean())
tot_통신비_per_2023 = (tot_통신비_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 통신비 소비 비율

print(tot_통신비_2023)
print(tot_통신비_mean_2023)
print(tot_통신비_per_2023)
# Out:
# 0        145490
# 1        110900
# 2        271500
# 3        210560
# 4         51992
#           ...
# 13139     47500
# 13140     62704
# 13141    107645
# 13142    218248
# 13143     60732
# Name: 통신비, Length: 13144, dtype: int64
# 117431
# 4.429912500259349

# %% [markdown]
# 1인가구 통신비 평균소비 비용, 비율

# %%
sin_tot_통신비_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '통신비']
sin_tot_통신비_mean_2023 = int(sin_tot_통신비_2023.mean())
sin_tot_통신비_per_2023 = (sin_tot_통신비_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 통신비 소비 비율

print(sin_tot_통신비_2023)
print(sin_tot_통신비_mean_2023)
print(sin_tot_통신비_per_2023)
# Out:
# 4        51992
# 13       33897
# 18       77074
# 20       44248
# 25       46315
#          ...
# 13127    48295
# 13130    18514
# 13134    43520
# 13139    47500
# 13143    60732
# Name: 통신비, Length: 4233, dtype: int64
# 61236
# 3.931905024550328

# %% [markdown]
# 전체가구 오락문화비 평균소비 비용, 비율

# %%
tot_오락문화비_2023 = dat_2023['오락문화비']
tot_오락문화비_mean_2023 = int(tot_오락문화비_2023.mean())
tot_오락문화비_per_2023 = (tot_오락문화비_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 오락문화비 소비 비율

print(tot_오락문화비_2023)
print(tot_오락문화비_mean_2023)
print(tot_오락문화비_per_2023)
# Out:
# 0        133150
# 1         50780
# 2         87880
# 3         35600
# 4        145292
#           ...
# 13139     32580
# 13140     20103
# 13141     83837
# 13142     75422
# 13143     48457
# Name: 오락문화비, Length: 13144, dtype: int64
# 182923
# 6.900502288875518

# %% [markdown]
# 1인가구 오락문화비 평균소비 비용, 비율

# %%
sin_tot_오락문화비_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '오락문화비']
sin_tot_오락문화비_mean_2023 = int(sin_tot_오락문화비_2023.mean())
sin_tot_오락문화비_per_2023 = (sin_tot_오락문화비_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 오락문화비 소비 비율

print(sin_tot_오락문화비_2023)
print(sin_tot_오락문화비_mean_2023)
print(sin_tot_오락문화비_per_2023)
# Out:
# 4         145292
# 13         54740
# 18        150436
# 20         36650
# 25         28583
#           ...
# 13127    1665785
# 13130      11550
# 13134       8917
# 13139      32580
# 13143      48457
# Name: 오락문화비, Length: 4233, dtype: int64
# 109570
# 7.0353849621134525

# %%
print(f"전체가구 소비 중 오락문화비 소비지출, 비율: {tot_오락문화비_mean_2023:,}원 ({tot_오락문화비_per_2023:.2f}%)")
print(f"1인가구 소비 중 오락문화비 소비지출, 비율: {sin_tot_오락문화비_mean_2023:,}원 ({sin_tot_오락문화비_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 오락문화비 소비지출, 비율: 182,923원 (6.90%)
# 1인가구 소비 중 오락문화비 소비지출, 비율: 109,570원 (7.04%)

# %% [markdown]
# 전체가구 교육비 평균소비 비용, 비율

# %%
tot_교육비_2023 = dat_2023['교육비']
tot_교육비_mean_2023 = int(tot_교육비_2023.mean())
tot_교육비_per_2023 = (tot_교육비_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 교육비 소비 비율

print(tot_교육비_2023)
print(tot_교육비_mean_2023)
print(tot_교육비_per_2023)
# Out:
# 0        801000
# 1             0
# 2             0
# 3             0
# 4             0
#           ...
# 13139         0
# 13140         0
# 13141         0
# 13142         0
# 13143         0
# Name: 교육비, Length: 13144, dtype: int64
# 169667
# 6.400439101953513

# %% [markdown]
# 1인가구 교육비 평균소비 비용, 비율

# %%
sin_tot_교육비_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '교육비']
sin_tot_교육비_mean_2023 = int(sin_tot_교육비_2023.mean())
sin_tot_교육비_per_2023 = (sin_tot_교육비_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 교육비 소비 비율

print(sin_tot_교육비_2023)
print(sin_tot_교육비_mean_2023)
print(sin_tot_교육비_per_2023)
# Out:
# 4        0
# 13       0
# 18       0
# 20       0
# 25       0
#         ..
# 13127    0
# 13130    0
# 13134    0
# 13139    0
# 13143    0
# Name: 교육비, Length: 4233, dtype: int64
# 24248
# 1.5569409013537194

# %%
print(f"전체가구 소비 중 교육비 소비지출, 비율: {tot_교육비_mean_2023:,}원 ({tot_교육비_per_2023:.2f}%)")
print(f"1인가구 소비 중 교육비 소비지출, 비율: {sin_tot_교육비_mean_2023:,}원 ({sin_tot_교육비_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 교육비 소비지출, 비율: 169,667원 (6.40%)
# 1인가구 소비 중 교육비 소비지출, 비율: 24,248원 (1.56%)

# %% [markdown]
# 전체가구 음식숙박비 평균소비 비용, 비율

# %%
tot_음식숙박비_2023 = dat_2023['음식숙박비']
tot_음식숙박비_mean_2023 = int(tot_음식숙박비_2023.mean())
tot_음식숙박비_per_2023 = (tot_음식숙박비_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 음식숙박비 소비 비율

print(tot_음식숙박비_2023)
print(tot_음식숙박비_mean_2023)
print(tot_음식숙박비_per_2023)
# Out:
# 0        860200
# 1         78000
# 2        852800
# 3        122000
# 4        351943
#           ...
# 13139      5167
# 13140    279817
# 13141    452500
# 13142    483042
# 13143    126317
# Name: 음식숙박비, Length: 13144, dtype: int64
# 388451
# 14.653745098298101

# %% [markdown]
# 1인가구 음식숙박비 평균소비 비용, 비율

# %%
sin_tot_음식숙박비_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '음식숙박비']
sin_tot_음식숙박비_mean_2023 = int(sin_tot_음식숙박비_2023.mean())
sin_tot_음식숙박비_per_2023 = (sin_tot_음식숙박비_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 음식숙박비 소비 비율

print(sin_tot_음식숙박비_2023)
print(sin_tot_음식숙박비_mean_2023)
print(sin_tot_음식숙박비_per_2023)
# Out:
# 4        351943
# 13       195345
# 18       205400
# 20       282650
# 25       129133
#           ...
# 13127    143317
# 13130      6600
# 13134     30917
# 13139      5167
# 13143    126317
# Name: 음식숙박비, Length: 4233, dtype: int64
# 260120
# 16.7020565514735

# %%
print(f"전체가구 소비 중 음식숙박비 소비지출, 비율: {tot_음식숙박비_mean_2023:,}원 ({tot_음식숙박비_per_2023:.2f}%)")
print(f"1인가구 소비 중 음식숙박비 소비지출, 비율: {sin_tot_음식숙박비_mean_2023:,}원 ({sin_tot_음식숙박비_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 음식숙박비 소비지출, 비율: 388,451원 (14.65%)
# 1인가구 소비 중 음식숙박비 소비지출, 비율: 260,120원 (16.70%)

# %% [markdown]
# 전체가구 기타상품서비스이용 평균소비 비용, 비율

# %%
tot_기타상품서비스이용_2023 = dat_2023['기타상품서비스이용']
tot_기타상품서비스이용_mean_2023 = int(tot_기타상품서비스이용_2023.mean())
tot_기타상품서비스이용_per_2023 = (tot_기타상품서비스이용_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 기타상품서비스이용 소비 비율

print(tot_기타상품서비스이용_2023)
print(tot_기타상품서비스이용_mean_2023)
print(tot_기타상품서비스이용_per_2023)
# Out:
# 0        232289
# 1         88554
# 2        422559
# 3        127404
# 4         98643
#           ...
# 13139     21633
# 13140    217198
# 13141    371080
# 13142    774415
# 13143     28041
# Name: 기타상품서비스이용, Length: 13144, dtype: int64
# 217999
# 8.22369302095731

# %% [markdown]
# 1인가구 기타상품서비스이용 평균소비 비용, 비율

# %%
sin_tot_기타상품서비스이용_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '기타상품서비스이용']
sin_tot_기타상품서비스이용_mean_2023 = int(sin_tot_기타상품서비스이용_2023.mean())
sin_tot_기타상품서비스이용_per_2023 = (sin_tot_기타상품서비스이용_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 기타상품서비스이용 소비 비율

print(sin_tot_기타상품서비스이용_2023)
print(sin_tot_기타상품서비스이용_mean_2023)
print(sin_tot_기타상품서비스이용_per_2023)
# Out:
# 4         98643
# 13       161633
# 18       152420
# 20        49400
# 25       155562
#           ...
# 13127     44347
# 13130     16920
# 13134     17715
# 13139     21633
# 13143     28041
# Name: 기타상품서비스이용, Length: 4233, dtype: int64
# 125116
# 8.0335787617029

# %%
print(f"전체가구 소비 중 기타상품서비스이용 소비지출, 비율: {tot_기타상품서비스이용_mean_2023:,}원 ({tot_기타상품서비스이용_per_2023:.2f}%)")
print(f"1인가구 소비 중 기타상품서비스이용 소비지출, 비율: {sin_tot_기타상품서비스이용_mean_2023:,}원 ({sin_tot_기타상품서비스이용_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 기타상품서비스이용 소비지출, 비율: 217,999원 (8.22%)
# 1인가구 소비 중 기타상품서비스이용 소비지출, 비율: 125,116원 (8.03%)

# %% [markdown]
# 전체가구 비소비지출금액 평균소비 비용, 비율

# %%
tot_비소비지출금액_2023 = dat_2023['비소비지출금액']
tot_비소비지출금액_mean_2023 = int(tot_비소비지출금액_2023.mean())
tot_비소비지출금액_per_2023 = (tot_비소비지출금액_mean_2023 / total_expend_mean_2023) * 100  # 전체가구 소비 중 비소비지출금액 소비 비율

print(tot_비소비지출금액_2023)
print(tot_비소비지출금액_mean_2023)
print(tot_비소비지출금액_per_2023)
# Out:
# 0        2057310
# 1         540160
# 2         679738
# 3         200162
# 4        1216350
#           ...
# 13139        917
# 13140    1037004
# 13141    1592385
# 13142    1677890
# 13143    1089698
# Name: 비소비지출금액, Length: 13144, dtype: int64
# 946309
# 35.69812117931317

# %% [markdown]
# 1인가구 비소비지출금액 평균소비 비용, 비율

# %%
sin_tot_비소비지출금액_2023 = dat_2023.loc[dat_2023['가구원수'] == 1, '비소비지출금액']
sin_tot_비소비지출금액_mean_2023 = int(sin_tot_비소비지출금액_2023.mean())
sin_tot_비소비지출금액_per_2023 = (sin_tot_비소비지출금액_mean_2023 / single_expend_mean_2023) * 100  # 1인가구 소비 중 비소비지출금액 소비 비율

print(sin_tot_비소비지출금액_2023)
print(sin_tot_비소비지출금액_mean_2023)
print(sin_tot_비소비지출금액_per_2023)
# Out:
# 4        1216350
# 13        290748
# 18        511550
# 20        711200
# 25        177753
#           ...
# 13127     305833
# 13130     261100
# 13134     223333
# 13139        917
# 13143    1089698
# Name: 비소비지출금액, Length: 4233, dtype: int64
# 548998
# 35.250636793194865

# %%
print(f"전체가구 소비 중 비소비지출금액 소비지출, 비율: {tot_비소비지출금액_mean_2023:,}원 ({tot_비소비지출금액_per_2023:.2f}%)")
print(f"1인가구 소비 중 비소비지출금액 소비지출, 비율: {sin_tot_비소비지출금액_mean_2023:,}원 ({sin_tot_비소비지출금액_per_2023:.2f}%)")
# Out:
# 전체가구 소비 중 비소비지출금액 소비지출, 비율: 946,309원 (35.70%)
# 1인가구 소비 중 비소비지출금액 소비지출, 비율: 548,998원 (35.25%)

# %%
col = [['2019','2019','2020','2020','2021','2021','2022','2022','2023','2023'],['전체가구','1인가구','전체가구','1인가구','전체가구','1인가구','전체가구','1인가구','전체가구','1인가구']]
ind = ['소비지출','식료품음료구입','주류담배구입','의류신발구입','주거수도광열비','가정용품가사서비스이용','보건제품구입','교통비','통신비','오락문화비','교육비','음식숙박비',
          '기타상품서비스이용']
content = [[total_expend_mean_2019,single_expend_mean_2019,total_expend_mean_2020,single_expend_mean_2020,total_expend_mean_2021,single_expend_mean_2021,total_expend_mean_2022,single_expend_mean_2022,total_expend_mean_2023,single_expend_mean_2023],
           [tot_식료품음료구입_mean_2019,sin_tot_식료품음료구입_mean_2019,tot_식료품음료구입_mean_2020,sin_tot_식료품음료구입_mean_2020,tot_식료품음료구입_mean_2021,sin_tot_식료품음료구입_mean_2021,tot_식료품음료구입_mean_2022,sin_tot_식료품음료구입_mean_2022,tot_식료품음료구입_mean_2023,sin_tot_식료품음료구입_mean_2023],
           [tot_주류담배구입_mean_2019,sin_tot_주류담배구입_mean_2019,tot_주류담배구입_mean_2020,sin_tot_주류담배구입_mean_2020,tot_주류담배구입_mean_2021,sin_tot_주류담배구입_mean_2021,tot_주류담배구입_mean_2022,sin_tot_주류담배구입_mean_2022,tot_주류담배구입_mean_2023,sin_tot_주류담배구입_mean_2023],
           [tot_의류신발구입_mean_2019,sin_tot_의류신발구입_mean_2019,tot_의류신발구입_mean_2020,sin_tot_의류신발구입_mean_2020,tot_의류신발구입_mean_2021,sin_tot_의류신발구입_mean_2021,tot_의류신발구입_mean_2022,sin_tot_의류신발구입_mean_2022,tot_의류신발구입_mean_2023,sin_tot_의류신발구입_mean_2023],
           [tot_주거수도광열비_mean_2019,sin_tot_주거수도광열비_mean_2019,tot_주거수도광열비_mean_2020,sin_tot_주거수도광열비_mean_2020,tot_주거수도광열비_mean_2021,sin_tot_주거수도광열비_mean_2021,tot_주거수도광열비_mean_2022,sin_tot_주거수도광열비_mean_2022,tot_주거수도광열비_mean_2023,sin_tot_주거수도광열비_mean_2023],
           [tot_가정용품가사서비스이용_mean_2019,sin_tot_가정용품가사서비스이용_mean_2019,tot_가정용품가사서비스이용_mean_2020,sin_tot_가정용품가사서비스이용_mean_2020,tot_가정용품가사서비스이용_mean_2021,sin_tot_가정용품가사서비스이용_mean_2021,tot_가정용품가사서비스이용_mean_2022,sin_tot_가정용품가사서비스이용_mean_2022,tot_가정용품가사서비스이용_mean_2023,sin_tot_가정용품가사서비스이용_mean_2023],
           [tot_보건제품구입_mean_2019,sin_tot_보건제품구입_mean_2019,tot_보건제품구입_mean_2020,sin_tot_보건제품구입_mean_2020,tot_보건제품구입_mean_2021,sin_tot_보건제품구입_mean_2021,tot_보건제품구입_mean_2022,sin_tot_보건제품구입_mean_2022,tot_보건제품구입_mean_2023,sin_tot_보건제품구입_mean_2023],
           [tot_교통비_mean_2019,sin_tot_교통비_mean_2019,tot_교통비_mean_2020,sin_tot_교통비_mean_2020,tot_교통비_mean_2021,sin_tot_교통비_mean_2021,tot_교통비_mean_2022,sin_tot_교통비_mean_2022,tot_교통비_mean_2023,sin_tot_교통비_mean_2023],
           [tot_통신비_mean_2019,sin_tot_통신비_mean_2019,tot_통신비_mean_2020,sin_tot_통신비_mean_2020,tot_통신비_mean_2021,sin_tot_통신비_mean_2021,tot_통신비_mean_2022,sin_tot_통신비_mean_2022,tot_통신비_mean_2023,sin_tot_통신비_mean_2023],
           [tot_오락문화비_mean_2019,sin_tot_오락문화비_mean_2019,tot_오락문화비_mean_2020,sin_tot_오락문화비_mean_2020,tot_오락문화비_mean_2021,sin_tot_오락문화비_mean_2021,tot_오락문화비_mean_2022,sin_tot_오락문화비_mean_2022,tot_오락문화비_mean_2023,sin_tot_오락문화비_mean_2023],
           [tot_교육비_mean_2019,sin_tot_교육비_mean_2019,tot_교육비_mean_2020,sin_tot_교육비_mean_2020,tot_교육비_mean_2021,sin_tot_교육비_mean_2021,tot_교육비_mean_2022,sin_tot_교육비_mean_2022,tot_교육비_mean_2023,sin_tot_교육비_mean_2023],
           [tot_음식숙박비_mean_2019,sin_tot_음식숙박비_mean_2019,tot_음식숙박비_mean_2020,sin_tot_음식숙박비_mean_2020,tot_음식숙박비_mean_2021,sin_tot_음식숙박비_mean_2021,tot_음식숙박비_mean_2022,sin_tot_음식숙박비_mean_2022,tot_음식숙박비_mean_2023,sin_tot_음식숙박비_mean_2023],
           [tot_기타상품서비스이용_mean_2019,sin_tot_기타상품서비스이용_mean_2019,tot_기타상품서비스이용_mean_2020,sin_tot_기타상품서비스이용_mean_2020,tot_기타상품서비스이용_mean_2021,sin_tot_기타상품서비스이용_mean_2021,tot_기타상품서비스이용_mean_2022,sin_tot_기타상품서비스이용_mean_2022,tot_기타상품서비스이용_mean_2023,sin_tot_기타상품서비스이용_mean_2023]]

# %%
df_2019_2023_소비 = pd.DataFrame(content,columns=col,index=ind)
df_2019_2023_소비
# Out:
#                 2019              2020              2021              2022  \
#                 전체가구     1인가구     전체가구     1인가구     전체가구     1인가구     전체가구
# 소비지출         2294545  1307691  2294703  1267818  2379894  1360988  2484244
# 식료품음료구입       330163   175818   376312   192714   388651   204345   389564
# 주류담배구입         34241    28626    36077    28446    37719    31483    37535
# 의류신발구입        131953    66339   110233    57543   117356    62391   124142
# 주거수도광열비       261760   237834   282187   244525   292074   257078   294624
# 가정용품가사서비스이용   113575    62826   130262    59014   128857    64682   114133
# 보건제품구입        206698   118033   219874   122046   223207   121820   233825
# 교통비           287754   160438   279250   133018   286067   144317   302091
# 통신비           112556    51662   111928    55401   114891    59044   116984
# 오락문화비         155304    83652   129164    73450   130236    80112   147422
# ...

# %%
col_rate = [['2019','2019','2020','2020','2021','2021','2022','2022','2023','2023'],['전체가구','1인가구','전체가구','1인가구','전체가구','1인가구','전체가구','1인가구','전체가구','1인가구']]
ind_rate = ['소비지출','식료품음료구입','주류담배구입','의류신발구입','주거수도광열비','가정용품가사서비스이용','보건제품구입','교통비','통신비','오락문화비','교육비','음식숙박비',
          '기타상품서비스이용']
content_rate = [[total_expend_mean_2019,single_expend_mean_2019,total_expend_mean_2020,single_expend_mean_2020,total_expend_mean_2021,single_expend_mean_2021,total_expend_mean_2022,single_expend_mean_2022,total_expend_mean_2023,single_expend_mean_2023],
                [tot_식료품음료구입_per_2019,sin_tot_식료품음료구입_per_2019,tot_식료품음료구입_per_2020,sin_tot_식료품음료구입_per_2020,tot_식료품음료구입_per_2021,sin_tot_식료품음료구입_per_2021,tot_식료품음료구입_per_2022,sin_tot_식료품음료구입_per_2022,tot_식료품음료구입_per_2023,sin_tot_식료품음료구입_per_2023],
                [tot_주류담배구입_per_2019,sin_tot_주류담배구입_per_2019,tot_주류담배구입_per_2020,sin_tot_주류담배구입_per_2020,tot_주류담배구입_per_2021,sin_tot_주류담배구입_per_2021,tot_주류담배구입_per_2022,sin_tot_주류담배구입_per_2022,tot_주류담배구입_per_2023,sin_tot_주류담배구입_per_2023],
                [tot_의류신발구입_per_2019,sin_tot_의류신발구입_per_2019,tot_의류신발구입_per_2020,sin_tot_의류신발구입_per_2020,tot_의류신발구입_per_2021,sin_tot_의류신발구입_per_2021,tot_의류신발구입_per_2022,sin_tot_의류신발구입_per_2022,tot_의류신발구입_per_2023,sin_tot_의류신발구입_per_2023],
                [tot_주거수도광열비_per_2019,sin_tot_주거수도광열비_per_2019,tot_주거수도광열비_per_2020,sin_tot_주거수도광열비_per_2020,tot_주거수도광열비_per_2021,sin_tot_주거수도광열비_per_2021,tot_주거수도광열비_per_2022,sin_tot_주거수도광열비_per_2022,tot_주거수도광열비_per_2023,sin_tot_주거수도광열비_per_2023],
                [tot_가정용품가사서비스이용_per_2019,sin_tot_가정용품가사서비스이용_per_2019,tot_가정용품가사서비스이용_per_2020,sin_tot_가정용품가사서비스이용_per_2020,tot_가정용품가사서비스이용_per_2021,sin_tot_가정용품가사서비스이용_per_2021,tot_가정용품가사서비스이용_per_2022,sin_tot_가정용품가사서비스이용_per_2022,tot_가정용품가사서비스이용_per_2023,sin_tot_가정용품가사서비스이용_per_2023],
                [tot_보건제품구입_per_2019,sin_tot_보건제품구입_per_2019,tot_보건제품구입_per_2020,sin_tot_보건제품구입_per_2020,tot_보건제품구입_per_2021,sin_tot_보건제품구입_per_2021,tot_보건제품구입_per_2022,sin_tot_보건제품구입_per_2022,tot_보건제품구입_per_2023,sin_tot_보건제품구입_per_2023],
                [tot_교통비_per_2019,sin_tot_교통비_per_2019,tot_교통비_per_2020,sin_tot_교통비_per_2020,tot_교통비_per_2021,sin_tot_교통비_per_2021,tot_교통비_per_2022,sin_tot_교통비_per_2022,tot_교통비_per_2023,sin_tot_교통비_per_2023],
                [tot_통신비_per_2019,sin_tot_통신비_per_2019,tot_통신비_per_2020,sin_tot_통신비_per_2020,tot_통신비_per_2021,sin_tot_통신비_per_2021,tot_통신비_per_2022,sin_tot_통신비_per_2022,tot_통신비_per_2023,sin_tot_통신비_per_2023],
                [tot_오락문화비_per_2019,sin_tot_오락문화비_per_2019,tot_오락문화비_per_2020,sin_tot_오락문화비_per_2020,tot_오락문화비_per_2021,sin_tot_오락문화비_per_2021,tot_오락문화비_per_2022,sin_tot_오락문화비_per_2022,tot_오락문화비_per_2023,sin_tot_오락문화비_per_2023],
                [tot_교육비_per_2019,sin_tot_교육비_per_2019,tot_교육비_per_2020,sin_tot_교육비_per_2020,tot_교육비_per_2021,sin_tot_교육비_per_2021,tot_교육비_per_2022,sin_tot_교육비_per_2022,tot_교육비_per_2023,sin_tot_교육비_per_2023],
                [tot_음식숙박비_per_2019,sin_tot_음식숙박비_per_2019,tot_음식숙박비_per_2020,sin_tot_음식숙박비_per_2020,tot_음식숙박비_per_2021,sin_tot_음식숙박비_per_2021,tot_음식숙박비_per_2022,sin_tot_음식숙박비_per_2022,tot_음식숙박비_per_2023,sin_tot_음식숙박비_per_2023],
                [tot_기타상품서비스이용_per_2019,sin_tot_기타상품서비스이용_per_2019,tot_기타상품서비스이용_per_2020,sin_tot_기타상품서비스이용_per_2020,tot_기타상품서비스이용_per_2021,sin_tot_기타상품서비스이용_per_2021,tot_기타상품서비스이용_per_2022,sin_tot_기타상품서비스이용_per_2022,tot_기타상품서비스이용_per_2023,sin_tot_기타상품서비스이용_per_2023]]

# %%
df_2019_2023_소비비율 = pd.DataFrame(content_rate,columns=col_rate,index=ind_rate)
df_2019_2023_소비비율
# Out:
#                      2019                        2020                \
#                      전체가구          1인가구          전체가구          1인가구
# 소비지출         2.294545e+06  1.307691e+06  2.294703e+06  1.267818e+06
# 식료품음료구입      1.438904e+01  1.344492e+01  1.639916e+01  1.520045e+01
# 주류담배구입       1.492278e+00  2.189049e+00  1.572186e+00  2.243697e+00
# 의류신발구입       5.750726e+00  5.072987e+00  4.803802e+00  4.538743e+00
# 주거수도광열비      1.140793e+01  1.818732e+01  1.229732e+01  1.928707e+01
# 가정용품가사서비스이용  4.949783e+00  4.804346e+00  5.676639e+00  4.654769e+00
# 보건제품구입       9.008235e+00  9.026062e+00  9.581806e+00  9.626461e+00
# 교통비          1.254079e+01  1.226880e+01  1.216933e+01  1.049188e+01
# 통신비          4.905373e+00  3.950627e+00  4.877668e+00  4.369791e+00
# 오락문화비        6.768401e+00  6.396924e+00  5.628789e+00  5.793418e+00
# 교육비          6.588191e+00  1.737031e+00  5.733727e+00  1.167518e+00
# 음식숙박비        1.356774e+01  1.494329e+01  1.268975e+01  1.513955e+01
# ...

# %%
df_2019_2023_소비비율.round(2)
# Out:
#                    2019                    2020                    2021  \
#                    전체가구        1인가구        전체가구        1인가구        전체가구
# 소비지출         2294545.00  1307691.00  2294703.00  1267818.00  2379894.00
# 식료품음료구입           14.39       13.44       16.40       15.20       16.33
# 주류담배구입             1.49        2.19        1.57        2.24        1.58
# 의류신발구입             5.75        5.07        4.80        4.54        4.93
# 주거수도광열비           11.41       18.19       12.30       19.29       12.27
# 가정용품가사서비스이용        4.95        4.80        5.68        4.65        5.41
# 보건제품구입             9.01        9.03        9.58        9.63        9.38
# 교통비               12.54       12.27       12.17       10.49       12.02
# 통신비                4.91        3.95        4.88        4.37        4.83
# 오락문화비              6.77        6.40        5.63        5.79        5.47
# 교육비                6.59        1.74        5.73        1.17        6.23
# ...

# %%
col = [['2019','2019','2020','2020','2021','2021','2022','2022','2023','2023'],['전체가구','1인가구','전체가구','1인가구','전체가구','1인가구','전체가구','1인가구','전체가구','1인가구']]
ind = ['소비지출','식료품음료구입','주류담배구입','의류신발구입','주거수도광열비','가정용품가사서비스이용','보건제품구입','교통비','통신비','오락문화비','교육비','음식숙박비','기타상품서비스이용']

content = []

for i in range(len(ind)):
    temp = []
    for j in range(len(col[0])):
        temp.append(f'tot_{ind[i]}_mean_{col[0][j]}')
        temp.append(f'sin_tot_{ind[i]}_mean_{col[0][j]}')
    content.append(temp)

# %%
content
# Out:
# [['tot_소비지출_mean_2019',
#   'sin_tot_소비지출_mean_2019',
#   'tot_소비지출_mean_2019',
#   'sin_tot_소비지출_mean_2019',
#   'tot_소비지출_mean_2020',
#   'sin_tot_소비지출_mean_2020',
#   'tot_소비지출_mean_2020',
#   'sin_tot_소비지출_mean_2020',
#   'tot_소비지출_mean_2021',
#   'sin_tot_소비지출_mean_2021',
#   'tot_소비지출_mean_2021',
#   'sin_tot_소비지출_mean_2021',
#   'tot_소비지출_mean_2022',
#   'sin_tot_소비지출_mean_2022',
#   'tot_소비지출_mean_2022',
#   'sin_tot_소비지출_mean_2022',
#   'tot_소비지출_mean_2023',
#   'sin_tot_소비지출_mean_2023',
#   'tot_소비지출_mean_2023',
#   'sin_tot_소비지출_mean_2023'],
#  ['tot_식료품음료구입_mean_2019',
#   'sin_tot_식료품음료구입_mean_2019',
#   'tot_식료품음료구입_mean_2019',
#   'sin_tot_식료품음료구입_mean_2019',
#   'tot_식료품음료구입_mean_2020',
#   'sin_tot_식료품음료구입_mean_2020',
#   'tot_식료품음료구입_mean_2020',
#   'sin_tot_식료품음료구입_mean_2020',
#   'tot_식료품음료구입_mean_2021',
#   'sin_tot_식료품음료구입_mean_2021',
#   'tot_식료품음료구입_mean_2021',
#   'sin_tot_식료품음료구입_mean_2021',
#   'tot_식료품음료구입_mean_2022',
#   'sin_tot_식료품음료구입_mean_2022',
# ...
